# %%
import pandas as pd
from datetime import datetime
import os

# %%
# Lectura archivo CSV Pruebas Saber 11
# file_path = "Resultados_Saber_11_Original.csv"
file_path = r"C:\Users\jaime\ALUNA Dropbox\JAIME ARTURO RAMIREZ\MIAD-Proyecto\Resultados__nicos_Saber_11_20241014.csv"

# Leer el archivo CSV (utiliza chunks para manejar grandes volúmenes de datos)
chunksize = 100000  # Tamaño de los chunks
data_iter = pd.read_csv(file_path, chunksize=chunksize, low_memory=False)

# Concatenar los chunks en un solo DataFrame
df_Saber11 = pd.concat(data_iter)

# %%
# Lectura archivo CSV Pruebas Saber Pro
# file_path = "Resultados__nicos_Saber_Pro.csv"
file_path = r"C:\Users\jaime\ALUNA Dropbox\JAIME ARTURO RAMIREZ\MIAD-Proyecto\Resultados__nicos_Saber_Pro.csv"

# Leer el archivo CSV (utiliza chunks para manejar grandes volúmenes de datos)
chunksize = 100000  # Tamaño de los chunks
data_iter = pd.read_csv(file_path, chunksize=chunksize, low_memory=False)

# Concatenar los chunks en un solo DataFrame
df_SaberPro = pd.concat(data_iter)

# %%
df_Saber11.columns
# Out:
# Index(['PERIODO', 'ESTU_TIPODOCUMENTO', 'ESTU_CONSECUTIVO',
#        'COLE_AREA_UBICACION', 'COLE_BILINGUE', 'COLE_CALENDARIO',
#        'COLE_CARACTER', 'COLE_COD_DANE_ESTABLECIMIENTO', 'COLE_COD_DANE_SEDE',
#        'COLE_COD_DEPTO_UBICACION', 'COLE_COD_MCPIO_UBICACION',
#        'COLE_CODIGO_ICFES', 'COLE_DEPTO_UBICACION', 'COLE_GENERO',
#        'COLE_JORNADA', 'COLE_MCPIO_UBICACION', 'COLE_NATURALEZA',
#        'COLE_NOMBRE_ESTABLECIMIENTO', 'COLE_NOMBRE_SEDE',
#        'COLE_SEDE_PRINCIPAL', 'ESTU_COD_DEPTO_PRESENTACION',
#        'ESTU_COD_MCPIO_PRESENTACION', 'ESTU_COD_RESIDE_DEPTO',
#        'ESTU_COD_RESIDE_MCPIO', 'ESTU_DEPTO_PRESENTACION', 'ESTU_DEPTO_RESIDE',
#        'ESTU_ESTADOINVESTIGACION', 'ESTU_ESTUDIANTE', 'ESTU_FECHANACIMIENTO',
#        'ESTU_GENERO', 'ESTU_MCPIO_PRESENTACION', 'ESTU_MCPIO_RESIDE',
#        'ESTU_NACIONALIDAD', 'ESTU_PAIS_RESIDE', 'ESTU_PRIVADO_LIBERTAD',
#        'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE',
#        'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR', 'FAMI_TIENEAUTOMOVIL',
#        'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET', 'FAMI_TIENELAVADORA',
#        'DESEMP_INGLES', 'PUNT_INGLES', 'PUNT_MATEMATICAS',
#        'PUNT_SOCIALES_CIUDADANAS', 'PUNT_C_NATURALES', 'PUNT_LECTURA_CRITICA',
#        'PUNT_GLOBAL'],
#       dtype='object')

# %%
df_SaberPro.columns
# Out:
# Index(['PERIODO', 'ESTU_CONSECUTIVO', 'ESTU_TIPODOCUMENTO', 'ESTU_PAIS_RESIDE',
#        'ESTU_COD_RESIDE_DEPTO', 'ESTU_DEPTO_RESIDE', 'ESTU_COD_RESIDE_MCPIO',
#        'ESTU_MCPIO_RESIDE', 'ESTU_CODDANE_COLE_TERMINO',
#        'ESTU_COD_COLE_MCPIO_TERMINO', 'ESTU_COD_DEPTO_PRESENTACION',
#        'INST_COD_INSTITUCION', 'INST_NOMBRE_INSTITUCION',
#        'INST_CARACTER_ACADEMICO', 'ESTU_NUCLEO_PREGRADO',
#        'ESTU_INST_DEPARTAMENTO', 'ESTU_INST_CODMUNICIPIO',
#        'ESTU_INST_MUNICIPIO', 'ESTU_PRGM_ACADEMICO', 'ESTU_PRGM_DEPARTAMENTO',
#        'ESTU_PRGM_CODMUNICIPIO', 'ESTU_PRGM_MUNICIPIO',
#        'ESTU_NIVEL_PRGM_ACADEMICO', 'ESTU_METODO_PRGM',
#        'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_DEPTO_PRESENTACION',
#        'ESTU_COD_MCPIO_PRESENTACION', 'ESTU_MCPIO_PRESENTACION',
#        'ESTU_PAGOMATRICULABECA', 'ESTU_PAGOMATRICULACREDITO',
#        'ESTU_HORASSEMANATRABAJA', 'ESTU_SNIES_PRGMACADEMICO',
#        'ESTU_PRIVADO_LIBERTAD', 'ESTU_NACIONALIDAD', 'ESTU_ESTUDIANTE',
#        'ESTU_GENERO', 'ESTU_COLE_TERMINO', 'ESTU_PAGOMATRICULAPADRES',
#        'ESTU_ESTADOINVESTIGACION', 'ESTU_FECHANACIMIENTO',
#        'ESTU_PAGOMATRICULAPROPIO', 'ESTU_TIPODOCUMENTOSB11',
#        'FAMI_EDUCACIONPADRE', 'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENELAVADORA',
#        'FAMI_ESTRATOVIVIENDA', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET',
#        'FAMI_EDUCACIONMADRE', 'INST_ORIGEN', 'MOD_RAZONA_CUANTITAT_PUNT',
#        'MOD_COMUNI_ESCRITA_PUNT', 'MOD_COMUNI_ESCRITA_DESEM',
#        'MOD_INGLES_DESEM', 'MOD_LECTURA_CRITICA_PUNT', 'MOD_INGLES_PUNT',
#        'MOD_COMPETEN_CIUDADA_PUNT'],
#       dtype='object')

# %%
# Saber11: Extraer el año de la columna 'PERIODO' (los primeros 4 dígitos) y crear una nueva columna 'AÑO'
df_Saber11['AÑO'] = df_Saber11['PERIODO'].astype(str).str[:4]

# Convertir la nueva columna 'AÑO' a formato numérico
df_Saber11['AÑO'] = pd.to_numeric(df_Saber11['AÑO'])

# Ver cuántos registros hay de cada año
conteo_por_año = df_Saber11['AÑO'].value_counts().sort_index()

# Mostrar el resultado
print(conteo_por_año)
# Out:
# AÑO
# 2010     670030
# 2011     650420
# 2012     680388
# 2013     583775
# 2014     571637
# 2015     570464
# 2016     563370
# 2017     561287
# 2018      32348
# 2019    1109085
# 2020      15435
# 2021      15528
# 2022    1085937
# Name: count, dtype: int64

# %%
# SaberPro: Extraer el año de la columna 'PERIODO' (los primeros 4 dígitos) y crear una nueva columna 'AÑO'
df_SaberPro['AÑO'] = df_SaberPro['PERIODO'].astype(str).str[:4]

# Convertir la nueva columna 'AÑO' a formato numérico
df_SaberPro['AÑO'] = pd.to_numeric(df_SaberPro['AÑO'])

# Ver cuántos registros hay de cada año
conteo_por_año_pro = df_SaberPro['AÑO'].value_counts().sort_index()

# Mostrar el resultado
print(conteo_por_año_pro)
# Out:
# AÑO
# 2018    235597
# 2019    260756
# 2020    246455
# 2021    248769
# 2022    225905
# Name: count, dtype: int64

# %%
df_SaberPro.shape
# Out:
# (1217482, 58)

# %%
df_Saber11.shape
# Out:
# (7109704, 52)

# %%
# Eliminar la columna 'PERIODO' del DataFrame Saber 11

df_Saber11 = df_Saber11.drop('PERIODO', axis=1)

# Eliminar la columna 'PERIODO' del DataFrame Saber Pro
df_SaberPro = df_SaberPro.drop('PERIODO', axis=1)

# %%
# Respecto a la fecha de nacimiento, es determinante para saber la edad en la cual tomó el examen,
# más no es necesaria la fecha de nacimiento una vez hecho el cálculo.
# Ahora generamos la edad a partir de la fecha de nacimiento y eliminamos la columna de fecha
# Previamente se hace una limpieza de datos y conversión de fecha a un solo formato

# El proceso que estamos siguiendo es:
# Filtrar el rango de años: En la función convertir_a_fecha_estandar, el código revisa si el año de nacimiento
# está dentro del rango de 1980 a 2010, que es razonable para estudiantes que toman el examen Saber 11 (esto supone que
# vamos a analizar estudiante que al momento de tomar el examen, por ejemplo en 2010, tienen máximo 40 años). Consideramos
# que para efectos del proyecto es un mecanismo práctico y válido.
# Manejo de valores inválidos: Si una fecha no está en el formato correcto o el año no es válido,
# el valor se marca como None y no se calcula la edad para ese registro.
# Cálculo de la edad: Calculamos la edad solo para las fechas que pasaron la validación.

# Paso 1: Función para convertir las fechas y manejar los casos incorrectos
def convertir_a_fecha_estandar(fecha):
    try:
        # Convertir a formato datetime usando día/mes/año
        fecha_convertida = datetime.strptime(fecha, '%d/%m/%Y')
        # Filtrar por un rango de años razonable
        if 1980 <= fecha_convertida.year <= 2010:
            return fecha_convertida
        else:
            return None  # Si el año no está en el rango, devolver None
    except (ValueError, TypeError):
        return None  # Devolver None si la fecha no es válida

# Aplicar la conversión a la columna de fechas en Saber 11
df_Saber11['FECHA_NACIMIENTO_LIMPIA'] = df_Saber11['ESTU_FECHANACIMIENTO'].apply(convertir_a_fecha_estandar)

# Paso 2: Calcular la edad en el momento del examen
def calcular_edad_en_examen(examen_year, fecha_nacimiento):
    if pd.notna(fecha_nacimiento):
        return examen_year - fecha_nacimiento.year
    else:
        return None

df_Saber11['EDAD_EXAMEN'] = df_Saber11.apply(lambda row: calcular_edad_en_examen(row['AÑO'], row['FECHA_NACIMIENTO_LIMPIA']), axis=1)

# Paso 3: Filtrar los que tengan 40 años o menos al momento de presentar el examen
df_Saber11 = df_Saber11[df_Saber11['EDAD_EXAMEN'] <= 40]

# Paso 4: Eliminar las columnas innecesarias
df_Saber11.drop(columns=['ESTU_FECHANACIMIENTO', 'FECHA_NACIMIENTO_LIMPIA'], inplace=True)

# Verificar el resultado
print(df_Saber11[['AÑO', 'EDAD_EXAMEN']].head())
# Out:
#     AÑO  EDAD_EXAMEN
# 0  2013         19.0
# 1  2019         16.0
# 2  2019         16.0
# 3  2012         16.0
# 4  2013         16.0

# %%
# Aplicar la conversión a la columna de fechas en Saber Pro
df_SaberPro['FECHA_NACIMIENTO_LIMPIA'] = df_SaberPro['ESTU_FECHANACIMIENTO'].apply(convertir_a_fecha_estandar)

# Calcular la edad en el momento del examen para Saber Pro
df_SaberPro['EDAD_EXAMEN'] = df_SaberPro.apply(lambda row: calcular_edad_en_examen(row['AÑO'], row['FECHA_NACIMIENTO_LIMPIA']), axis=1)

# Filtrar los que tengan 40 años o menos al momento de presentar el examen
df_SaberPro = df_SaberPro[df_SaberPro['EDAD_EXAMEN'] <= 40]

# Eliminar las columnas innecesarias
df_SaberPro.drop(columns=['ESTU_FECHANACIMIENTO', 'FECHA_NACIMIENTO_LIMPIA'], inplace=True)

# Verificar el resultado
print(df_SaberPro[['AÑO', 'EDAD_EXAMEN']].head())
# Out:
#     AÑO  EDAD_EXAMEN
# 0  2018         21.0
# 1  2018         23.0
# 2  2018         24.0
# 3  2018         21.0
# 4  2018         31.0

# %%
df_SaberPro.columns
# Out:
# Index(['ESTU_CONSECUTIVO', 'ESTU_TIPODOCUMENTO', 'ESTU_PAIS_RESIDE',
#        'ESTU_COD_RESIDE_DEPTO', 'ESTU_DEPTO_RESIDE', 'ESTU_COD_RESIDE_MCPIO',
#        'ESTU_MCPIO_RESIDE', 'ESTU_CODDANE_COLE_TERMINO',
#        'ESTU_COD_COLE_MCPIO_TERMINO', 'ESTU_COD_DEPTO_PRESENTACION',
#        'INST_COD_INSTITUCION', 'INST_NOMBRE_INSTITUCION',
#        'INST_CARACTER_ACADEMICO', 'ESTU_NUCLEO_PREGRADO',
#        'ESTU_INST_DEPARTAMENTO', 'ESTU_INST_CODMUNICIPIO',
#        'ESTU_INST_MUNICIPIO', 'ESTU_PRGM_ACADEMICO', 'ESTU_PRGM_DEPARTAMENTO',
#        'ESTU_PRGM_CODMUNICIPIO', 'ESTU_PRGM_MUNICIPIO',
#        'ESTU_NIVEL_PRGM_ACADEMICO', 'ESTU_METODO_PRGM',
#        'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_DEPTO_PRESENTACION',
#        'ESTU_COD_MCPIO_PRESENTACION', 'ESTU_MCPIO_PRESENTACION',
#        'ESTU_PAGOMATRICULABECA', 'ESTU_PAGOMATRICULACREDITO',
#        'ESTU_HORASSEMANATRABAJA', 'ESTU_SNIES_PRGMACADEMICO',
#        'ESTU_PRIVADO_LIBERTAD', 'ESTU_NACIONALIDAD', 'ESTU_ESTUDIANTE',
#        'ESTU_GENERO', 'ESTU_COLE_TERMINO', 'ESTU_PAGOMATRICULAPADRES',
#        'ESTU_ESTADOINVESTIGACION', 'ESTU_PAGOMATRICULAPROPIO',
#        'ESTU_TIPODOCUMENTOSB11', 'FAMI_EDUCACIONPADRE', 'FAMI_TIENEAUTOMOVIL',
#        'FAMI_TIENELAVADORA', 'FAMI_ESTRATOVIVIENDA', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENEINTERNET', 'FAMI_EDUCACIONMADRE', 'INST_ORIGEN',
#        'MOD_RAZONA_CUANTITAT_PUNT', 'MOD_COMUNI_ESCRITA_PUNT',
#        'MOD_COMUNI_ESCRITA_DESEM', 'MOD_INGLES_DESEM',
#        'MOD_LECTURA_CRITICA_PUNT', 'MOD_INGLES_PUNT',
#        'MOD_COMPETEN_CIUDADA_PUNT', 'AÑO', 'EDAD_EXAMEN'],
#       dtype='object')

# %%
df_Saber11.columns
# Out:
# Index(['ESTU_TIPODOCUMENTO', 'ESTU_CONSECUTIVO', 'COLE_AREA_UBICACION',
#        'COLE_BILINGUE', 'COLE_CALENDARIO', 'COLE_CARACTER',
#        'COLE_COD_DANE_ESTABLECIMIENTO', 'COLE_COD_DANE_SEDE',
#        'COLE_COD_DEPTO_UBICACION', 'COLE_COD_MCPIO_UBICACION',
#        'COLE_CODIGO_ICFES', 'COLE_DEPTO_UBICACION', 'COLE_GENERO',
#        'COLE_JORNADA', 'COLE_MCPIO_UBICACION', 'COLE_NATURALEZA',
#        'COLE_NOMBRE_ESTABLECIMIENTO', 'COLE_NOMBRE_SEDE',
#        'COLE_SEDE_PRINCIPAL', 'ESTU_COD_DEPTO_PRESENTACION',
#        'ESTU_COD_MCPIO_PRESENTACION', 'ESTU_COD_RESIDE_DEPTO',
#        'ESTU_COD_RESIDE_MCPIO', 'ESTU_DEPTO_PRESENTACION', 'ESTU_DEPTO_RESIDE',
#        'ESTU_ESTADOINVESTIGACION', 'ESTU_ESTUDIANTE', 'ESTU_GENERO',
#        'ESTU_MCPIO_PRESENTACION', 'ESTU_MCPIO_RESIDE', 'ESTU_NACIONALIDAD',
#        'ESTU_PAIS_RESIDE', 'ESTU_PRIVADO_LIBERTAD', 'FAMI_CUARTOSHOGAR',
#        'FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE', 'FAMI_ESTRATOVIVIENDA',
#        'FAMI_PERSONASHOGAR', 'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENEINTERNET', 'FAMI_TIENELAVADORA', 'DESEMP_INGLES',
#        'PUNT_INGLES', 'PUNT_MATEMATICAS', 'PUNT_SOCIALES_CIUDADANAS',
#        'PUNT_C_NATURALES', 'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL', 'AÑO',
#        'EDAD_EXAMEN'],
#       dtype='object')

# %%
Columnas_a_eliminar_saber_11 = ['ESTU_CONSECUTIVO','ESTU_TIPODOCUMENTO','ESTU_ESTADOINVESTIGACION']
Columnas_a_eliminar_saber_pro = ['ESTU_CONSECUTIVO','ESTU_TIPODOCUMENTO','ESTU_ESTADOINVESTIGACION','INST_NOMBRE_INSTITUCION','ESTU_TIPODOCUMENTOSB11']
df_Saber11.drop(columns=Columnas_a_eliminar_saber_11, inplace=True)
df_SaberPro.drop(columns=Columnas_a_eliminar_saber_pro, inplace=True)

# %%
df_Saber11.shape
# Out:
# (6989288, 48)

# %%
df_SaberPro.shape
# Out:
# (1153951, 52)

# %%
print(df_Saber11.isnull().sum())
# Out:
# COLE_AREA_UBICACION                 2550
# COLE_BILINGUE                     900023
# COLE_CALENDARIO                     1383
# COLE_CARACTER                     105646
# COLE_COD_DANE_ESTABLECIMIENTO       2893
# COLE_COD_DANE_SEDE                    93
# COLE_COD_DEPTO_UBICACION               6
# COLE_COD_MCPIO_UBICACION               6
# COLE_CODIGO_ICFES                  23418
# COLE_DEPTO_UBICACION                   6
# COLE_GENERO                            6
# COLE_JORNADA                           6
# COLE_MCPIO_UBICACION                   6
# COLE_NATURALEZA                        6
# COLE_NOMBRE_ESTABLECIMIENTO            6
# COLE_NOMBRE_SEDE                       6
# COLE_SEDE_PRINCIPAL                    6
# ESTU_COD_DEPTO_PRESENTACION           85
# ESTU_COD_MCPIO_PRESENTACION           85
# ESTU_COD_RESIDE_DEPTO              38506
# ESTU_COD_RESIDE_MCPIO              38506
# ESTU_DEPTO_PRESENTACION               85
# ESTU_DEPTO_RESIDE                  38506
# ESTU_ESTUDIANTE                        0
# ESTU_GENERO                         3332
# ESTU_MCPIO_PRESENTACION               85
# ESTU_MCPIO_RESIDE                  38506
# ESTU_NACIONALIDAD                      0
# ESTU_PAIS_RESIDE                       0
# ESTU_PRIVADO_LIBERTAD                  0
# FAMI_CUARTOSHOGAR                 125560
# FAMI_EDUCACIONMADRE               206409
# FAMI_EDUCACIONPADRE               206062
# FAMI_ESTRATOVIVIENDA              211473
# FAMI_PERSONASHOGAR                125079
# FAMI_TIENEAUTOMOVIL               130479
# FAMI_TIENECOMPUTADOR              147425
# FAMI_TIENEINTERNET                184992
# FAMI_TIENELAVADORA                124435
# DESEMP_INGLES                       5317
# PUNT_INGLES                         4137
# PUNT_MATEMATICAS                       0
# PUNT_SOCIALES_CIUDADANAS         2539155
# PUNT_C_NATURALES                 2539155
# PUNT_LECTURA_CRITICA             2539155
# PUNT_GLOBAL                      2539155
# AÑO                                    0
# EDAD_EXAMEN                            0
# dtype: int64

# %%
print(df_SaberPro.isnull().sum())
# Out:
# ESTU_PAIS_RESIDE                       0
# ESTU_COD_RESIDE_DEPTO               3061
# ESTU_DEPTO_RESIDE                   3061
# ESTU_COD_RESIDE_MCPIO               3061
# ESTU_MCPIO_RESIDE                   3061
# ESTU_CODDANE_COLE_TERMINO         370391
# ESTU_COD_COLE_MCPIO_TERMINO       370391
# ESTU_COD_DEPTO_PRESENTACION           93
# INST_COD_INSTITUCION                   0
# INST_CARACTER_ACADEMICO                0
# ESTU_NUCLEO_PREGRADO                   0
# ESTU_INST_DEPARTAMENTO                 0
# ESTU_INST_CODMUNICIPIO                 0
# ESTU_INST_MUNICIPIO                    0
# ESTU_PRGM_ACADEMICO                    0
# ESTU_PRGM_DEPARTAMENTO                 0
# ESTU_PRGM_CODMUNICIPIO                 0
# ESTU_PRGM_MUNICIPIO                    0
# ESTU_NIVEL_PRGM_ACADEMICO              0
# ESTU_METODO_PRGM                       0
# ESTU_VALORMATRICULAUNIVERSIDAD     11194
# ESTU_DEPTO_PRESENTACION               93
# ESTU_COD_MCPIO_PRESENTACION           93
# ESTU_MCPIO_PRESENTACION               93
# ESTU_PAGOMATRICULABECA             11656
# ESTU_PAGOMATRICULACREDITO          11584
# ESTU_HORASSEMANATRABAJA            50367
# ESTU_SNIES_PRGMACADEMICO               2
# ESTU_PRIVADO_LIBERTAD                  0
# ESTU_NACIONALIDAD                      0
# ESTU_ESTUDIANTE                        0
# ESTU_GENERO                          109
# ESTU_COLE_TERMINO                 347708
# ESTU_PAGOMATRICULAPADRES           11458
# ESTU_PAGOMATRICULAPROPIO           11537
# FAMI_EDUCACIONPADRE                37170
# FAMI_TIENEAUTOMOVIL                68952
# FAMI_TIENELAVADORA                 61369
# FAMI_ESTRATOVIVIENDA               49795
# FAMI_TIENECOMPUTADOR               58931
# FAMI_TIENEINTERNET                 42923
# FAMI_EDUCACIONMADRE                37849
# INST_ORIGEN                            0
# MOD_RAZONA_CUANTITAT_PUNT              0
# MOD_COMUNI_ESCRITA_PUNT             6797
# MOD_COMUNI_ESCRITA_DESEM           51262
# MOD_INGLES_DESEM                     105
# MOD_LECTURA_CRITICA_PUNT               0
# MOD_INGLES_PUNT                      105
# MOD_COMPETEN_CIUDADA_PUNT              0
# AÑO                                    0
# EDAD_EXAMEN                            0
# dtype: int64

# %%
# Paso 1: Seleccionar las columnas categóricas (no numéricas)
# Esto ayudará a identificar columnas de tipo "object" que suelen ser categóricas
columnas_categoricas = df_Saber11.select_dtypes(include=['object']).columns

# Paso 2: Mostrar los valores únicos de cada columna categórica
# Este bucle recorre cada columna categórica y muestra sus valores únicos
for columna in columnas_categoricas:
    print(f"Valores únicos de la columna '{columna}':")
    print(df_Saber11[columna].unique())
    print("\n" + "-"*50 + "\n")
# Out:
# Valores únicos de la columna 'COLE_AREA_UBICACION':
# ['URBANO' 'RURAL' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'COLE_BILINGUE':
# ['N' nan 'S']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'COLE_CALENDARIO':
# ['B' 'A' 'OTRO' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'COLE_CARACTER':
# ['ACADÉMICO' 'TÉCNICO/ACADÉMICO' 'TÉCNICO' 'NO APLICA' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'COLE_DEPTO_UBICACION':
# ['BOGOTA' 'HUILA' 'QUINDIO' 'CAUCA' 'VALLE' 'TOLIMA' 'ANTIOQUIA'
#  'PUTUMAYO' 'SANTANDER' 'ATLANTICO' 'SUCRE' 'BOYACA' 'BOLIVAR' 'CESAR'
#  'BOGOTÁ' 'MAGDALENA' 'NORTE SANTANDER' 'NARIÑO' 'CUNDINAMARCA' 'CASANARE'
#  'META' 'CALDAS' 'CHOCO' 'CORDOBA' 'RISARALDA' 'VICHADA' 'CAQUETA'
#  'LA GUAJIRA' 'AMAZONAS' 'ARAUCA' 'GUAVIARE' 'VAUPES' 'SAN ANDRES'
#  'GUAINIA' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'COLE_GENERO':
# ['FEMENINO' 'MIXTO' 'MASCULINO' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'COLE_JORNADA':
# ['COMPLETA' 'MAÑANA' 'SABATINA' 'NOCHE' 'TARDE' 'UNICA' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'COLE_MCPIO_UBICACION':
# ['BOGOTÁ D.C.' 'AIPE' 'CALARCÁ' ... 'BUSBANZA' 'PTO SANTANDER' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'COLE_NATURALEZA':
# ['NO OFICIAL' 'OFICIAL' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'COLE_NOMBRE_ESTABLECIMIENTO':
# ['GIMN FEMENINO' 'INSTITUCION EDUCATIVA JESUS MARIA AGUIRRE CHARRY'
#  'INSTITUCION EDUCATIVA ANTONIO NARIÑO' ...
#  'FUNDACION COLEGIO SAN JUAN DEL CAMINO'
#  'INSTITUTO DE EDUCACION COMFENALCO VALLE'
#  'COLEGIO DE EDUCACION BASICA SECUNDARIA Y MEDIA ACADEMICA PARA ADULTOS HEISENBERG']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'COLE_NOMBRE_SEDE':
# ['GIMN FEMENINO' 'DINDAL' 'ANTONIO NARIÑO' ...
#  'INSTITUTO DE EDUCACION COMFENALCO VALLE - SEDE PRINCIPAL'
#  'INSTITUTO BOLIVARIANO ESDISEÑOS DEL VALLE- SEDE PRINCIPAL'
#  'COLEGIO DE EDUCACION BASICA SECUNDARIA Y MEDIA ACADEMICA PARA ADULTOS HEISENBERG']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'COLE_SEDE_PRINCIPAL':
# ['S' 'N' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_DEPTO_PRESENTACION':
# ['BOGOTÁ' 'HUILA' 'QUINDIO' 'CAUCA' 'VALLE' 'TOLIMA' 'ANTIOQUIA'
#  'PUTUMAYO' 'SANTANDER' 'ATLANTICO' 'SUCRE' 'BOYACA' 'BOLIVAR' 'CESAR'
#  'MAGDALENA' 'NORTE SANTANDER' 'NARIÑO' 'CUNDINAMARCA' 'CALDAS' 'GUAVIARE'
#  'CASANARE' 'META' 'CHOCO' 'CORDOBA' 'RISARALDA' 'VICHADA' 'CAQUETA'
#  'LA GUAJIRA' 'ARAUCA' 'AMAZONAS' 'VAUPES' 'SAN ANDRES' 'GUAINIA' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_DEPTO_RESIDE':
# ['BOGOTÁ' 'HUILA' 'QUINDIO' 'CAUCA' 'VALLE' 'TOLIMA' 'ANTIOQUIA'
#  'PUTUMAYO' 'SANTANDER' 'ATLANTICO' 'SUCRE' 'BOYACA' 'BOLIVAR' 'CESAR'
#  'MAGDALENA' 'NORTE SANTANDER' 'NARIÑO' 'CUNDINAMARCA' nan 'CASANARE'
#  'META' 'CALDAS' 'CHOCO' 'CORDOBA' 'RISARALDA' 'VICHADA' 'CAQUETA'
#  'LA GUAJIRA' 'ARAUCA' 'AMAZONAS' 'GUAVIARE' 'SAN ANDRES' 'GUAINIA'
#  'VAUPES' 'EXTRANJERO']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_ESTUDIANTE':
# ['ESTUDIANTE']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_GENERO':
# ['F' 'M' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_MCPIO_PRESENTACION':
# ['BOGOTÁ D.C.' 'AIPE' 'CALARCÁ' 'POPAYÁN' 'LA PLATA' 'CALI' 'GUAMO'
#  'ITAGÜÍ' 'SIBUNDOY' 'BUCARAMANGA' 'BARRANQUILLA' 'ZARZAL' 'SINCELEJO'
#  'PUERTO BOYACÁ' 'TURBACO' 'VALLEDUPAR' 'SANTA ROSA DEL SUR' 'PLATO'
#  'JAMUNDÍ' 'MEDELLÍN' 'MOMPÓS' 'NEIVA' 'VILLA DEL ROSARIO' 'OVEJAS'
#  'YUMBO' 'PASTO' 'MALAMBO' 'CAMPO DE LA CRUZ' 'IPIALES'
#  'CARMEN DE APICALÁ' 'CÚCUTA' 'CHÍA' 'COPACABANA' 'LA DORADA'
#  'SAN JOSÉ DEL GUAVIARE' 'PAZ DE ARIPORO' 'SOLEDAD'
#  'SANTANDER DE QUILICHAO' 'VEGACHÍ' 'VILLAVICENCIO' 'BELLO' 'GIRÓN'
#  'LOS PATIOS' 'BARBOSA' 'ARBOLETES' 'RIOSUCIO' 'PALMIRA'
#  'PUERTO LEGUÍZAMO' 'SANTA MARTA' 'COROZAL' 'GUAMAL' 'EL COCUY' 'ENVIGADO'
#  'CONDOTO' 'SABANA DE TORRES' 'CAJICÁ' 'CIÉNAGA DE ORO' 'FUSAGASUGÁ'
#  'APARTADÓ' 'CARTAGO' 'MONTELÍBANO' 'SABANETA' 'LORICA'
#  'CARTAGENA DE INDIAS' 'PIEDECUESTA' 'BARBACOAS' 'ANDES' 'VILLA DE LEYVA'
#  'CANDELARIA' 'SAN GIL' 'LA UNIÓN' 'PUERTO LIBERTADOR' 'TULUÁ' 'GIRARDOT'
#  'IBAGUÉ' 'MÁLAGA' 'SAN JUAN NEPOMUCENO' 'BARRANCABERMEJA' 'SANTA ANA'
#  'LA VEGA' 'MARINILLA' 'SEGOVIA' 'SABANALARGA' 'DOSQUEBRADAS' 'SOACHA'
#  'CAUCASIA' 'MONTERÍA' 'FLORIDABLANCA' 'PLANETA RICA' 'CHARALÁ' 'ARJONA'
#  'ZIPAQUIRÁ' 'SOCHA' 'CHIRIGUANÁ' 'FACATATIVÁ' 'VÉLEZ' 'MOSQUERA'
#  'CUMARIBO' 'ACACÍAS' 'SAN JOSÉ DEL FRAGUA' 'GUADALAJARA DE BUGA'
#  'SAN LUIS DE PALENQUE' 'CIMITARRA' 'MONIQUIRÁ' 'EL BANCO' 'SANDONÁ'
#  'VIOTÁ' 'VILLETA' 'GUARNE' 'SAN ESTANISLAO' 'GUADUAS' 'VENTAQUEMADA'
#  'CAPARRAPÍ' 'PEREIRA' 'ESPINAL' 'LA JAGUA DE IBIRICO' 'SAN LUIS DE SINCÉ'
#  'GRANADA' 'ALCALÁ' 'EL CARMEN DE CHUCURÍ' 'TUNJA' 'EL CARMEN DE BOLÍVAR'
#  'TIERRALTA' 'RIOHACHA' 'LA TEBAIDA' 'SONSÓN' 'MANATÍ' 'AGUAZUL' 'ARAUCA'
#  'SAN AGUSTÍN' 'CERETÉ' 'CURUMANÍ' 'SAN ONOFRE' 'AMAGÁ' 'FUNDACIÓN'
#  'SANTA FÉ DE ANTIOQUIA' 'SAN ANDRÉS DE TUMACO' 'PUERTO ASÍS' 'PEÑOL'
#  'BARANOA' 'CALIMA' 'SANTA ROSA DE CABAL' 'SOGAMOSO' 'CÁCERES' 'MARSELLA'
#  'ROVIRA' 'VILLANUEVA' 'TÁMESIS' 'AGUACHICA' 'LETICIA' 'QUINCHÍA'
#  'SANTA ROSA DE OSOS' 'MAICAO' 'TENERIFE' 'ARIGUANÍ' 'RIONEGRO'
#  'CAICEDONIA' 'CISNEROS' 'EL COLEGIO' 'SAN VICENTE DE CHUCURÍ' 'CAREPA'
#  'YOPAL' 'SAN ALBERTO' 'EL COPEY' 'GARZÓN' 'MOCOA'
#  'SAN BERNARDO DEL VIENTO' 'TAURAMENA' 'EL CERRITO' 'SAHAGÚN' 'DABEIBA'
#  'TUTA' 'PUERTO WILCHES' 'QUIMBAYA' 'SAN PEDRO DE LOS MILAGROS' 'TURBO'
#  'SABANAGRANDE' 'QUIBDÓ' 'SEVILLA' 'PIVIJAY' 'MELGAR' 'SOCORRO' 'FONSECA'
#  'CAÑASGORDAS' 'OCAÑA' 'EL TAMBO' 'GACHETÁ' 'TAME' 'CHINCHINÁ' 'PATÍA'
#  'PUPIALES' 'NECOCLÍ' 'EL BAGRE' 'SAN ANDRÉS DE SOTAVENTO' 'EL PASO'
#  'ARMENIA' 'SAN PELAYO' 'FUNZA' 'DAGUA' 'CIÉNAGA' 'SALAMINA' 'BALBOA'
#  'FLORENCIA' 'EL DONCELLO' 'ANSERMA' 'VILLA DE SAN DIEGO DE UBATÉ'
#  'PRADERA' 'SAN JUAN DE RIOSECO' 'BOLÍVAR' 'MAGANGUÉ' 'MARÍA LA BAJA'
#  'ISTMINA' 'BUENAVENTURA' 'MIRANDA' 'MITÚ' 'SAN SEBASTIÁN DE MARIQUITA'
#  'AGUSTÍN CODAZZI' 'CHAPARRAL' 'SAN ANDRÉS' 'SARAVENA' 'MANIZALES'
#  'DUITAMA' 'ASTREA' 'SANTO TOMÁS' 'PAIPA' 'PURIFICACIÓN' 'CALAMAR'
#  'BUGALAGRANDE' 'MANAURE' 'LA CRUZ' 'PITALITO' 'INZÁ' 'MADRID' 'TOCAIMA'
#  'BOAVITA' 'EL PLAYÓN' 'TÚQUERRES' 'SAN JUAN DE URABÁ' 'GUATEQUE'
#  'SAN PEDRO' 'EL CARMEN DE VIBORAL' 'FRONTINO' 'CIRCASIA' 'CHINÚ'
#  'CORINTO' 'SAN JUAN DEL CESAR' 'PUERTO TEJADA' 'URIBIA' 'SAN ROQUE'
#  'CHIQUINQUIRÁ' 'PUERTO NARIÑO' 'BUESACO' 'VALLE DEL GUAMUEZ' 'SUCRE'
#  'LA PALMA' 'CUMARAL' 'TIBÚ' 'LA ESTRELLA' 'GARAGOA' 'MERCADERES'
#  'YARUMAL' 'CHOCONTÁ' 'ROLDANILLO' 'PUERTO LÓPEZ' 'EL RETORNO'
#  'CAMPOALEGRE' 'PINILLOS' 'LA CEJA' 'SAN MARCOS' 'SUÁREZ' 'ANDALUCÍA'
#  'SOATÁ' 'LÓPEZ DE MICAY' 'SAN PABLO' 'LÍBANO' 'PIENDAMÓ - TUNÍA' 'CALDAS'
#  'PUERTO GAITÁN' 'MANÍ' 'CIUDAD BOLÍVAR' 'MAJAGUAL' 'PUERTO BERRÍO'
#  'TAMALAMEQUE' 'LA CALERA' 'GINEBRA' 'PAUNA' 'RESTREPO' 'PUERTO CARREÑO'
#  'SANTIAGO DE TOLÚ' 'MARQUETALIA' 'SAN VICENTE DEL CAGUÁN' 'ITUANGO'
#  'CUMBAL' 'EL PAUJÍL' 'LA MESA' 'ALBÁN' 'SAN BENITO ABAD'
#  'SANTA ROSA DE VITERBO' 'CHINÁCOTA' 'SILVIA' 'TOLÚ VIEJO' 'SAMANIEGO'
#  'ACHÍ' 'CHIGORODÓ' 'APÍA' 'AGUADAS' 'TAMINANGO' 'ABEJORRAL' 'TURMEQUÉ'
#  'PIJAO' 'PACHO' 'DONMATÍAS' 'PELAYA' 'ORITO' 'SIMITÍ' 'ARBOLEDAS'
#  'RÍO VIEJO' 'EL CAIRO' 'BARRANCO MINAS' 'CALOTO' 'CÁQUEZA' 'GUACHUCAL'
#  'LÉRIDA' 'SARDINATA' 'CONVENCIÓN' 'ARAUQUITA' 'EL ÁGUILA' 'SIBATÉ'
#  'PLANADAS' 'SAN MARTÍN' 'TIMANÁ' 'BELÉN DE UMBRÍA' 'LA PAZ' 'TOLEDO'
#  'EL CHARCO' 'ALTO BAUDÓ' 'GUAPÍ' 'SANTA BÁRBARA' 'TADÓ' 'CHIMICHAGUA'
#  'ISNOS' 'VILLAGARZÓN' 'VENADILLO' 'BAGADÓ' 'AYAPEL' 'JERICÓ'
#  'LA VIRGINIA' 'SUBACHOQUE' 'BOSCONIA' 'ATRATO' 'PAMPLONA'
#  'VIGÍA DEL FUERTE' 'MONTERREY' 'ANSERMANUEVO' 'AMALFI' 'CAJAMARCA'
#  'TRUJILLO' 'SAN MARTÍN DE LOBA' 'URRAO' 'CARTAGENA DEL CHAIRÁ' 'BECERRIL'
#  'COYAIMA' 'FLORIDA' 'PALERMO' 'CONTRATACIÓN' 'LA TOLA' 'BAJO BAUDÓ'
#  'SITIONUEVO' 'LA PRIMAVERA' 'ZARAGOZA' 'REMEDIOS' 'HONDA' 'MUTATÁ'
#  'ANOLAIMA' 'PUERTO RICO' 'RICAURTE' 'SAN LUIS DE GACENO' 'DOLORES'
#  'UNGUÍA' 'NEIRA' 'SAMANÁ' 'SAN PEDRO DE URABÁ' 'MOGOTES' 'PENSILVANIA'
#  'SAN JACINTO' 'PÁEZ' 'ARACATACA' 'MIRAFLORES' 'EL CARMEN DE ATRATO'
#  'SAMACÁ' 'SAN CARLOS' 'TORO' 'TIMBIQUÍ' 'PÁCORA' 'NOCAIMA' 'BELALCÁZAR'
#  'OTANCHE' 'LA MACARENA' 'NÓVITA' 'SANTA MARÍA' 'ICONONZO' 'PEQUE'
#  'REPELÓN' 'NECHÍ' 'CONSACÁ' 'SAN SEBASTIÁN' 'CÁCHIRA' 'ACANDÍ'
#  'VALPARAÍSO' 'GALERAS' 'OROCUÉ' 'BAHÍA SOLANO' 'PUERTO TRIUNFO' 'GIGANTE'
#  'YOLOMBÓ' 'FALAN' 'ALBANIA' 'RÍO QUITO' 'MONTENEGRO' 'FRANCISCO PIZARRO'
#  'NATAGAIMA' 'CAPITANEJO' 'SANTUARIO' 'OLAYA HERRERA' 'YAVARATÉ' 'TANGUA'
#  'ZAPATOCA' 'TARAPACÁ' 'CHITA' 'LEIVA' 'SAN SEBASTIÁN DE BUENAVISTA'
#  'ARBELÁEZ' 'MORALES' 'BOJAYÁ' 'RÍO IRÓ' 'BARRANCO DE LOBA' 'CARURÚ'
#  'FRESNO' 'PROVIDENCIA' 'ÁBREGO' 'INÍRIDA' 'MOÑITOS' 'LA CHORRERA'
#  'COVEÑAS' 'EL CANTÓN DEL SAN PABLO' 'SALAZAR' 'NUQUÍ' 'SANTA ROSALÍA'
#  'MUZO' 'GUACARÍ' 'NUNCHÍA' 'PEDRAZA' 'GÜICÁN DE LA SIERRA' 'GACHALÁ'
#  'TÁMARA' 'SANTO DOMINGO' 'SOPETRÁN' 'BUENOS AIRES' 'RIVERA' 'ARENAL'
#  'MEDIO BAUDÓ' 'RAMIRIQUÍ' 'LA GLORIA' 'MAGÜÍ' 'EL ENCANTO'
#  'CARMEN DEL DARIÉN' 'LA PEDRERA' 'LLORÓ' 'SAN JOSÉ DEL PALMAR'
#  'GÓMEZ PLATA' 'GIRARDOTA' 'MIRITÍ - PARANÁ' 'JURADÓ' 'VALENCIA' 'MATANZA'
#  nan 'TARAIRA' 'PANA PANA' 'MORICHAL' 'PACOA' 'MAPIRIPÁN' 'MESETAS'
#  'MAPIRIPANA' 'ANORÍ' 'URIBE' 'PUERTO SANTANDER' 'FÓMEQUE'
#  'MEDIO SAN JUAN' 'CHIVOLO' 'LEJANÍAS' 'MACEO' 'LA ARGENTINA'
#  'ZONA BANANERA' 'PUERTO GUZMÁN' 'CÓMBITA' 'ALMAGUER' 'URUMITA'
#  'SAN FELIPE' 'ANAPOIMA' 'MANZANARES' 'SIMIJACA' 'DIBULLA' 'MEDINA' 'UNE'
#  'LEBRIJA' 'SILVANIA']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_MCPIO_RESIDE':
# ['BOGOTÁ D.C.' 'AIPE' 'CALARCÁ' ... 'LA GUADALUPE' 'PUERTO ALEGRÍA'
#  'CACAHUAL']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_NACIONALIDAD':
# ['COLOMBIA' 'ESTADOS UNIDOS' 'VENEZUELA' 'ARGELIA' 'ECUADOR' 'ESPAÑA'
#  'COREA DEL SUR' 'BRASIL' 'COMORAS' 'PERÚ' 'REINO UNIDO' 'MÉXICO'
#  'BOLIVIA' 'DINAMARCA' 'BELICE' 'ANGOLA' 'TAIWAN' 'ITALIA' 'AUSTRIA'
#  'ARGENTINA' 'CHILE' 'COREA DEL NORTE' 'TERRITORIOS PALESTINOS' 'JAPÓN'
#  'GUATEMALA' 'ALEMANIA' 'COSTA RICA' 'COSTA DE MARFIL' 'ALAND'
#  'REPÚBLICA DOMINICANA' 'CHAD' 'CHINA' 'PUERTO RICO' 'CANADÁ' 'ANTÁRTIDA'
#  'HONDURAS' 'CUBA' 'OMÁN' 'PANAMÁ' 'RUSIA' 'CABO VERDE' 'LÍBANO' 'FRANCIA'
#  'CROACIA' 'PAÍSES BAJOS - HOLANDA' 'ARMENIA' 'NAMIBIA' 'CURAZAO' 'SUIZA'
#  'PARAGUAY' 'ZIMBABUE' 'BULGARIA' 'NICARAGUA' 'CIUDAD DEL VATICANO' 'IRÁN'
#  'AFGANISTÁN' 'PORTUGAL' 'ANDORRA' 'ISLAS SALOMÓN' 'LITUANIA' 'URUGUAY'
#  'BÉLGICA' 'LAOS - REPÚBLICA DEMOCRÁTICA POPULAR LAO' 'NORUEGA'
#  'AUSTRALIA' 'EL SALVADOR' 'ALBANIA' 'BRUNÉI' 'ISRAEL' 'SUDÁFRICA' 'INDIA'
#  'BONAIRE' 'BURUNDI' 'ARABIA SAUDITA' 'FILIPINAS' 'ARUBA' 'SUECIA'
#  'UCRANIA' 'BIELORRUSIA' 'VANUATU' 'GUADALUPE' 'NAURU' 'TURQUÍA'
#  'EMIRATOS ÁRABES UNIDOS' 'DOMINICA' 'ETIOPÍA' 'LETONIA' 'SENEGAL'
#  'JORDANIA' 'WALLIS Y FUTUNA' 'VIETNAM']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_PAIS_RESIDE':
# ['COLOMBIA' 'ESTADOS UNIDOS' 'VENEZUELA' 'ARGELIA' 'ECUADOR' 'ESPAÑA'
#  'COREA DEL SUR' 'BRASIL' 'COMORAS' 'PERÚ' 'REINO UNIDO' 'MÉXICO'
#  'BOLIVIA' 'DINAMARCA' 'BELICE' 'ANGOLA' 'TAIWAN' 'ITALIA' 'AUSTRIA'
#  'ARGENTINA' 'CHILE' 'COREA DEL NORTE' 'TERRITORIOS PALESTINOS' 'JAPÓN'
#  'GUATEMALA' 'ALEMANIA' 'COSTA RICA' 'COSTA DE MARFIL' 'ALAND'
#  'REPÚBLICA DOMINICANA' 'CHAD' 'CHINA' 'PUERTO RICO' 'CANADÁ' 'ANTÁRTIDA'
#  'HONDURAS' 'CUBA' 'OMÁN' 'PANAMÁ' 'RUSIA' 'CABO VERDE' 'LÍBANO' 'FRANCIA'
#  'CROACIA' 'PAÍSES BAJOS - HOLANDA' 'ARMENIA' 'NAMIBIA' 'CURAZAO' 'SUIZA'
#  'PARAGUAY' 'ZIMBABUE' 'BULGARIA' 'NICARAGUA' 'CIUDAD DEL VATICANO' 'IRÁN'
#  'AFGANISTÁN' 'PORTUGAL' 'ANDORRA' 'ISLAS SALOMÓN' 'LITUANIA' 'URUGUAY'
#  'BÉLGICA' 'LAOS - REPÚBLICA DEMOCRÁTICA POPULAR LAO' 'NORUEGA'
#  'AUSTRALIA' 'EL SALVADOR' 'ALBANIA' 'BRUNÉI' 'ISRAEL' 'SUDÁFRICA' 'INDIA'
#  'BONAIRE' 'BURUNDI' 'ARABIA SAUDITA' 'FILIPINAS' 'ARUBA' 'SUECIA'
#  'UCRANIA' 'BIELORRUSIA' 'VANUATU' 'GUADALUPE' 'NAURU' 'TURQUÍA'
#  'EMIRATOS ÁRABES UNIDOS' 'DOMINICA' 'ETIOPÍA' 'LETONIA' 'SENEGAL'
#  'JORDANIA' 'WALLIS Y FUTUNA' 'VIETNAM']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_PRIVADO_LIBERTAD':
# ['N' 'S']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'FAMI_CUARTOSHOGAR':
# ['Cuatro' 'Dos' 'Cinco' 'Tres' 'Uno' 'Seis' 'Diez o más' 'Ocho' nan
#  'Seis o mas' 'Siete' 'Nueve']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'FAMI_EDUCACIONMADRE':
# ['Educación profesional completa' 'Postgrado'
#  'Secundaria (Bachillerato) incompleta' 'Primaria incompleta' 'Ninguno'
#  'Educación profesional incompleta' 'Secundaria (Bachillerato) completa'
#  'Primaria completa' 'Técnica o tecnológica completa' 'No sabe'
#  'Técnica o tecnológica incompleta' nan 'No Aplica']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'FAMI_EDUCACIONPADRE':
# ['Educación profesional completa' 'Primaria completa' 'No sabe'
#  'Educación profesional incompleta' 'Primaria incompleta'
#  'Secundaria (Bachillerato) completa' 'Técnica o tecnológica completa'
#  'Postgrado' 'Ninguno' 'Secundaria (Bachillerato) incompleta' nan
#  'Técnica o tecnológica incompleta' 'No Aplica']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'FAMI_ESTRATOVIVIENDA':
# ['Estrato 6' 'Estrato 2' 'Estrato 1' 'Estrato 5' 'Estrato 3' 'Estrato 4'
#  nan 'Sin Estrato'
#  'Vive en una zona rural donde no hay estratificación socioeconómica']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'FAMI_PERSONASHOGAR':
# ['Cuatro' '1 a 2' 'Ocho' '5 a 6' 'Cinco' 'Tres' '3 a 4' 'Siete' 'Nueve'
#  'Dos' 'Diez' 'Seis' '7 a 8' 'Doce o más' 'Once' '9 o más' 'Una' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'FAMI_TIENEAUTOMOVIL':
# ['Si' 'No' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'FAMI_TIENECOMPUTADOR':
# ['Si' 'No' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'FAMI_TIENEINTERNET':
# ['Si' 'No' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'FAMI_TIENELAVADORA':
# ['Si' 'No' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'DESEMP_INGLES':
# ['B+' 'B1' 'A1' 'A-' 'A2' nan '-1']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'PUNT_INGLES':
# [94.0 71.0 48.0 43.0 46.0 59.0 33.0 44.0 49.66 42.0 61.0 40.0 52.0 31.0
#  41.66 79.55 50.0 47.0 37.0 56.0 32.0 38.0 75.0 39.0 40.14 30.0 68.0 36.0
#  60.0 44.51 63.0 53.0 41.0 45.0 65.0 45.84 35.0 52.08 49.0 54.0 62.0 57.0
#  55.0 51.0 58.0 80.0 91.0 81.0 48.42 77.0 26.0 36.8 34.0 51.33 64.24 43.53
#  70.0 36.06 44.92 43.48 66.03 47.58 67.0 43.11 69.0 66.0 50.1 78.0 58.47
#  60.44 40.54 48.86 58.59 79.0 55.62 46.27 90.0 54.45 56.09 59.9 92.0 56.82
#  53.73 52.54 38.53 29.0 83.0 27.0 32.9 73.0 47.15 79.4 45.63 14.0 59.67
#  62.94 44.93 64.0 73.68 50.87 37.19 74.0 38.78 60.9 23.0 34.94 81.98 76.0
#  61.66 87.0 61.22 30.95 46.71 64.7 93.0 67.41 28.64 -1.0 42.07 89.0 66.95
#  73.24 91.71 72.0 62.69 82.38 57.29 85.0 65.57 68.86 45.94 63.4 83.41 82.0
#  53.27 7.44 69.92 86.0 38.92 94.05 28.0 100.0 75.1 84.0 33.81 102.61 75.52
#  85.05 67.51 38.08 25.0 69.93 95.0 70.37 20.0 88.0 41.61 54.92 58.01 51.01
#  68.41 24.0 42.76 50.66 41.43 71.98 28.32 35.25 97.0 55.95 49.22 54.64
#  59.21 77.55 77.13 74.73 69.01 47.79 30.61 73.93 nan 71.53 62.13 79.81
#  89.24 39.87 57.27 40.28 19.0 46.35 88.85 0.0 31.34 70.18 52.09 35.31 37.1
#  87.56 44.56 33.22 33.25 77.68 22.0 102.96 25.22 47.17 31.02 77.44 95.85
#  53.32 25.71 77.14 65.1 17.0 116.95 26.09 72.06 85.44 72.32 75.34 66.91
#  44.71 50.86 48.4 94.41 96.0 23.36 75.8 68.31 3.0 73.23 49.63 99.0 117.29
#  21.0 66.44 11.0 9.0 7.0 20.46 10.0 22.55 24.9 27.99 17.39 15.0 49.94
#  15.55 64.8 71.12 64.56 19.16 11.71 6.0 21.34 14.14 98.0 21.05 15.82 3.34
#  16.08 10.71 '51' '32' '47' '52' '41' '60' '49' '46' '42' '39' '53.27'
#  '38' '79' '50' '58' '54' '68' '43' '71' '53' '76' '83' '36' '37' '46.27'
#  '40' '45' '48' '57' '61' '55' '64' '35' '23' '47.58' '56.82' '65' '34'
#  '75.1' '73' '56' '80' '62' '59' '72' '68.41' '44' '49.66' '36.8' '69'
#  '43.11' '44.51' '51.33' '31' '75' '41.61' '74' '70' '30' '55.62' '85'
#  '88' '42.07' '63' '48.86' '43.53' '33' '40.14' '67' '40.54' '77' '19'
#  '66' '49.63' '41.66' '48.42' '38.08' '97' '93' '81' '50.87' '22' '27'
#  '45.84' '58.01' '78' '29' '86' '50.1' '57.29' '52.08' '20' '54.45'
#  '73.24' '82' '100' '59.67' '26' '9' '53.73' '24' '31.02' '59.21' '28.64'
#  '52.54' '64.24' '65.57' '47.15' '62.94' '87' '44.93' '60.44' '25' '77.55'
#  '94' '28' '40.28' '38.53' '52.09' '95' '72.32' '87.56' '89' '74.73'
#  '82.38' '94.41' '79.55' '64.56' '75.52' '33.25' '60.9' '44.71' '44.92'
#  '73.68' '102.96' '90' '47.79' '42.76' '79.4' '102.61' '38.92' '62.13'
#  '66.03' '58.47' '88.85' '56.09' '81.98' '37.1' '94.05' '61.66' '37.19'
#  '67.51' '71.98' '30.95' '92' '45.63' '33.22' '14' '54.92' '36.06' '64.7'
#  '41.43' '54.64' '68.86' '58.59' '39.87' '43.48' '33.81' '72.06' '77.13'
#  '66.44' '96' '-1' '68.31' '83.41' '35.25' '26.09' '66.95' '49.22' '35.31'
#  '38.78' '71.53' '30.61' '47.17' '91' '0' '34.94' '62.69' '91.71' '59.9'
#  '84' '57.27' '46.35' '69.93' '53.32' '48.4' '116.95' '55.95' '79.81'
#  '21.34' '85.44' '50.66' '31.34' '32.9' '73.93' '63.4' '69.92' '25.71'
#  '67.41' '61.22' '3.34' '28.32' '45.94' '70.37' '89.24' '21.05' '95.85'
#  '71.12' '50.86' '77.14' '51.01' '73.23' '85.05' '117.29' '70.18' '17'
#  '44.56' '3' '21' '15.82' '66.91' '77.44' '65.1' '75.8' '49.94' '7' '64.8'
#  '69.01' '27.99' '77.68' '46.71' '11' '75.34' '20.46' '98' '36,44' '22.55'
#  '23.36' 18.0 7.21 16.0 '25.22' '15' '99' '10' 13.0 '24.9' '43,48' '17.39'
#  '6' '18' '19.16' 7.64 '42,76' '15.55']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'PUNT_MATEMATICAS':
# [88.0 66.0 45.0 52.0 43.0 57.0 34.0 53.0 48.17 64.0 46.0 45.38 60.14 49.0
#  56.0 71.0 47.0 44.0 39.12 59.0 58.0 38.0 23.0 53.37 55.0 51.0 35.0 72.0
#  67.0 53.16 30.0 63.0 65.63 65.0 60.0 42.0 50.0 48.0 61.0 55.62 55.89 31.0
#  41.0 32.0 70.0 39.25 39.0 79.0 62.0 37.0 40.0 28.0 24.0 58.38 69.0 69.01
#  42.46 54.0 52.39 74.0 40.93 35.59 49.52 33.0 58.05 27.0 25.0 68.0 83.0
#  36.0 22.0 59.94 73.0 60.91 42.4 49.57 100.0 48.09 29.0 75.0 60.51 85.0
#  38.84 75.41 50.82 25.02 40.78 26.0 35.39 80.0 81.0 29.11 50.67 76.0 78.0
#  62.92 28.78 41.51 71.35 20.0 66.17 57.11 63.02 72.36 25.39 59.93 30.9
#  49.55 68.39 44.39 69.12 63.5 46.84 72.05 82.0 21.0 19.0 77.0 31.19 43.99
#  52.11 78.36 57.29 41.82 47.01 16.0 84.0 52.17 74.62 79.26 16.12 57.27
#  88.79 37.56 57.34 38.64 18.0 87.0 44.69 54.77 6.0 47.3 90.0 38.94 89.0
#  72.53 0.0 54.67 87.21 92.0 12.0 32.42 86.0 62.72 35.84 47.19 43.88 32.15
#  41.69 13.0 62.48 23.97 15.67 59.86 52.32 46.77 54.74 89.92 7.0 60.2 28.52
#  68.62 87.15 17.0 46.86 44.55 11.0 65.27 37.36 95.0 91.0 33.46 62.98 8.26
#  87.14 28.27 49.43 62.53 33.72 23.04 96.0 97.0 87.76 83.87 51.97 97.02
#  68.03 54.52 99.0 28.58 76.53 5.0 82.87 93.0 76.37 35.55 39.16 81.47 99.48
#  81.17 32.75 36.11 49.85 124.0 65.86 65.93 72.11 57.53 65.67 49.77 65.46
#  69.03 62.56 81.33 23.84 113.27 68.85 15.0 65.19 102.0 71.12 71.05 68.11
#  77.98 76.1 44.23 101.0 98.19 113.48 57.47 108.0 28.91 87.43 76.65 35.78
#  54.94 8.0 74.33 3.0 72.63 126.0 74.38 23.61 54.88 12.92 94.0 59.77 123.0
#  97.31 82.15 98.0 116.0 22.65 112.99 113.46 117.0 107.0 127.0 97.66 106.0
#  105.0 80.88 10.0 24.3 1.0 114.88 115.0 7.95 109.0 17.7 82.16 97.5 103.94
#  7.78 87.61 9.0 13.38 125.0 17.91 93.69 103.0 113.64 114.0 2.0 18.23 17.5
#  93.8 '58' '34' '54' '45' '47' '64' '33' '42' '55.62' '59' '53' '38' '57'
#  '37' '89' '71' '55' '61' '69' '24' '41' '42.46' '50' '28' '68' '60' '63'
#  '44' '36' '49' '27' '39' '66' '52' '46' '58.38' '50.67' '48' '70' '72'
#  '23' '66.17' '56' '35' '16' '43' '31' '58.05' '76' '42.4' '39.12' '30'
#  '67' '45.38' '53.37' '32' '40' '46.84' '1' '51' '25' '22' '48.09' '75'
#  '55.89' '65' '60.51' '29' '35.39' '82' '48.17' '63.5' '52.32' '74' '62'
#  '78' '39.16' '98' '53.16' '84' '50.82' '85' '6' '39.25' '80' '72.05'
#  '30.9' '71.35' '73' '63.02' '81' '60.91' '13' '100' '31.19' '90' '65.63'
#  '21' '40.93' '82.87' '49.43' '77' '26' '35.59' '49.52' '20' '44.23'
#  '69.01' '57.34' '82.15' '57.29' '32.42' '79' '62.98' '12' '72.36' '32.75'
#  '43.88' '87' '83.87' '7' '86' '25.02' '46.77' '74.62' '113.46' '78.36'
#  '18' '33.46' '54.52' '22.65' '40.78' '91' '35.84' '79.26' '68.39' '87.14'
#  '99' '83' '38.64' '59.86' '98.19' '54.67' '28.58' '59.93' '19' '41.51'
#  '57.11' '65.67' '114.88' '75.41' '54.74' '59.94' '43.99' '62.72' '62.92'
#  '49.55' '52.17' '59.77' '11' '92' '16.12' '35.55' '28.78' '37.56' '72.11'
#  '37.36' '60.2' '65.93' '49.85' '97' '57.47' '41.69' '93' '51.97' '57.53'
#  '71.05' '108' '17' '47.01' '49.77' '38.84' '96' '68.85' '54.77' '0'
#  '46.86' '28.27' '15' '62.48' '44.69' '88' '69.12' '5' '68.03' '25.39'
#  '35.78' '65.46' '47.3' '62.56' '65.19' '60.14' '76.37' '101' '41.82'
#  '69.03' '81.47' '38.94' '81.33' '88.79' '62.53' '7.78' '44.39' '52.11'
#  '44.55' '76.1' '23.04' '65.27' '28.52' '65.86' '72.63' '49.57' '97.31'
#  '72.53' '68.11' '74.38' '95' '106' '24.3' '23.97' '54.88' '89.92' '87.43'
#  '80.88' '23.61' '54.94' '33.72' '8' '81.17' '52.39' '117' '8.26' '94'
#  '47.19' '76.53' '15.67' '29.11' '36.11' '105' '76.65' '17.5' '74.33'
#  '68.62' '112.99' '28.91' '123' '87.61' '87.76' '31,87' '32.15' '125'
#  '116' '102' '18.23' '9' '57.27' '23.84' '93.69' 120.23 8.57 104.09 122.0
#  '12.92' '87.21' '97.5' '77.98' '14' '97.66' '99.48' '109' '113.27'
#  '97.02' '35,2' '3' '71.12' '113.48' 120.39 '69,27' '104.09' '87.15' '127'
#  '107' '82.16' '115' '103' '2' '42,58' '93.8' '114']
#
# --------------------------------------------------

# %% [markdown]
# Las siguientes columnas: FAMI_EDUCACIONMADRE (nulos 205546), FAMI_EDUCACIONPADRE (nulos 205201), FAMI_ESTRATOVIVIENDA (nulos 210618) son muy relevantes para el proyecto, por los estudios que existen en relación a su efecto en la educación. Por lo anterior, se van a eliminar los valores nulos de estas columnas.

# %%
# Eliminar los registros con valores nulos en 'FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE' y 'FAMI_ESTRATOVIVIENDA'
df_Saber11.dropna(subset=['FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE', 'FAMI_ESTRATOVIVIENDA'], inplace=True)

# Verificar el número de registros después de eliminar los nulos
num_registros_saber11 = len(df_Saber11)
print(f"Número de registros en Saber11 después de eliminar nulos: {num_registros_saber11}")
# Out:
# Número de registros en Saber11 después de eliminar nulos: 6728965

# %%
df_SaberPro.dropna(subset=['FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE', 'FAMI_ESTRATOVIVIENDA'], inplace=True)
num_registros_SaberPro = len(df_SaberPro)
print(f"Número de registros en Saber11 después de eliminar nulos: {num_registros_SaberPro}")
# Out:
# Número de registros en Saber11 después de eliminar nulos: 1100345

# %%
# Se van a eliminar los valores nulos de las columnas que tienen pocos registros de nulos proporcionalmente.

# Lista de columnas con valores nulos a eliminar en Saber11
columnas_nulas_a_eliminar = [
    'COLE_AREA_UBICACION', 'COLE_CALENDARIO', 'COLE_COD_DANE_ESTABLECIMIENTO',
    'COLE_COD_DANE_SEDE', 'COLE_COD_DEPTO_UBICACION', 'COLE_COD_MCPIO_UBICACION',
    'COLE_DEPTO_UBICACION', 'COLE_GENERO', 'COLE_JORNADA', 'COLE_MCPIO_UBICACION',
    'COLE_NATURALEZA', 'COLE_NOMBRE_ESTABLECIMIENTO', 'COLE_NOMBRE_SEDE',
    'COLE_SEDE_PRINCIPAL', 'ESTU_COD_DEPTO_PRESENTACION', 'ESTU_COD_MCPIO_PRESENTACION',
    'ESTU_DEPTO_PRESENTACION', 'ESTU_GENERO', 'ESTU_MCPIO_PRESENTACION'
]

# Eliminar registros con valores nulos en las columnas especificadas
df_Saber11.dropna(subset=columnas_nulas_a_eliminar, inplace=True)

# Verificar el número total de registros después de la eliminación
num_registros_saber11 = len(df_Saber11)
print(f"Número de registros en Saber11 después de eliminar nulos: {num_registros_saber11}")
# Out:
# Número de registros en Saber11 después de eliminar nulos: 6721922

# %% [markdown]
# Hay dos variables que tienen un número significativo de nulos: FAMI_TIENECOMPUTADOR 146573 FAMI_TIENEINTERNET 184136 El manejo más adecuado para estas dos columnas es asignarles el valor de 'Si' o de 'No', de manera aleatoria en una proporción igual a los datos que tengan ese estrato en los estudiantes que tienen un valor válido ('Si', 'No').

# %%
import numpy as np
# Función para imputar valores nulos según la proporción en un grupo específico
def imputar_por_proporcion(df, columna_imputar, columna_grupo):
    for grupo, sub_df in df.groupby(columna_grupo):
        # Calcular las proporciones de 'Si' y 'No' para el grupo actual
        proporciones = sub_df[columna_imputar].value_counts(normalize=True)
        prob_si = proporciones.get('Si', 0)
        prob_no = proporciones.get('No', 0)
        
        # Imputar valores nulos en la columna de interés según las proporciones del grupo
        mask = (df[columna_grupo] == grupo) & (df[columna_imputar].isna())
        df.loc[mask, columna_imputar] = np.random.choice(
            ['Si', 'No'],
            size=mask.sum(),
            p=[prob_si, prob_no]
        )

# Imputar FAMI_TIENECOMPUTADOR según FAMI_ESTRATOVIVIENDA
imputar_por_proporcion(df_Saber11, 'FAMI_TIENECOMPUTADOR', 'FAMI_ESTRATOVIVIENDA')

# Imputar FAMI_TIENEINTERNET según FAMI_ESTRATOVIVIENDA
imputar_por_proporcion(df_Saber11, 'FAMI_TIENEINTERNET', 'FAMI_ESTRATOVIVIENDA')

# Verificar los resultados
print(df_Saber11[['FAMI_ESTRATOVIVIENDA', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET']].head())
# Out:
#   FAMI_ESTRATOVIVIENDA FAMI_TIENECOMPUTADOR FAMI_TIENEINTERNET
# 0            Estrato 6                   Si                 Si
# 1            Estrato 2                   Si                 Si
# 2            Estrato 2                   Si                 Si
# 3            Estrato 1                   Si                 Si
# 4            Estrato 2                   Si                 Si

# %%
imputar_por_proporcion(df_SaberPro, 'FAMI_TIENECOMPUTADOR', 'FAMI_ESTRATOVIVIENDA')

# Imputar FAMI_TIENEINTERNET según FAMI_ESTRATOVIVIENDA
imputar_por_proporcion(df_SaberPro, 'FAMI_TIENEINTERNET', 'FAMI_ESTRATOVIVIENDA')
print(df_SaberPro[['FAMI_ESTRATOVIVIENDA', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET']].head())
# Out:
#   FAMI_ESTRATOVIVIENDA FAMI_TIENECOMPUTADOR FAMI_TIENEINTERNET
# 0            Estrato 2                   Si                 Si
# 1            Estrato 2                   Si                 Si
# 2            Estrato 2                   Si                 Si
# 3            Estrato 2                   Si                 Si
# 4            Estrato 3                   Si                 Si

# %%
imputar_por_proporcion(df_Saber11, 'FAMI_TIENEAUTOMOVIL', 'FAMI_ESTRATOVIVIENDA')
imputar_por_proporcion(df_SaberPro, 'FAMI_TIENEAUTOMOVIL', 'FAMI_ESTRATOVIVIENDA')
imputar_por_proporcion(df_Saber11, 'FAMI_TIENELAVADORA', 'FAMI_ESTRATOVIVIENDA')
imputar_por_proporcion(df_SaberPro, 'FAMI_TIENELAVADORA', 'FAMI_ESTRATOVIVIENDA')

# %%
# Filtrar los registros con puntajes nulos en todas las materias y en el puntaje global
df_nulos_puntajes = df_Saber11[
    df_Saber11[['PUNT_SOCIALES_CIUDADANAS', 'PUNT_C_NATURALES', 'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL']].isnull().all(axis=1)
]

# 1. Verificar los años de los registros con puntajes nulos
conteo_por_año_nulos = df_nulos_puntajes['AÑO'].value_counts().sort_index()
print("Distribución de registros con puntajes nulos por año:")
print(conteo_por_año_nulos)

# 2. Examinar la ubicación geográfica de los registros nulos
# Contar por departamento de presentación
conteo_por_departamento = df_nulos_puntajes['ESTU_DEPTO_PRESENTACION'].value_counts()
print("\nDistribución de registros con puntajes nulos por departamento de presentación:")
print(conteo_por_departamento)

# Contar por municipio de presentación
conteo_por_municipio = df_nulos_puntajes['ESTU_MCPIO_PRESENTACION'].value_counts()
print("\nDistribución de registros con puntajes nulos por municipio de presentación:")
print(conteo_por_municipio)

# 3. Revisar otras características de los registros nulos
# Ver distribución por estrato socioeconómico
conteo_por_estrato = df_nulos_puntajes['FAMI_ESTRATOVIVIENDA'].value_counts(dropna=False)
print("\nDistribución de registros con puntajes nulos por estrato socioeconómico:")
print(conteo_por_estrato)

# Ver distribución por naturaleza del colegio (público, privado, etc.)
conteo_por_naturaleza = df_nulos_puntajes['COLE_NATURALEZA'].value_counts(dropna=False)
print("\nDistribución de registros con puntajes nulos por naturaleza del colegio:")
print(conteo_por_naturaleza)

# Ver distribución por área de ubicación del colegio (urbano, rural)
conteo_por_area_ubicacion = df_nulos_puntajes['COLE_AREA_UBICACION'].value_counts(dropna=False)
print("\nDistribución de registros con puntajes nulos por área de ubicación del colegio:")
print(conteo_por_area_ubicacion)

# 4. Comparar con registros completos
# Filtrar los registros con puntajes completos en todas las materias y en el puntaje global
df_completos_puntajes = df_Saber11[
    df_Saber11[['PUNT_SOCIALES_CIUDADANAS', 'PUNT_C_NATURALES', 'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL']].notnull().all(axis=1)
]

# Verificar distribución por año en registros completos
conteo_por_año_completos = df_completos_puntajes['AÑO'].value_counts().sort_index()
print("\nDistribución de registros con puntajes completos por año:")
print(conteo_por_año_completos)

# Verificar distribución por estrato socioeconómico en registros completos
conteo_por_estrato_completos = df_completos_puntajes['FAMI_ESTRATOVIVIENDA'].value_counts(dropna=False)
print("\nDistribución de registros con puntajes completos por estrato socioeconómico:")
print(conteo_por_estrato_completos)

# Verificar distribución por naturaleza del colegio en registros completos
conteo_por_naturaleza_completos = df_completos_puntajes['COLE_NATURALEZA'].value_counts(dropna=False)
print("\nDistribución de registros con puntajes completos por naturaleza del colegio:")
print(conteo_por_naturaleza_completos)
# Out:
# Distribución de registros con puntajes nulos por año:
# AÑO
# 2010    628780
# 2011    611902
# 2012    628241
# 2013    567106
# 2014     23851
# Name: count, dtype: int64
#
# Distribución de registros con puntajes nulos por departamento de presentación:
# ESTU_DEPTO_PRESENTACION
# BOGOTÁ             399117
# ANTIOQUIA          388661
# VALLE              239812
# CUNDINAMARCA       153198
# ATLANTICO          138600
# SANTANDER          126880
# BOLIVAR             94460
# BOYACA              77723
# CORDOBA             76635
# NARIÑO              76304
# TOLIMA              67886
# NORTE SANTANDER     64956
# HUILA               60462
# MAGDALENA           56115
# CAUCA               52826
# CALDAS              48894
# META                47975
# CESAR               47139
# RISARALDA           43373
# SUCRE               42555
# LA GUAJIRA          27586
# QUINDIO             27094
# CASANARE            26520
# CHOCO               15734
# ARAUCA              15660
# CAQUETA             15546
# PUTUMAYO            15002
# GUAVIARE             3723
# SAN ANDRES           3132
# AMAZONAS             2797
# VICHADA              1732
# VAUPES               1086
# GUAINIA               697
# Name: count, dtype: int64
#
# Distribución de registros con puntajes nulos por municipio de presentación:
# ESTU_MCPIO_PRESENTACION
# BOGOTÁ D.C.            399117
# MEDELLÍN               205076
# CALI                   146604
# BARRANQUILLA            94638
# CARTAGENA DE INDIAS     57211
#                         ...
# CARURÚ                     79
# TARAPACÁ                   68
# YAVARATÉ                   52
# TARAIRA                    52
# JURADÓ                     50
# Name: count, Length: 438, dtype: int64
#
# Distribución de registros con puntajes nulos por estrato socioeconómico:
# FAMI_ESTRATOVIVIENDA
# Estrato 1                                                             926443
# Estrato 2                                                             879323
# Estrato 3                                                             476580
# Estrato 4                                                             107186
# Estrato 5                                                              44159
# Estrato 6                                                              26188
# Vive en una zona rural donde no hay estratificación socioeconómica         1
# Name: count, dtype: int64
#
# Distribución de registros con puntajes nulos por naturaleza del colegio:
# COLE_NATURALEZA
# OFICIAL       1737548
# NO OFICIAL     722332
# Name: count, dtype: int64
#
# Distribución de registros con puntajes nulos por área de ubicación del colegio:
# COLE_AREA_UBICACION
# URBANO    2160631
# RURAL      299249
# Name: count, dtype: int64
#
# Distribución de registros con puntajes completos por año:
# AÑO
# 2014     533743
# 2015     558359
# 2016     554424
# 2017     527066
# 2018      29977
# 2019    1029040
# 2020      10312
# 2021      13178
# 2022    1005943
# Name: count, dtype: int64
#
# Distribución de registros con puntajes completos por estrato socioeconómico:
# FAMI_ESTRATOVIVIENDA
# Estrato 1      1500973
# Estrato 2      1494640
# Estrato 3       840940
# Estrato 4       211043
# Sin Estrato      88166
# Estrato 5        79260
# Estrato 6        47020
# Name: count, dtype: int64
#
# Distribución de registros con puntajes completos por naturaleza del colegio:
# COLE_NATURALEZA
# OFICIAL       3137750
# NO OFICIAL    1124292
# Name: count, dtype: int64

# %% [markdown]
# El principal hallazgo es que los registros con puntajes nulos están concentrados en los primeros años: Distribución de registros con puntajes nulos por año: 2010 628765 2011 611890 2012 628071 2013 566869 2014 23765 Por ello, dado que son variables imprescindibles para el modelo, eliminar estos registros es razonable y justificado, especialmente porque se concentran en los primeros años y representan una porción significativa de datos que, además, carecen de información esencial para el modelo. No eliminarlos va a influir en la calidad del modelo, dado que las variables de puntajes en diferentes áreas (como matemáticas, ciencias naturales, y lectura crítica) son cruciales para este modelo predictivo que está centrado en rendimiento académico.
#
# La opción es que exista una focalización en datos recientes, los cuales reflejan mejor las condiciones actuales y la tendencia educativa en Colombia, lo que permite desarrollar un modelo con una aplicabilidad práctica más alta. Finalmente, el tamaño de la muestra sigue siendo razonable, y debería ser suficientemente grande para construir un modelo robusto y confiable.

# %%
# Paso 1: Eliminar registros con valores nulos en las columnas de puntajes
columnas_puntajes = ['PUNT_SOCIALES_CIUDADANAS', 'PUNT_C_NATURALES', 'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL']
df_Saber11 = df_Saber11.dropna(subset=columnas_puntajes)

# Paso 2: Mostrar el número total de registros después de la eliminación
total_registros = len(df_Saber11)
print(f"Número total de registros después de eliminar puntajes nulos: {total_registros}")

# Paso 3: Contar y mostrar el número de registros por año
registros_por_año = df_Saber11['AÑO'].value_counts().sort_index()
print("\nNúmero de registros por año después de la eliminación:")
print(registros_por_año)
# Out:
# Número total de registros después de eliminar puntajes nulos: 4262042
#
# Número de registros por año después de la eliminación:
# AÑO
# 2014     533743
# 2015     558359
# 2016     554424
# 2017     527066
# 2018      29977
# 2019    1029040
# 2020      10312
# 2021      13178
# 2022    1005943
# Name: count, dtype: int64

# %%
# Verificar columnas con valores nulos en df_Saber11
columnas_nulas = df_Saber11.isnull().sum()

# Filtrar y mostrar solo las columnas con valores nulos mayores a cero
columnas_nulas = columnas_nulas[columnas_nulas > 0]

# Mostrar las columnas con valores nulos y sus respectivos conteos
print("Columnas con valores nulos y sus conteos:")
print(columnas_nulas)
# Out:
# Columnas con valores nulos y sus conteos:
# COLE_BILINGUE            624819
# COLE_CARACTER             85134
# ESTU_COD_RESIDE_DEPTO       978
# ESTU_COD_RESIDE_MCPIO       978
# ESTU_DEPTO_RESIDE           978
# ESTU_MCPIO_RESIDE           978
# FAMI_CUARTOSHOGAR         43191
# FAMI_PERSONASHOGAR        42533
# DESEMP_INGLES              3603
# PUNT_INGLES                3643
# dtype: int64

# %%
# Con relación a los valores nulos que aún quedan, se va a llevar a cabo lo siguiente:

# Eliminar registros con nulos en 'ESTU_COD_RESIDE_DEPTO' y 'ESTU_COD_RESIDE_MCPIO' (pocos nulos)

df_Saber11 = df_Saber11.dropna(subset=['ESTU_COD_RESIDE_DEPTO', 'ESTU_COD_RESIDE_MCPIO','ESTU_DEPTO_RESIDE','ESTU_MCPIO_RESIDE'])

# Eliminar registros con nulos en 'DESEMP_INGLES' y 'PUNT_INGLES' (pocos nulos)
df_Saber11 = df_Saber11.dropna(subset=['DESEMP_INGLES', 'PUNT_INGLES'])

# Eliminar la columna 'COLE_CARACTER' . No se encuentra esta variable relevante.
df_Saber11.drop(columns=['COLE_CARACTER'], inplace=True)

# Imputar valores nulos en 'COLE_BILINGUE' con 'No especificado'. En este caso se coloca valor "No especificado", para no
# afectar el resultado, siendo una variable importante.
df_Saber11['COLE_BILINGUE'].fillna('No especificado', inplace=True)

# Verificar el resultado final
print("Número total de registros después de la limpieza:", len(df_Saber11))
print("\nNúmero de registros con valores nulos por columna después de la limpieza:")
print(df_Saber11.isna().sum())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 8
#       5 df_Saber11 = df_Saber11.dropna(subset=['DESEMP_INGLES', 'PUNT_INGLES'])
#       7 # Eliminar la columna 'COLE_CARACTER'. No se encuentra esta variable relevante.
# ----> 8 df_Saber11 = df_Saber11.drop(columns=['COLE_CARACTER'])
#      10 # Imputar valores nulos en 'COLE_BILINGUE' con 'No especificado'.
#      11 # Evitamos el uso de 'inplace=True' para evitar la advertencia.
#      12 df_Saber11['COLE_BILINGUE'] = df_Saber11['COLE_BILINGUE'].fillna('No especificado')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['COLE_CARACTER'] not found in axis"

# %%
# Para la columna 'FAMI_CUARTOSHOGAR' se hace primero una conversión al número de cuartos respectivo y luego se registra la
# mediana.
# Paso 1: Mapeo de valores de texto a números en 'FAMI_CUARTOSHOGAR'
mapeo_cuartos = {
    'Uno': 1, 'Dos': 2, 'Tres': 3, 'Cuatro': 4, 'Cinco': 5,
    'Seis': 6, 'Siete': 7, 'Ocho': 8, 'Nueve': 9,
    'Diez o más': 10, 'Seis o mas': 6  # Suponemos que 'Seis o mas' es equivalente a 6
}

# Reemplazar los valores de texto con sus valores numéricos
df_Saber11['FAMI_CUARTOSHOGAR'] = df_Saber11['FAMI_CUARTOSHOGAR'].map(mapeo_cuartos)

# Paso 2: Imputar valores nulos en 'FAMI_CUARTOSHOGAR' con la mediana
df_Saber11['FAMI_CUARTOSHOGAR'].fillna(df_Saber11['FAMI_CUARTOSHOGAR'].median(), inplace=True)

# Verificar el resultado de la imputación
print("Valores únicos en 'FAMI_CUARTOSHOGAR' después de la imputación:", df_Saber11['FAMI_CUARTOSHOGAR'].unique())
# Out:
# Valores únicos en 'FAMI_CUARTOSHOGAR' después de la imputación: [ 2.  4.  5.  3.  1.  6. 10.  8.  7.  9.]
# C:\Users\jaime\AppData\Local\Temp\ipykernel_7992\2220298745.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Saber11['FAMI_CUARTOSHOGAR'].fillna(df_Saber11['FAMI_CUARTOSHOGAR'].median(), inplace=True)

# %%
# La última columna con nulos es FAMI_PERSONASHOGAR y se le hace la conversión a numérico y se registra la mediana.

# Paso 1: Mapeo de valores de texto a números en 'FAMI_PERSONASHOGAR'
mapeo_personas = {
    'Una': 1, '1 a 2': 2, 'Dos': 2, 'Tres': 3, '3 a 4': 4, 
    'Cuatro': 4, 'Cinco': 5, '5 a 6': 6, 'Seis': 6, 'Siete': 7, 
    '7 a 8': 8, 'Ocho': 8, 'Nueve': 9, '9 o más': 9, 'Diez': 10,
    'Once': 11, 'Doce o más': 12
}

# Reemplazar los valores de texto con sus valores numéricos
df_Saber11['FAMI_PERSONASHOGAR'] = df_Saber11['FAMI_PERSONASHOGAR'].map(mapeo_personas)

# Paso 2: Imputar valores nulos en 'FAMI_PERSONASHOGAR' con la mediana
df_Saber11['FAMI_PERSONASHOGAR'].fillna(df_Saber11['FAMI_PERSONASHOGAR'].median(), inplace=True)

# Verificar el resultado de la imputación
print("Valores únicos en 'FAMI_PERSONASHOGAR' después de la imputación:", df_Saber11['FAMI_PERSONASHOGAR'].unique())
print("Mediana de 'FAMI_PERSONASHOGAR':", df_Saber11['FAMI_PERSONASHOGAR'].median())
# Out:
# Valores únicos en 'FAMI_PERSONASHOGAR' después de la imputación: [ 2.  6.  5.  4.  7.  3.  8.  9. 12. 11. 10.  1.]
# Mediana de 'FAMI_PERSONASHOGAR': 4.0
# C:\Users\jaime\AppData\Local\Temp\ipykernel_7992\220257329.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Saber11['FAMI_PERSONASHOGAR'].fillna(df_Saber11['FAMI_PERSONASHOGAR'].median(), inplace=True)

# %%
print(df_Saber11.isnull().sum())
# Out:
# COLE_AREA_UBICACION              0
# COLE_BILINGUE                    0
# COLE_CALENDARIO                  0
# COLE_COD_DANE_ESTABLECIMIENTO    0
# COLE_COD_DANE_SEDE               0
# COLE_COD_DEPTO_UBICACION         0
# COLE_COD_MCPIO_UBICACION         0
# COLE_CODIGO_ICFES                0
# COLE_DEPTO_UBICACION             0
# COLE_GENERO                      0
# COLE_JORNADA                     0
# COLE_MCPIO_UBICACION             0
# COLE_NATURALEZA                  0
# COLE_NOMBRE_ESTABLECIMIENTO      0
# COLE_NOMBRE_SEDE                 0
# COLE_SEDE_PRINCIPAL              0
# ESTU_COD_DEPTO_PRESENTACION      0
# ESTU_COD_MCPIO_PRESENTACION      0
# ESTU_COD_RESIDE_DEPTO            0
# ESTU_COD_RESIDE_MCPIO            0
# ESTU_DEPTO_PRESENTACION          0
# ESTU_DEPTO_RESIDE                0
# ESTU_ESTUDIANTE                  0
# ESTU_GENERO                      0
# ESTU_MCPIO_PRESENTACION          0
# ESTU_MCPIO_RESIDE                0
# ESTU_NACIONALIDAD                0
# ESTU_PAIS_RESIDE                 0
# ESTU_PRIVADO_LIBERTAD            0
# FAMI_CUARTOSHOGAR                0
# FAMI_EDUCACIONMADRE              0
# FAMI_EDUCACIONPADRE              0
# FAMI_ESTRATOVIVIENDA             0
# FAMI_PERSONASHOGAR               0
# FAMI_TIENEAUTOMOVIL              0
# FAMI_TIENECOMPUTADOR             0
# FAMI_TIENEINTERNET               0
# FAMI_TIENELAVADORA               0
# DESEMP_INGLES                    0
# PUNT_INGLES                      0
# PUNT_MATEMATICAS                 0
# PUNT_SOCIALES_CIUDADANAS         0
# PUNT_C_NATURALES                 0
# PUNT_LECTURA_CRITICA             0
# PUNT_GLOBAL                      0
# AÑO                              0
# EDAD_EXAMEN                      0
# dtype: int64

# %%
# Eliminar registros con valores nulos en las columnas específicas de SaberPro que tienen un número pequeño de nulos.

columnas_a_eliminar_nulos = [
    'ESTU_COD_RESIDE_DEPTO',
    'ESTU_COD_RESIDE_MCPIO',
    'ESTU_COD_DEPTO_PRESENTACION',
    'ESTU_DEPTO_PRESENTACION',
    'ESTU_COD_MCPIO_PRESENTACION',
    'ESTU_SNIES_PRGMACADEMICO',
    'ESTU_GENERO',
    'MOD_INGLES_DESEM',
    'MOD_INGLES_PUNT'
]

# Eliminar registros con nulos en cada columna especificada
df_SaberPro.dropna(subset=columnas_a_eliminar_nulos, inplace=True)

# Verificar el número total de registros después de la eliminación
print("Número total de registros después de eliminar los valores nulos en columnas seleccionadas:", len(df_SaberPro))
# Out:
# Número total de registros después de eliminar los valores nulos en columnas seleccionadas: 1099481

# %%
# Verificar columnas con valores nulos en df_Saber11
columnas_nulas = df_SaberPro.isnull().sum()

# Filtrar y mostrar solo las columnas con valores nulos mayores a cero
columnas_nulas = columnas_nulas[columnas_nulas > 0]

# Mostrar las columnas con valores nulos y sus respectivos conteos
print("Columnas con valores nulos y sus conteos:")
print(columnas_nulas)
# Out:
# Columnas con valores nulos y sus conteos:
# ESTU_CODDANE_COLE_TERMINO         350195
# ESTU_COD_COLE_MCPIO_TERMINO       350195
# ESTU_VALORMATRICULAUNIVERSIDAD      7577
# ESTU_PAGOMATRICULABECA              8010
# ESTU_PAGOMATRICULACREDITO           7943
# ESTU_HORASSEMANATRABAJA            10729
# ESTU_COLE_TERMINO                 328941
# ESTU_PAGOMATRICULAPADRES            7824
# ESTU_PAGOMATRICULAPROPIO            7901
# MOD_COMUNI_ESCRITA_PUNT             6026
# MOD_COMUNI_ESCRITA_DESEM           48537
# dtype: int64

# %%
# Es importante conocer los valores únicos de cada columna no numérica de SaberPro y verificar las variables categóricas que se
# deben convertir.

# Paso 1: Seleccionar las columnas categóricas (no numéricas)
# Esto ayudará a identificar columnas de tipo "object" que suelen ser categóricas
columnas_categoricas = df_SaberPro.select_dtypes(include=['object']).columns

# Paso 2: Mostrar los valores únicos de cada columna categórica
# Este bucle recorre cada columna categórica y muestra sus valores únicos
for columna in columnas_categoricas:
    print(f"Valores únicos de la columna '{columna}':")
    print(df_SaberPro[columna].unique())
    print("\n" + "-"*50 + "\n")  # Separador para claridad
# Out:
# Valores únicos de la columna 'ESTU_PAIS_RESIDE':
# ['COLOMBIA' 'VIETNAM' 'ESTADOS UNIDOS' 'SANTA LUCÍA' 'VENEZUELA' 'COMORAS'
#  'CURAZAO' 'MÉXICO' 'BRASIL' 'COREA DEL NORTE' 'PERÚ' 'ECUADOR' 'ALEMANIA'
#  'CUBA' 'PANAMÁ' 'CHILE' 'PORTUGAL' 'FRANCIA' 'ITALIA' 'COREA DEL SUR'
#  'RUSIA' 'ESPAÑA' 'ESTADOS FEDERADOS DE MICRONESIA' 'BÉLGICA' 'KENIA'
#  'BOLIVIA' 'ARGENTINA' 'NICARAGUA' 'ISRAEL' 'EL SALVADOR' 'JAPÓN'
#  'UCRANIA' 'MARRUECOS' 'COSTA RICA' 'REINO UNIDO' 'PAÍSES BAJOS - HOLANDA'
#  'CAMERÚN' 'DINAMARCA' 'URUGUAY' 'POLONIA' 'ARMENIA' 'HAITI' 'GUATEMALA'
#  'SUIZA' 'TURQUÍA' 'CHINA' 'AZERBAIYÁN' 'HONDURAS' 'PARAGUAY'
#  'REPÚBLICA DOMINICANA' 'TERRITORIOS PALESTINOS' 'DOMINICA' 'CABO VERDE'
#  'CROACIA' 'NORUEGA' 'VANUATU' 'UGANDA' 'BIELORRUSIA' 'CANADÁ'
#  'BURKINA FASO' 'ALBANIA' 'REPÚBLICA DEMOCRÁTICA DEL CONGO' 'GABÓN' 'OMÁN'
#  'MOZAMBIQUE' 'TANZANIA' 'INDIA' 'ZIMBABUE' 'SUECIA' 'CIUDAD DEL VATICANO'
#  'YEMEN' 'UZBEKISTÁN' 'BUTÁN' 'MACAO' 'COSTA DE MARFIL'
#  'LAOS - REPÚBLICA DEMOCRÁTICA POPULAR LAO' 'ANTIGUA Y BARBUDA' 'ALAND'
#  'REUNIÓN' 'LÍBANO']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_DEPTO_RESIDE':
# ['BOGOTÁ' 'VALLE' 'TOLIMA' 'SANTANDER' 'SUCRE' 'ANTIOQUIA' 'BOYACA'
#  'CAUCA' 'HUILA' 'CUNDINAMARCA' 'CORDOBA' 'ATLANTICO' 'BOLIVAR' 'ARAUCA'
#  'CALDAS' 'RISARALDA' 'NORTE SANTANDER' 'CESAR' 'QUINDIO' 'MAGDALENA'
#  'LA GUAJIRA' 'META' 'CAQUETA' 'NARIÑO' 'PUTUMAYO' 'AMAZONAS' 'CHOCO'
#  'CASANARE' 'SAN ANDRES' 'GUAVIARE' 'EXTRANJERO' 'GUAINIA' 'VAUPES'
#  'VICHADA' 'ATLANTA' 'MADRID' 'FRANKFURT' 'SACRAMENTO' 'ROMA' 'QUEBEC'
#  'MIAMI' 'SEUL' 'BUENOS AIRES' 'LIMA' 'BARCELONA' 'TRENTON' 'PARIS'
#  'SANTIAGO DE CHILE' 'SAO PAULO']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_MCPIO_RESIDE':
# ['BOGOTÁ D.C.' 'SEVILLA' 'IBAGUÉ' ... 'PARIS' 'SANTIAGO DE CHILE'
#  'SAO PAULO']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'INST_CARACTER_ACADEMICO':
# ['INSTITUCIÓN UNIVERSITARIA' 'UNIVERSIDAD' 'TÉCNICA PROFESIONAL'
#  'INSTITUCIÓN TECNOLÓGICA']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_NUCLEO_PREGRADO':
# ['ADMINISTRACIÓN' 'CONTADURÍA PUBLICA'
#  'INGENIERÍA AMBIENTAL, SANITARIA Y AFINES'
#  'BIBLIOTECOLOGÍA, OTROS DE CIENCIAS SOCIALES Y HUMANAS' 'PSICOLOGÍA'
#  'INGENIERÍA DE SISTEMAS, TELEMÁTICA Y AFINES' 'DISEÑO'
#  'BIOLOGÍA, MICROBIOLOGÍA Y AFINES' 'DERECHO Y AFINES' 'EDUCACIÓN'
#  'INGENIERÍA CIVIL Y AFINES'
#  'INGENIERÍA ELECTRÓNICA, TELECOMUNICACIONES Y AFINES' 'MEDICINA'
#  'INGENIERÍA QUÍMICA Y AFINES'
#  'GEOLOGÍA, OTROS PROGRAMAS DE CIENCIAS NATURALES' 'ENFERMERÍA'
#  'INGENIERÍA INDUSTRIAL Y AFINES' 'ODONTOLOGÍA'
#  'SOCIOLOGÍA, TRABAJO SOCIAL Y AFINES' 'INGENIERÍA BIOMÉDICA Y AFINES'
#  'ECONOMÍA' 'COMUNICACIÓN SOCIAL, PERIODISMO Y AFINES' 'TERAPIAS'
#  'INGENIERÍA AGRÍCOLA, FORESTAL Y AFINES' 'GEOGRAFÍA, HISTORIA'
#  'AGRONOMÍA' 'LENGUAS MODERNAS, LITERATURA, LINGÜÍSTICA Y AFINES'
#  'INGENIERÍA MECÁNICA Y AFINES' 'NUTRICIÓN Y DIETÉTICA' 'SALUD PUBLICA'
#  'QUÍMICA Y AFINES' 'ARQUITECTURA' 'ZOOTECNIA'
#  'DEPORTES, EDUCACIÓN FÍSICA Y RECREACIÓN'
#  'INGENIERÍA ADMINISTRATIVA Y AFINES' 'INSTRUMENTACIÓN QUIRÚRGICA'
#  'FÍSICA' 'CIENCIA POLÍTICA, RELACIONES INTERNACIONALES'
#  'INGENIERÍA ELÉCTRICA Y AFINES'
#  'OPTOMETRÍA, OTROS PROGRAMAS DE CIENCIAS DE LA SALUD'
#  'FILOSOFÍA, TEOLOGÍA Y AFINES' 'PUBLICIDAD Y AFINES'
#  'MEDICINA VETERINARIA' 'OTRAS INGENIERÍAS' 'BACTERIOLOGÍA'
#  'FORMACIÓN RELACIONADA CON EL CAMPO MILITAR O POLICIAL'
#  'ARTES PLÁSTICAS, VISUALES Y AFINES'
#  'INGENIERÍA AGRONÓMICA, PECUARIA Y AFINES'
#  'INGENIERÍA DE MINAS, METALURGIA Y AFINES' 'MÚSICA'
#  'ANTROPOLOGÍA, ARTES LIBERALES'
#  'INGENIERÍA AGROINDUSTRIAL, ALIMENTOS Y AFINES'
#  'MATEMÁTICAS, ESTADÍSTICA Y AFINES' 'ARTES REPRESENTATIVAS'
#  'OTROS PROGRAMAS ASOCIADOS A BELLAS ARTES' 'SIN CLASIFICAR']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_INST_DEPARTAMENTO':
# ['BOGOTÁ' 'VALLE' 'SANTANDER' 'QUINDIO' 'SUCRE' 'ANTIOQUIA' 'BOYACA'
#  'CAUCA' 'HUILA' 'CUNDINAMARCA' 'CORDOBA' 'ATLANTICO' 'CALDAS' 'BOLIVAR'
#  'RISARALDA' 'MAGDALENA' 'NORTE SANTANDER' 'CESAR' 'TOLIMA' 'CAQUETA'
#  'NARIÑO' 'LA GUAJIRA' 'META' 'CHOCO' 'CASANARE' 'PUTUMAYO']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_INST_MUNICIPIO':
# ['BOGOTÁ D.C.' 'CALI' 'BARRANCABERMEJA' 'ARMENIA' 'SINCELEJO'
#  'SANTA ROSA DE OSOS' 'TUNJA' 'POPAYÁN' 'NEIVA' 'EL CARMEN DE VIBORAL'
#  'MEDELLÍN' 'CHÍA' 'MONTERÍA' 'BARRANQUILLA' 'MANIZALES'
#  'CARTAGENA DE INDIAS' 'BUCARAMANGA' 'ENVIGADO' 'BUENAVENTURA' 'RIONEGRO'
#  'PEREIRA' 'FUSAGASUGÁ' 'SANTA MARTA' 'SANTA ROSA DE CABAL' 'SABANETA'
#  'PAMPLONA' 'VALLEDUPAR' 'CÚCUTA' 'IBAGUÉ' 'SOGAMOSO' 'FLORENCIA'
#  'GIRARDOT' 'BELLO' 'FACATATIVÁ' 'PASTO' 'RIOHACHA' 'ROLDANILLO' 'SOCORRO'
#  'TURBO' 'VILLAVICENCIO' 'QUIBDÓ' 'DUITAMA' 'ESPINAL' 'OCAÑA' 'SAN GIL'
#  'SOLEDAD' 'PALMIRA' 'TULUÁ' 'CALDAS' 'AGUACHICA' 'YOPAL' 'MOCOA'
#  'CARTAGO' 'ANDES' 'VILLA DE SAN DIEGO DE UBATÉ' 'CAUCASIA' 'CHIQUINQUIRÁ'
#  'APARTADÓ' 'GUADALAJARA DE BUGA' 'PUERTO BERRÍO' 'SAN JUAN DEL CESAR']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_PRGM_ACADEMICO':
# ['HOTELERIA Y TURISMO' 'CONTADURIA PUBLICA' 'CONTADURÍA PÚBLICA' ...
#  'LICENCIATURA EN RECREACIÓN  Y TURISMO'
#  'REALIZACIÓN Y PRODUCCIÓN MUSICAL' 'MATEM¿TICA APLICADA']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_PRGM_DEPARTAMENTO':
# ['BOGOTÁ' 'VALLE' 'SANTANDER' 'QUINDIO' 'SUCRE' 'ANTIOQUIA' 'BOYACA'
#  'CAUCA' 'HUILA' 'TOLIMA' 'CUNDINAMARCA' 'CORDOBA' 'ATLANTICO' 'CALDAS'
#  'BOLIVAR' 'ARAUCA' 'NORTE SANTANDER' 'CESAR' 'RISARALDA' 'MAGDALENA'
#  'META' 'CAQUETA' 'NARIÑO' 'LA GUAJIRA' 'CHOCO' 'CASANARE' 'PUTUMAYO'
#  'AMAZONAS' 'VAUPES' 'GUAVIARE' 'SAN ANDRES']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_PRGM_MUNICIPIO':
# ['BOGOTÁ D.C.' 'TULUÁ' 'BARRANCABERMEJA' 'ARMENIA' 'SINCELEJO'
#  'SANTA ROSA DE OSOS' 'TUNJA' 'POPAYÁN' 'NEIVA' 'EL CARMEN DE VIBORAL'
#  'IBAGUÉ' 'MEDELLÍN' 'CHÍA' 'CALI' 'MONTERÍA' 'BARRANQUILLA' 'MANIZALES'
#  'CARTAGENA DE INDIAS' 'ARAUCA' 'MÁLAGA' 'ENVIGADO' 'BUENAVENTURA'
#  'CÚCUTA' 'RIONEGRO' 'PITALITO' 'VALLEDUPAR' 'PEREIRA' 'BUCARAMANGA'
#  'VILLA DE SAN DIEGO DE UBATÉ' 'SANTA MARTA' 'SANTA ROSA DE CABAL'
#  'SABANETA' 'PAMPLONA' 'VILLA DEL ROSARIO' 'VILLAVICENCIO' 'SOGAMOSO'
#  'CAJICÁ' 'FLORENCIA' 'PASTO' 'GIRARDOT' 'BELLO' 'FACATATIVÁ' 'MAICAO'
#  'VILLANUEVA' 'CHAPARRAL' 'RIOHACHA' 'ROLDANILLO' 'SOCORRO' 'APARTADÓ'
#  'FUSAGASUGÁ' 'SOACHA' 'QUIBDÓ' 'ESPINAL' 'DUITAMA' 'OCAÑA' 'YOPAL'
#  'SOLEDAD' 'GUADALAJARA DE BUGA' 'TIERRALTA' 'PALMIRA' 'ACACÍAS' 'IPIALES'
#  'SANTANDER DE QUILICHAO' 'ZARZAL' 'SAN GIL' 'CALDAS' 'CARTAGO'
#  'COPACABANA' 'AGUACHICA' 'SANTA FÉ DE ANTIOQUIA' 'MANAURE'
#  'SAN ANDRÉS DE TUMACO' 'SAN CAYETANO' 'GARAGOA' 'CHIQUINQUIRÁ'
#  'LA PINTADA' 'MOCOA' 'RIVERA' 'CIRCASIA' 'RIOSUCIO' 'ANDES' 'TURBO'
#  'FONSECA' 'CAUCASIA' 'ITAGÜÍ' 'SONSÓN' 'PURIFICACIÓN' 'MONIQUIRÁ'
#  'CAICEDONIA' 'AGUAZUL' 'FILADELFIA' 'LA PLATA' 'ZIPAQUIRÁ' 'SIBATÉ'
#  'CAREPA' 'SIBUNDOY' 'AMALFI' 'LETICIA' 'RIOBLANCO' 'TORIBÍO' 'TÚQUERRES'
#  'SAMANIEGO' 'SEGOVIA' 'MITÚ' 'CUMARAL' 'PÁCORA' 'YARUMAL' 'HONDA'
#  'PLANADAS' 'PUERTO COLOMBIA' 'ISTMINA' 'GARZÓN' 'LÍBANO' 'ICONONZO'
#  'ARBOLEDAS' 'MELGAR' 'CHISCAS' 'COGUA' 'FRESNO' 'FLANDES' 'SAN MARTÍN'
#  'SOATÁ' 'MIRANDA' 'SAN JOSÉ DEL GUAVIARE' 'SAN LUIS DE SINCÉ' 'LA UNIÓN'
#  'SEVILLA' 'SAN ANDRÉS' 'PUERTO BERRÍO' 'MISTRATÓ' 'SAN CARLOS' 'QUETAME'
#  'PUERTO BOYACÁ' 'EL DOVIO' 'RICAURTE' 'LORICA' 'MAGANGUÉ' 'ALBANIA'
#  'LA DORADA' 'PUERTO ASÍS' 'AGUSTÍN CODAZZI' 'LÉRIDA' 'DURANIA'
#  'SAN JUAN DEL CESAR' 'ANSERMA' 'AGUADAS' 'CHIVOLO' 'MARÍA LA BAJA'
#  'SUTATENZA' 'FUNDACIÓN' 'ANAPOIMA' 'SAHAGÚN' 'SAN AGUSTÍN'
#  'SANTA ROSA DEL SUR' 'SAN JUAN NEPOMUCENO' 'COROZAL' 'BOSCONIA' 'URIBIA']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_NIVEL_PRGM_ACADEMICO':
# ['UNIVERSITARIO']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_METODO_PRGM':
# ['PRESENCIAL' 'DISTANCIA' 'DISTANCIA VITUAL']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_VALORMATRICULAUNIVERSIDAD':
# ['Entre 2.5 millones y menos de 4 millones' 'Menos de 500 mil'
#  'Entre 1 millón y menos de 2.5 millones'
#  'Entre 500 mil y menos de 1 millón' 'Más de 7 millones'
#  'Entre 4 millones y menos de 5.5 millones'
#  'Entre 5.5 millones y menos de 7 millones' 'No pagó matrícula' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_DEPTO_PRESENTACION':
# ['BOGOTÁ' 'VALLE' 'TOLIMA' 'SANTANDER' 'SUCRE' 'ANTIOQUIA' 'BOYACA'
#  'CAUCA' 'HUILA' 'CUNDINAMARCA' 'CORDOBA' 'ATLANTICO' 'BOLIVAR' 'ARAUCA'
#  'CALDAS' 'RISARALDA' 'NORTE SANTANDER' 'CESAR' 'QUINDIO' 'MAGDALENA'
#  'META' 'CAQUETA' 'NARIÑO' 'LA GUAJIRA' 'PUTUMAYO' 'AMAZONAS' 'CHOCO'
#  'CASANARE' 'GUAVIARE' 'SAN ANDRES' 'LOS ANGELES' 'GUADALAJARA'
#  'MÉXICO DF' 'NUEVA YORK' 'PARIS' 'GUAINIA' 'BARCELONA' 'SAO PAULO'
#  'BERLIN' 'BUENOS AIRES' 'VAUPES' 'VICHADA' 'MADRID' 'VIENA' 'MIAMI'
#  'ABU DHABI' 'LIMA' 'BERNA' 'FRANKFURT' 'SANTIAGO DE CHILE' 'SYDNEY'
#  'MILAN' 'LONDRES' 'CIUDAD DE PANAMÁ' 'HOUSTON' 'ESTOCOLMO'
#  'SAN JUAN DE PUERTO RICO' 'TOKIO' 'ANKARA' 'AMSTERDAM' 'TORONTO' 'SEUL'
#  'CALGARY' 'ROMA' 'HONG KONG' 'GUATEMALA' 'SAN JOSE' 'BEIJING' 'QUITO'
#  'TEL AVIV' 'MONTEVIDEO' 'AUCKLAND' 'LA HABANA' 'SANTO DOMINGO']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_MCPIO_PRESENTACION':
# ['BOGOTÁ D.C.' 'TULUÁ' 'IBAGUÉ' 'BARRANCABERMEJA' 'SINCELEJO' 'PALMIRA'
#  'ITAGÜÍ' 'DUITAMA' 'POPAYÁN' 'NEIVA' 'RIONEGRO' 'BELLO' 'CHÍA' 'CALI'
#  'MONTERÍA' 'BARRANQUILLA' 'MONTELÍBANO' 'CARTAGENA DE INDIAS' 'SOACHA'
#  'ARAUCA' 'TURBO' 'MÁLAGA' 'SABANETA' 'RIOSUCIO' 'BUENAVENTURA' 'PEREIRA'
#  'CÚCUTA' 'MEDELLÍN' 'PITALITO' 'VALLEDUPAR' 'BUCARAMANGA' 'ARMENIA'
#  'SANTA MARTA' 'BARANOA' 'SOLEDAD' 'MANIZALES' 'TUNJA' 'VILLA DEL ROSARIO'
#  'VILLAVICENCIO' 'SOGAMOSO' 'FLORENCIA' 'GIRARDOT' 'PASTO' 'FUNZA'
#  'ZIPAQUIRÁ' 'FACATATIVÁ' 'SAHAGÚN' 'RIOHACHA' 'IPIALES' 'GIRÓN' 'MOCOA'
#  'ROLDANILLO' 'SOCORRO' 'CHIQUINQUIRÁ' 'GUADALAJARA DE BUGA' 'LETICIA'
#  'APARTADÓ' 'EL BANCO' 'FUSAGASUGÁ' 'JAMUNDÍ' 'SANTANDER DE QUILICHAO'
#  'QUIBDÓ' 'YOPAL' 'SANTA ROSA DE OSOS' 'COROZAL' 'OCAÑA' 'CAUCASIA'
#  'PAMPLONA' 'GUAPÍ' 'CALDAS' 'SAN JOSÉ DEL GUAVIARE'
#  'SAN ANDRÉS DE TUMACO' 'PENSILVANIA' 'MADRID' 'MOSQUERA' 'CALARCÁ'
#  'SAN ANDRÉS' 'PUERTO ASÍS' 'ESPINAL' 'MAGANGUÉ' 'MONIQUIRÁ' 'SAN GIL'
#  'LOS ANGELES' 'LA DORADA' 'ANDES' 'CARTAGO' 'ORITO' 'PIEDECUESTA'
#  'GUADALAJARA' 'MÉXICO DF' 'MELGAR' 'NUEVA YORK' 'AGUACHICA'
#  'PIENDAMÓ - TUNÍA' 'GARZÓN' 'SANTA FÉ DE ANTIOQUIA' 'PARIS' 'SIBUNDOY'
#  'ISTMINA' 'INÍRIDA' 'MOMPÓS' 'NOCAIMA' 'EL CARMEN DE VIBORAL' 'SOATÁ'
#  'BARCELONA' 'ZARZAL' 'URRAO' 'SONSÓN' 'MARQUETALIA' 'PÁCORA' 'SAO PAULO'
#  'YOLOMBÓ' 'PUERTO BERRÍO' 'BERLIN' 'BUENOS AIRES' 'MITÚ' 'PUERTO CARREÑO'
#  'TADÓ' 'GACHETÁ' 'VIENA' 'MIAMI' 'ABU DHABI' 'MONTERREY'
#  'SAN JUAN NEPOMUCENO' 'YARUMAL' 'LIMA' 'VÉLEZ' 'BERNA' 'BARBOSA'
#  'FRANKFURT' 'SANTIAGO DE CHILE' 'ICONONZO' 'SYDNEY' 'MILAN' 'LONDRES'
#  'CIUDAD DE PANAMÁ' 'HOUSTON' 'ESTOCOLMO' 'SAN JUAN DE PUERTO RICO'
#  'TOKIO' 'ANKARA' 'GÜICÁN DE LA SIERRA' 'LA VEGA' 'AMSTERDAM' 'TORONTO'
#  'SEUL' 'CALGARY' 'ROMA' 'HONG KONG' 'GUATEMALA' 'SAN JOSE' 'BEIJING'
#  'SOPETRÁN' 'QUITO' 'TEL AVIV' 'MONTEVIDEO' 'AUCKLAND' 'LA HABANA'
#  'SANTO DOMINGO' 'NILO']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_PAGOMATRICULABECA':
# ['No' 'Si' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_PAGOMATRICULACREDITO':
# ['No' 'Si' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_HORASSEMANATRABAJA':
# ['Entre 11 y 20 horas' 'Entre 21 y 30 horas' 'Más de 30 horas' '0'
#  'Menos de 10 horas' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_PRIVADO_LIBERTAD':
# ['N' 'S']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_NACIONALIDAD':
# ['COLOMBIA' 'VIETNAM' 'ESTADOS UNIDOS' 'SANTA LUCÍA' 'VENEZUELA' 'COMORAS'
#  'CURAZAO' 'MÉXICO' 'BRASIL' 'COREA DEL NORTE' 'PERÚ' 'ECUADOR' 'ALEMANIA'
#  'CUBA' 'PANAMÁ' 'CHILE' 'PORTUGAL' 'FRANCIA' 'ITALIA' 'COREA DEL SUR'
#  'RUSIA' 'ESPAÑA' 'ESTADOS FEDERADOS DE MICRONESIA' 'BÉLGICA' 'KENIA'
#  'BOLIVIA' 'ARGENTINA' 'NICARAGUA' 'ISRAEL' 'EL SALVADOR' 'JAPÓN'
#  'UCRANIA' 'MARRUECOS' 'COSTA RICA' 'REINO UNIDO' 'PAÍSES BAJOS - HOLANDA'
#  'CAMERÚN' 'DINAMARCA' 'URUGUAY' 'POLONIA' 'ARMENIA' 'HAITI' 'GUATEMALA'
#  'SUIZA' 'TURQUÍA' 'CHINA' 'AZERBAIYÁN' 'HONDURAS' 'PARAGUAY'
#  'REPÚBLICA DOMINICANA' 'TERRITORIOS PALESTINOS' 'DOMINICA' 'CABO VERDE'
#  'CROACIA' 'NORUEGA' 'VANUATU' 'UGANDA' 'BIELORRUSIA' 'CANADÁ'
#  'BURKINA FASO' 'ALBANIA' 'REPÚBLICA DEMOCRÁTICA DEL CONGO' 'GABÓN' 'OMÁN'
#  'MOZAMBIQUE' 'TANZANIA' 'INDIA' 'ZIMBABUE' 'SUECIA' 'CIUDAD DEL VATICANO'
#  'YEMEN' 'UZBEKISTÁN' 'BUTÁN' 'MACAO' 'COSTA DE MARFIL'
#  'LAOS - REPÚBLICA DEMOCRÁTICA POPULAR LAO' 'ANTIGUA Y BARBUDA' 'ALAND'
#  'REUNIÓN' 'LÍBANO']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_ESTUDIANTE':
# ['ESTUDIANTE']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_GENERO':
# ['F' 'M']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_COLE_TERMINO':
# [nan 'SEDE 1  GERMAN PARDO' 'INSTITUTO TECNICO INDUSTRIAL' ...
#  'COLEGIO RENFORT - SEDE PRINCIPAL' 'I.E. LAS ACACIAS'
#  'SEDE GABRIELA MISTRAL A']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_PAGOMATRICULAPADRES':
# ['Si' 'No' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'ESTU_PAGOMATRICULAPROPIO':
# ['No' 'Si' nan]
#
# --------------------------------------------------
#
# Valores únicos de la columna 'FAMI_EDUCACIONPADRE':
# ['Primaria completa' 'Primaria incompleta' 'No Aplica' 'Postgrado'
#  'Educación profesional completa' 'Educación profesional incompleta'
#  'Técnica o tecnológica completa' 'Secundaria (Bachillerato) incompleta'
#  'Secundaria (Bachillerato) completa' 'Técnica o tecnológica incompleta'
#  'Ninguno' 'No sabe']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'FAMI_TIENEAUTOMOVIL':
# ['Si' 'No']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'FAMI_TIENELAVADORA':
# ['Si' 'No']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'FAMI_ESTRATOVIVIENDA':
# ['Estrato 2' 'Estrato 3' 'Estrato 1' 'Estrato 4' 'Estrato 5' 'Estrato 6'
#  'Sin Estrato']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'FAMI_TIENECOMPUTADOR':
# ['Si' 'No']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'FAMI_TIENEINTERNET':
# ['Si' 'No']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'FAMI_EDUCACIONMADRE':
# ['Secundaria (Bachillerato) incompleta' 'No sabe'
#  'Técnica o tecnológica completa' 'Educación profesional completa'
#  'Ninguno' 'Técnica o tecnológica incompleta' 'Primaria incompleta'
#  'Educación profesional incompleta' 'Secundaria (Bachillerato) completa'
#  'Postgrado' 'Primaria completa' 'No Aplica']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'INST_ORIGEN':
# ['NO OFICIAL - CORPORACIÓN' 'OFICIAL DEPARTAMENTAL'
#  'NO OFICIAL - FUNDACIÓN' 'OFICIAL NACIONAL' 'OFICIAL MUNICIPAL'
#  'REGIMEN ESPECIAL']
#
# --------------------------------------------------
#
# Valores únicos de la columna 'MOD_INGLES_DESEM':
# ['A2' 'B1' 'A1' '-A1' 'B2']
#
# --------------------------------------------------

# %%
# Dado que se tiene la columna ESTU_COLE_TERMINO con los nombres de los colegios, la información sobre el colegio se conserva.
# Por lo tanto, se puede asignar "NO DEFINIDO" a ESTU_CODDANE_COLE_TERMINO y 0 a ESTU_COD_COLE_MCPIO_TERMINO en los registros
# nulos indicando la falta de datos, sin necesidad de eliminar estos registros.

# Reemplazar valores nulos en 'ESTU_CODDANE_COLE_TERMINO' con 'NO DEFINIDO'
df_SaberPro['ESTU_CODDANE_COLE_TERMINO'].fillna('NO DEFINIDO', inplace=True)

# Reemplazar valores nulos en 'ESTU_COD_COLE_MCPIO_TERMINO' con 0
df_SaberPro['ESTU_COD_COLE_MCPIO_TERMINO'].fillna(0, inplace=True)

# Verificar la operación
print("Valores únicos después de reemplazar en 'ESTU_CODDANE_COLE_TERMINO':", df_SaberPro['ESTU_CODDANE_COLE_TERMINO'].unique())
print("Valores únicos después de reemplazar en 'ESTU_COD_COLE_MCPIO_TERMINO':", df_SaberPro['ESTU_COD_COLE_MCPIO_TERMINO'].unique())
# Out:
# Valores únicos después de reemplazar en 'ESTU_CODDANE_COLE_TERMINO': ['NO DEFINIDO' 173001004303.0 168081000571.0 ... 215469000113.0
#  173001001045.0 311001800685.0]
# Valores únicos después de reemplazar en 'ESTU_COD_COLE_MCPIO_TERMINO': [    0. 73001. 68081. ... 15550. 47675. 91263.]
# C:\Users\jaime\AppData\Local\Temp\ipykernel_7992\2607197337.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_SaberPro['ESTU_CODDANE_COLE_TERMINO'].fillna('NO DEFINIDO', inplace=True)
# C:\Users\jaime\AppData\Local\Temp\ipykernel_7992\2607197337.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NO DEFINIDO' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_SaberPro['ESTU_CODDANE_COLE_TERMINO'].fillna('NO DEFINIDO', inplace=True)
# C:\Users\jaime\AppData\Local\Temp\ipykernel_7992\2607197337.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_SaberPro['ESTU_COD_COLE_MCPIO_TERMINO'].fillna(0, inplace=True)

# %%
# El campo ESTU_VALORMATRICULAUNIVERSIDAD tiene 8037 valores nulos.
# Dado que hay una columna que se llama INST_COD_INSTITUCION, se puede buscar cuál es la moda de los valores de
# ESTU_VALORMATRICULAUNIVERSIDAD de cada institución y asignar esa en lugar del valor nulo. Esto dado que los valores
# en ESTU_VALORMATRICULAUNIVERSIDAD son categóricos en rangos y no numéricos.

# Calcular la moda de 'ESTU_VALORMATRICULAUNIVERSIDAD' para cada institución
moda_por_institucion = df_SaberPro.groupby('INST_COD_INSTITUCION')['ESTU_VALORMATRICULAUNIVERSIDAD'].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else "No pagó matrícula")

# Reemplazar valores nulos de 'ESTU_VALORMATRICULAUNIVERSIDAD' con la moda correspondiente
df_SaberPro['ESTU_VALORMATRICULAUNIVERSIDAD'] = df_SaberPro.apply(
    lambda row: moda_por_institucion[row['INST_COD_INSTITUCION']] if pd.isna(row['ESTU_VALORMATRICULAUNIVERSIDAD']) else row['ESTU_VALORMATRICULAUNIVERSIDAD'], 
    axis=1
)

# Verificar la operación
print("Valores únicos después de la imputación en 'ESTU_VALORMATRICULAUNIVERSIDAD':", df_SaberPro['ESTU_VALORMATRICULAUNIVERSIDAD'].unique())
# Out:
# Valores únicos después de la imputación en 'ESTU_VALORMATRICULAUNIVERSIDAD': ['Entre 2.5 millones y menos de 4 millones' 'Menos de 500 mil'
#  'Entre 1 millón y menos de 2.5 millones'
#  'Entre 500 mil y menos de 1 millón' 'Más de 7 millones'
#  'Entre 4 millones y menos de 5.5 millones'
#  'Entre 5.5 millones y menos de 7 millones' 'No pagó matrícula']

# %%
# Reemplazar valores nulos por 'No' en las columnas ESTU_PAGOMATRICULABECA y ESTU_PAGOMATRICULACREDITO.

df_SaberPro['ESTU_PAGOMATRICULABECA'].fillna('No', inplace=True)
df_SaberPro['ESTU_PAGOMATRICULACREDITO'].fillna('No', inplace=True)

# Verificación: contar cuántos nulos quedan en cada columna después de la asignación
print("Valores nulos en 'ESTU_PAGOMATRICULABECA':", df_SaberPro['ESTU_PAGOMATRICULABECA'].isna().sum())
print("Valores nulos en 'ESTU_PAGOMATRICULACREDITO':", df_SaberPro['ESTU_PAGOMATRICULACREDITO'].isna().sum())
# Out:
# Valores nulos en 'ESTU_PAGOMATRICULABECA': 0
# Valores nulos en 'ESTU_PAGOMATRICULACREDITO': 0
# C:\Users\jaime\AppData\Local\Temp\ipykernel_7992\419580853.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_SaberPro['ESTU_PAGOMATRICULABECA'].fillna('No', inplace=True)
# C:\Users\jaime\AppData\Local\Temp\ipykernel_7992\419580853.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_SaberPro['ESTU_PAGOMATRICULACREDITO'].fillna('No', inplace=True)

# %%
# A la columna ESTU_HORASSEMANATRABAJA asignar '0' en los valores nulos

# Reemplazar valores nulos por '0' en la columna 'ESTU_HORASSEMANATRABAJA'
df_SaberPro['ESTU_HORASSEMANATRABAJA'].fillna('0', inplace=True)

# Verificación: contar cuántos nulos quedan en la columna después de la asignación
print("Valores nulos en 'ESTU_HORASSEMANATRABAJA':", df_SaberPro['ESTU_HORASSEMANATRABAJA'].isna().sum())
# Out:
# Valores nulos en 'ESTU_HORASSEMANATRABAJA': 0
# C:\Users\jaime\AppData\Local\Temp\ipykernel_7992\2486438796.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_SaberPro['ESTU_HORASSEMANATRABAJA'].fillna('0', inplace=True)

# %%
# Asignar valores nulos en 'ESTU_PAGOMATRICULAPADRES' con la moda según el estrato en 'FAMI_ESTRATOVIVIENDA'

def imputar_moda_por_estrato(grupo):
    moda = grupo['ESTU_PAGOMATRICULAPADRES'].mode()  # Calcular la moda
    if not moda.empty:
        grupo['ESTU_PAGOMATRICULAPADRES'].fillna(moda[0], inplace=True)
    return grupo

# Aplicar la función de imputación por grupo de estrato
df_SaberPro = df_SaberPro.groupby('FAMI_ESTRATOVIVIENDA').apply(imputar_moda_por_estrato)

# Verificación: contar cuántos nulos quedan en la columna después de la imputación
print("Valores nulos en 'ESTU_PAGOMATRICULAPADRES' después de la imputación:", df_SaberPro['ESTU_PAGOMATRICULAPADRES'].isna().sum())
# Out:
# C:\Users\jaime\AppData\Local\Temp\ipykernel_7992\291544642.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   grupo['ESTU_PAGOMATRICULAPADRES'].fillna(moda[0], inplace=True)
# Valores nulos en 'ESTU_PAGOMATRICULAPADRES' después de la imputación: 0
# C:\Users\jaime\AppData\Local\Temp\ipykernel_7992\291544642.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_SaberPro = df_SaberPro.groupby('FAMI_ESTRATOVIVIENDA').apply(imputar_moda_por_estrato)

# %%
# Asignar valores nulos en 'ESTU_PAGOMATRICULAPROPIO' basado en 'ESTU_PAGOMATRICULAPADRES'

df_SaberPro['ESTU_PAGOMATRICULAPROPIO'] = df_SaberPro.apply(
    lambda row: 'No' if row['ESTU_PAGOMATRICULAPADRES'] == 'Si'
    else ('Si' if row['ESTU_PAGOMATRICULAPADRES'] == 'No' else row['ESTU_PAGOMATRICULAPROPIO']),
    axis=1
)

# Verificación: contar cuántos nulos quedan en la columna después de la imputación
print("Valores nulos en 'ESTU_PAGOMATRICULAPROPIO' después de la imputación:", df_SaberPro['ESTU_PAGOMATRICULAPROPIO'].isna().sum())
# Out:
# Valores nulos en 'ESTU_PAGOMATRICULAPROPIO' después de la imputación: 0

# %%
# Asignar el valor "NO DEFINIDO" en los valores nulos de 'ESTU_COLE_TERMINO'
df_SaberPro['ESTU_COLE_TERMINO'].fillna("NO DEFINIDO", inplace=True)

# Verificar el resultado para asegurar que no haya valores nulos en la columna
print("Valores nulos en 'ESTU_COLE_TERMINO' después de la imputación:", df_SaberPro['ESTU_COLE_TERMINO'].isna().sum())
# Out:
# Valores nulos en 'ESTU_COLE_TERMINO' después de la imputación: 0
# C:\Users\jaime\AppData\Local\Temp\ipykernel_7992\3360962910.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_SaberPro['ESTU_COLE_TERMINO'].fillna("NO DEFINIDO", inplace=True)

# %%
# Es importante saber cuáles registros nulos de FAMI_EDUCACIONPADRE (34671) coinciden con los registros nulos
# de FAMI_EDUCACIONMADRE (35350). Esto dado que estas dos variables son de mucha relevancia en el modelo y
# asignar valores podría no ser una buena estrategia.

# Contar cuántos registros tienen nulos en ambas columnas 'FAMI_EDUCACIONPADRE' y 'FAMI_EDUCACIONMADRE'
registros_nulos_ambas = df_SaberPro[df_SaberPro['FAMI_EDUCACIONPADRE'].isna() & df_SaberPro['FAMI_EDUCACIONMADRE'].isna()]

# Mostrar la cantidad de registros que tienen nulos en ambas columnas
print("Número de registros con nulos en 'FAMI_EDUCACIONPADRE' y 'FAMI_EDUCACIONMADRE':", registros_nulos_ambas.shape[0])
# Out:
# Número de registros con nulos en 'FAMI_EDUCACIONPADRE' y 'FAMI_EDUCACIONMADRE': 0

# %%
# Para las columnas FAMI_TIENEAUTOMOVIL (66437 nulos) y FAMI_TIENELAVADORA (58853 nulos) la estrategia es
# asignar 'Si' y 'No' de manera aleatoria, manteniendo la proporción en esas columnas de los registros de
# su mismo estrato y ESTU_COD_RESIDE_MCPIO. En el caso de que no sea posible estimar la proporción de esas
# dos columnas, se toma en cuenta solamente el estrato (FAMI_ESTRATOVIVIENDA).

def imputar_aleatoriamente(df, columna, agrupacion):
    """
    Imputa valores nulos en la columna dada de manera aleatoria, manteniendo
    la proporción de 'Si' y 'No' en cada grupo definido por las columnas de agrupación.
    """
    # Calcular las proporciones de 'Si' y 'No' en cada grupo
    proporciones = df.groupby(agrupacion)[columna].value_counts(normalize=True).unstack().fillna(0)

    # Calcular proporciones generales como respaldo
    proporciones_generales = df[columna].value_counts(normalize=True)

    # Función para aplicar la imputación basada en la proporción del grupo
    def imputar_valor(grupo):
        try:
            if pd.isna(grupo[columna]):
                # Intentar usar la proporción específica del grupo
                prob_si = proporciones.loc[(grupo[agrupacion[0]], grupo[agrupacion[1]]), 'Si']
                return np.random.choice(['Si', 'No'], p=[prob_si, 1 - prob_si])
        except KeyError:
            # Usar proporción general en caso de que la combinación no exista
            prob_si = proporciones_generales['Si']
            return np.random.choice(['Si', 'No'], p=[prob_si, 1 - prob_si])

        return grupo[columna]

    # Aplicar la función a cada fila
    df[columna] = df.apply(imputar_valor, axis=1)
    return df

# Reiniciar el índice para evitar ambigüedades
df_SaberPro = df_SaberPro.reset_index(drop=True)

# Intentar la imputación nuevamente
df_SaberPro = imputar_aleatoriamente(df_SaberPro, 'FAMI_TIENEAUTOMOVIL', ['FAMI_ESTRATOVIVIENDA', 'ESTU_COD_RESIDE_MCPIO'])
df_SaberPro = imputar_aleatoriamente(df_SaberPro, 'FAMI_TIENELAVADORA', ['FAMI_ESTRATOVIVIENDA', 'ESTU_COD_RESIDE_MCPIO'])

# Verificación de resultados
print("Distribución de valores en 'FAMI_TIENEAUTOMOVIL' después de imputación:")
print(df_SaberPro['FAMI_TIENEAUTOMOVIL'].value_counts())

print("Distribución de valores en 'FAMI_TIENELAVADORA' después de imputación:")
print(df_SaberPro['FAMI_TIENELAVADORA'].value_counts())

#########################
# Imputar valores en 'FAMI_TIENEAUTOMOVIL'
# df_SaberPro = imputar_aleatoriamente(df_SaberPro, 'FAMI_TIENEAUTOMOVIL', ['FAMI_ESTRATOVIVIENDA', 'ESTU_COD_RESIDE_MCPIO'])

# Imputar valores en 'FAMI_TIENELAVADORA'
# df_SaberPro = imputar_aleatoriamente(df_SaberPro, 'FAMI_TIENELAVADORA', ['FAMI_ESTRATOVIVIENDA', 'ESTU_COD_RESIDE_MCPIO'])

# Verificación de resultados
# print("Distribución de valores en 'FAMI_TIENEAUTOMOVIL' después de imputación:")
# print(df_SaberPro['FAMI_TIENEAUTOMOVIL'].value_counts())

# print("Distribución de valores en 'FAMI_TIENELAVADORA' después de imputación:")
# print(df_SaberPro['FAMI_TIENELAVADORA'].value_counts())
# Out:
# Distribución de valores en 'FAMI_TIENEAUTOMOVIL' después de imputación:
# FAMI_TIENEAUTOMOVIL
# No    706871
# Si    392610
# Name: count, dtype: int64
# Distribución de valores en 'FAMI_TIENELAVADORA' después de imputación:
# FAMI_TIENELAVADORA
# Si    946013
# No    153468
# Name: count, dtype: int64

# %%
# Con las variables FAMI_TIENECOMPUTADOR (56422 nulos) y FAMI_TIENEINTERNET (40418 nulos) se sigue la misma estrategia.

# Función para imputar valores de manera aleatoria manteniendo las proporciones
def imputar_aleatoriamente(df, columna, agrupacion):
    """
    Imputa valores nulos en la columna dada de manera aleatoria, manteniendo
    la proporción de 'Si' y 'No' en cada grupo definido por las columnas de agrupación.
    """
    # Calcular las proporciones de 'Si' y 'No' en cada grupo
    proporciones = df.groupby(agrupacion)[columna].value_counts(normalize=True).unstack().fillna(0)

    # Calcular proporciones generales como respaldo
    proporciones_generales = df[columna].value_counts(normalize=True)

    # Función para aplicar la imputación basada en la proporción del grupo
    def imputar_valor(grupo):
        try:
            if pd.isna(grupo[columna]):
                # Intentar usar la proporción específica del grupo
                prob_si = proporciones.loc[(grupo[agrupacion[0]], grupo[agrupacion[1]]), 'Si']
                return np.random.choice(['Si', 'No'], p=[prob_si, 1 - prob_si])
        except KeyError:
            # Usar proporción general en caso de que la combinación no exista
            prob_si = proporciones_generales['Si']
            return np.random.choice(['Si', 'No'], p=[prob_si, 1 - prob_si])

        return grupo[columna]

    # Aplicar la función a cada fila
    df[columna] = df.apply(imputar_valor, axis=1)
    return df

# Imputar valores en 'FAMI_TIENEAUTOMOVIL'
df_SaberPro = imputar_aleatoriamente(df_SaberPro, 'FAMI_TIENEAUTOMOVIL', ['FAMI_ESTRATOVIVIENDA', 'ESTU_COD_RESIDE_MCPIO'])

# Imputar valores en 'FAMI_TIENELAVADORA'
df_SaberPro = imputar_aleatoriamente(df_SaberPro, 'FAMI_TIENELAVADORA', ['FAMI_ESTRATOVIVIENDA', 'ESTU_COD_RESIDE_MCPIO'])

# Imputar valores en 'FAMI_TIENECOMPUTADOR'
df_SaberPro = imputar_aleatoriamente(df_SaberPro, 'FAMI_TIENECOMPUTADOR', ['FAMI_ESTRATOVIVIENDA', 'ESTU_COD_RESIDE_MCPIO'])

# Imputar valores en 'FAMI_TIENEINTERNET'
df_SaberPro = imputar_aleatoriamente(df_SaberPro, 'FAMI_TIENEINTERNET', ['FAMI_ESTRATOVIVIENDA', 'ESTU_COD_RESIDE_MCPIO'])

# Verificación de resultados
print("Distribución de valores en 'FAMI_TIENEAUTOMOVIL' después de imputación:")
print(df_SaberPro['FAMI_TIENEAUTOMOVIL'].value_counts())

print("Distribución de valores en 'FAMI_TIENELAVADORA' después de imputación:")
print(df_SaberPro['FAMI_TIENELAVADORA'].value_counts())

print("Distribución de valores en 'FAMI_TIENECOMPUTADOR' después de imputación:")
print(df_SaberPro['FAMI_TIENECOMPUTADOR'].value_counts())

print("Distribución de valores en 'FAMI_TIENEINTERNET' después de imputación:")
print(df_SaberPro['FAMI_TIENEINTERNET'].value_counts())
# Out:
# Distribución de valores en 'FAMI_TIENEAUTOMOVIL' después de imputación:
# FAMI_TIENEAUTOMOVIL
# No    706871
# Si    392610
# Name: count, dtype: int64
# Distribución de valores en 'FAMI_TIENELAVADORA' después de imputación:
# FAMI_TIENELAVADORA
# Si    946013
# No    153468
# Name: count, dtype: int64
# Distribución de valores en 'FAMI_TIENECOMPUTADOR' después de imputación:
# FAMI_TIENECOMPUTADOR
# Si    997707
# No    101774
# Name: count, dtype: int64
# Distribución de valores en 'FAMI_TIENEINTERNET' después de imputación:
# FAMI_TIENEINTERNET
# Si    978556
# No    120925
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Paso 1: Eliminar los registros nulos en MOD_COMUNI_ESCRITA_PUNT
df_SaberPro = df_SaberPro.dropna(subset=['MOD_COMUNI_ESCRITA_PUNT'])

# Paso 2: Analizar los valores únicos de MOD_COMUNI_ESCRITA_DESEM
print("Valores únicos de MOD_COMUNI_ESCRITA_DESEM:")
print(df_SaberPro['MOD_COMUNI_ESCRITA_DESEM'].unique())

# Paso 3: Visualizar la relación entre MOD_COMUNI_ESCRITA_PUNT y MOD_COMUNI_ESCRITA_DESEM
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_SaberPro, x='MOD_COMUNI_ESCRITA_DESEM', y='MOD_COMUNI_ESCRITA_PUNT')
plt.title("Distribución de MOD_COMUNI_ESCRITA_PUNT por nivel de desempeño en MOD_COMUNI_ESCRITA_DESEM")
plt.xlabel("Nivel de desempeño (MOD_COMUNI_ESCRITA_DESEM)")
plt.ylabel("Puntaje (MOD_COMUNI_ESCRITA_PUNT)")
plt.show()

# Paso 4: Calcular el rango promedio de MOD_COMUNI_ESCRITA_PUNT para cada categoría de MOD_COMUNI_ESCRITA_DESEM
desempeno_promedio = df_SaberPro.groupby('MOD_COMUNI_ESCRITA_DESEM')['MOD_COMUNI_ESCRITA_PUNT'].mean()
print("\nPromedio de MOD_COMUNI_ESCRITA_PUNT por cada nivel de desempeño:")
print(desempeno_promedio)
# Out:
# Valores únicos de MOD_COMUNI_ESCRITA_DESEM:
# [ 2.  4.  3.  1. nan]
# Promedio de MOD_COMUNI_ESCRITA_PUNT por cada nivel de desempeño:
# MOD_COMUNI_ESCRITA_DESEM
# 1.0     98.358895
# 2.0    133.181208
# 3.0    165.471589
# 4.0    205.786792
# Name: MOD_COMUNI_ESCRITA_PUNT, dtype: float64

# %% [markdown]
# La gráfica y los promedios indican que hay una relación clara y consistente entre el puntaje (MOD_COMUNI_ESCRITA_PUNT) y el nivel de desempeño (MOD_COMUNI_ESCRITA_DESEM). Los puntajes se agrupan en rangos que corresponden a cada nivel de desempeño, y los promedios aumentan de manera progresiva con cada categoría de MOD_COMUNI_ESCRITA_DESEM. Conclusión Dado que existe una correlación bien definida entre las dos variables, es razonable deducir los valores de MOD_COMUNI_ESCRITA_DESEM en función de MOD_COMUNI_ESCRITA_PUNT. Se asignan los valores nulos en MOD_COMUNI_ESCRITA_DESEM según los rangos o el promedio de MOD_COMUNI_ESCRITA_PUNT observados en cada nivel de desempeño:
#
# Desempeño 1: MOD_COMUNI_ESCRITA_PUNT aproximadamente de 50 a 120. Desempeño 2: MOD_COMUNI_ESCRITA_PUNT de 120 a 150. Desempeño 3: MOD_COMUNI_ESCRITA_PUNT de 150 a 180. Desempeño 4: MOD_COMUNI_ESCRITA_PUNT de 180 en adelante.

# %%
# Hacer una copia explícita para evitar el SettingWithCopyWarning
df_SaberPro = df_SaberPro.copy()

# Definir función para imputar valores nulos en MOD_COMUNI_ESCRITA_DESEM
def imputar_desempeno(row):
    if pd.isna(row['MOD_COMUNI_ESCRITA_DESEM']):
        puntaje = row['MOD_COMUNI_ESCRITA_PUNT']
        if puntaje < 120:
            return 1.0
        elif 120 <= puntaje < 150:
            return 2.0
        elif 150 <= puntaje < 180:
            return 3.0
        elif puntaje >= 180:
            return 4.0
    return row['MOD_COMUNI_ESCRITA_DESEM']  # Si ya tiene valor, mantenerlo

# Aplicar la función a la columna 'MOD_COMUNI_ESCRITA_DESEM'
df_SaberPro['MOD_COMUNI_ESCRITA_DESEM'] = df_SaberPro.apply(imputar_desempeno, axis=1)

# Verificar el resultado
print("Conteo de valores únicos en MOD_COMUNI_ESCRITA_DESEM después de imputar:")
print(df_SaberPro['MOD_COMUNI_ESCRITA_DESEM'].value_counts(dropna=False))
# Out:
# Conteo de valores únicos en MOD_COMUNI_ESCRITA_DESEM después de imputar:
# MOD_COMUNI_ESCRITA_DESEM
# 2.0    465564
# 3.0    340835
# 1.0    193190
# 4.0     93866
# Name: count, dtype: int64

# %% [markdown]
# Finalmente, la variable FAMI_ESTRATOVIVIENDA tiene 47280 nulos. Dado que es una variable muy relevante es preferible no eliminar estos registros. La estrategia es utilizar la asignación aleatoria condicional, utilizando (por ejemplo) la educación del padre y de la madre, el municipio, si tiene computador y si tiene internet. Para ello se debe filtrar los registros con valores conocidos (registros que tienen valores no nulos en FAMI_ESTRATOVIVIENDA) para establecer las proporciones de cada estrato, condicionado a las variables socioeconómicas seleccionadas.
#
# Calcular las Proporciones Condicionales: se calcula la probabilidad de cada estrato en función de las combinaciones de las variables condicionantes, como la educación de los padres, el municipio, y la tenencia de computador e internet.
#
# Se asignan los valores faltantes: para cada registro con un valor nulo en FAMI_ESTRATOVIVIENDA, se asigna un estrato basado en las probabilidades calculadas en el paso anterior.

# %%
# Paso 1: Filtrar los registros con valores conocidos
df_known_estrato = df_SaberPro.dropna(subset=['FAMI_ESTRATOVIVIENDA'])
df_unknown_estrato = df_SaberPro[df_SaberPro['FAMI_ESTRATOVIVIENDA'].isna()]

# Paso 2: Calcular las proporciones condicionales en base a las variables socioeconómicas seleccionadas
variables_condicionantes = ['FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE', 
                            'ESTU_COD_RESIDE_MCPIO', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET']

# Crear una tabla de proporciones condicionales
proporciones = df_known_estrato.groupby(variables_condicionantes)['FAMI_ESTRATOVIVIENDA'].value_counts(normalize=True).unstack()

# Paso 3: Función para asignar un valor de estrato basado en las proporciones condicionales
def imputar_estrato_condicional(grupo):
    # Obtener las probabilidades de cada estrato para el grupo actual
    try:
        probabilidades = proporciones.loc[(
            grupo['FAMI_EDUCACIONMADRE'], 
            grupo['FAMI_EDUCACIONPADRE'], 
            grupo['ESTU_COD_RESIDE_MCPIO'], 
            grupo['FAMI_TIENECOMPUTADOR'], 
            grupo['FAMI_TIENEINTERNET']
        )]
        # Imputar un valor basado en la distribución de probabilidad
        return np.random.choice(probabilidades.index, p=probabilidades.fillna(0))
    except KeyError:
        # Si no se encuentra la combinación en la tabla, imputar el valor más frecuente
        return df_known_estrato['FAMI_ESTRATOVIVIENDA'].mode()[0]

# Aplicar la imputación en los registros con valores nulos
df_unknown_estrato['FAMI_ESTRATOVIVIENDA'] = df_unknown_estrato.apply(imputar_estrato_condicional, axis=1)

# Combinar los registros conocidos e imputados en el DataFrame original
df_SaberPro_imputed = pd.concat([df_known_estrato, df_unknown_estrato], ignore_index=True)

# Verificar la distribución final
print("Distribución de FAMI_ESTRATOVIVIENDA después de la imputación:")
print(df_SaberPro_imputed['FAMI_ESTRATOVIVIENDA'].value_counts())
# Out:
# Distribución de FAMI_ESTRATOVIVIENDA después de la imputación:
# FAMI_ESTRATOVIVIENDA
# Estrato 2      386451
# Estrato 3      341101
# Estrato 1      195637
# Estrato 4      105591
# Estrato 5       38661
# Estrato 6       20922
# Sin Estrato      5092
# Name: count, dtype: int64

# %%
print("Resumen de tipos de datos y valores nulos en Saber11:")
print(df_Saber11.info())
print("\nResumen de tipos de datos y valores nulos en SaberPro:")
print(df_SaberPro.info())
# Out:
# Resumen de tipos de datos y valores nulos en Saber11:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4257421 entries, 1 to 7109703
# Data columns (total 47 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   COLE_AREA_UBICACION            object
#  1   COLE_BILINGUE                  object
#  2   COLE_CALENDARIO                object
#  3   COLE_COD_DANE_ESTABLECIMIENTO  float64
#  4   COLE_COD_DANE_SEDE             float64
#  5   COLE_COD_DEPTO_UBICACION       float64
#  6   COLE_COD_MCPIO_UBICACION       float64
#  7   COLE_CODIGO_ICFES              float64
#  8   COLE_DEPTO_UBICACION           object
#  9   COLE_GENERO                    object
#  10  COLE_JORNADA                   object
#  11  COLE_MCPIO_UBICACION           object
#  12  COLE_NATURALEZA                object
#  13  COLE_NOMBRE_ESTABLECIMIENTO    object
#  14  COLE_NOMBRE_SEDE               object
#  15  COLE_SEDE_PRINCIPAL            object
#  16  ESTU_COD_DEPTO_PRESENTACION    float64
#  17  ESTU_COD_MCPIO_PRESENTACION    float64
#  18  ESTU_COD_RESIDE_DEPTO          float64
#  19  ESTU_COD_RESIDE_MCPIO          float64
#  20  ESTU_DEPTO_PRESENTACION        object
#  21  ESTU_DEPTO_RESIDE              object
#  22  ESTU_ESTUDIANTE                object
#  23  ESTU_GENERO                    object
#  24  ESTU_MCPIO_PRESENTACION        object
#  25  ESTU_MCPIO_RESIDE              object
#  26  ESTU_NACIONALIDAD              object
#  27  ESTU_PAIS_RESIDE               object
#  28  ESTU_PRIVADO_LIBERTAD          object
#  29  FAMI_CUARTOSHOGAR              float64
#  30  FAMI_EDUCACIONMADRE            object
#  31  FAMI_EDUCACIONPADRE            object
#  32  FAMI_ESTRATOVIVIENDA           object
#  33  FAMI_PERSONASHOGAR             float64
#  34  FAMI_TIENEAUTOMOVIL            object
#  35  FAMI_TIENECOMPUTADOR           object
#  36  FAMI_TIENEINTERNET             object
#  37  FAMI_TIENELAVADORA             object
#  38  DESEMP_INGLES                  object
#  39  PUNT_INGLES                    object
#  40  PUNT_MATEMATICAS               object
#  41  PUNT_SOCIALES_CIUDADANAS       float64
#  42  PUNT_C_NATURALES               float64
#  43  PUNT_LECTURA_CRITICA           float64
#  44  PUNT_GLOBAL                    float64
#  45  AÑO                            int64
#  46  EDAD_EXAMEN                    float64
# dtypes: float64(16), int64(1), object(30)
# memory usage: 1.5+ GB
# None
#
# Resumen de tipos de datos y valores nulos en SaberPro:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1093455 entries, 0 to 1099480
# Data columns (total 52 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   ESTU_PAIS_RESIDE                1093455 non-null  object
#  1   ESTU_COD_RESIDE_DEPTO           1093455 non-null  float64
#  2   ESTU_DEPTO_RESIDE               1093455 non-null  object
#  3   ESTU_COD_RESIDE_MCPIO           1093455 non-null  float64
#  4   ESTU_MCPIO_RESIDE               1093455 non-null  object
#  5   ESTU_CODDANE_COLE_TERMINO       1093455 non-null  object
#  6   ESTU_COD_COLE_MCPIO_TERMINO     1093455 non-null  float64
#  7   ESTU_COD_DEPTO_PRESENTACION     1093455 non-null  float64
#  8   INST_COD_INSTITUCION            1093455 non-null  int64
#  9   INST_CARACTER_ACADEMICO         1093455 non-null  object
#  10  ESTU_NUCLEO_PREGRADO            1093455 non-null  object
#  11  ESTU_INST_DEPARTAMENTO          1093455 non-null  object
#  12  ESTU_INST_CODMUNICIPIO          1093455 non-null  int64
#  13  ESTU_INST_MUNICIPIO             1093455 non-null  object
#  14  ESTU_PRGM_ACADEMICO             1093455 non-null  object
#  15  ESTU_PRGM_DEPARTAMENTO          1093455 non-null  object
#  16  ESTU_PRGM_CODMUNICIPIO          1093455 non-null  int64
#  17  ESTU_PRGM_MUNICIPIO             1093455 non-null  object
#  18  ESTU_NIVEL_PRGM_ACADEMICO       1093455 non-null  object
#  19  ESTU_METODO_PRGM                1093455 non-null  object
#  20  ESTU_VALORMATRICULAUNIVERSIDAD  1093455 non-null  object
#  21  ESTU_DEPTO_PRESENTACION         1093455 non-null  object
#  22  ESTU_COD_MCPIO_PRESENTACION     1093455 non-null  float64
#  23  ESTU_MCPIO_PRESENTACION         1093455 non-null  object
#  24  ESTU_PAGOMATRICULABECA          1093455 non-null  object
#  25  ESTU_PAGOMATRICULACREDITO       1093455 non-null  object
#  26  ESTU_HORASSEMANATRABAJA         1093455 non-null  object
#  27  ESTU_SNIES_PRGMACADEMICO        1093455 non-null  float64
#  28  ESTU_PRIVADO_LIBERTAD           1093455 non-null  object
#  29  ESTU_NACIONALIDAD               1093455 non-null  object
#  30  ESTU_ESTUDIANTE                 1093455 non-null  object
#  31  ESTU_GENERO                     1093455 non-null  object
#  32  ESTU_COLE_TERMINO               1093455 non-null  object
#  33  ESTU_PAGOMATRICULAPADRES        1093455 non-null  object
#  34  ESTU_PAGOMATRICULAPROPIO        1093455 non-null  object
#  35  FAMI_EDUCACIONPADRE             1093455 non-null  object
#  36  FAMI_TIENEAUTOMOVIL             1093455 non-null  object
#  37  FAMI_TIENELAVADORA              1093455 non-null  object
#  38  FAMI_ESTRATOVIVIENDA            1093455 non-null  object
#  39  FAMI_TIENECOMPUTADOR            1093455 non-null  object
#  40  FAMI_TIENEINTERNET              1093455 non-null  object
#  41  FAMI_EDUCACIONMADRE             1093455 non-null  object
#  42  INST_ORIGEN                     1093455 non-null  object
#  43  MOD_RAZONA_CUANTITAT_PUNT       1093455 non-null  int64
#  44  MOD_COMUNI_ESCRITA_PUNT         1093455 non-null  float64
#  45  MOD_COMUNI_ESCRITA_DESEM        1093455 non-null  float64
#  46  MOD_INGLES_DESEM                1093455 non-null  object
#  47  MOD_LECTURA_CRITICA_PUNT        1093455 non-null  int64
#  48  MOD_INGLES_PUNT                 1093455 non-null  float64
#  49  MOD_COMPETEN_CIUDADA_PUNT       1093455 non-null  int64
#  50  AÑO                             1093455 non-null  int64
#  51  EDAD_EXAMEN                     1093455 non-null  float64
# dtypes: float64(10), int64(7), object(35)
# memory usage: 442.1+ MB
# None

# %%
# Conversión para columnas de Saber 11

# Convertir columnas de códigos de ubicación e instituciones a tipo 'object'
columnas_para_convertir = [
    'COLE_COD_DANE_ESTABLECIMIENTO', 'COLE_COD_DANE_SEDE', 
    'COLE_COD_DEPTO_UBICACION', 'COLE_COD_MCPIO_UBICACION',
    'ESTU_COD_DEPTO_PRESENTACION', 'ESTU_COD_MCPIO_PRESENTACION',
    'ESTU_COD_RESIDE_DEPTO', 'ESTU_COD_RESIDE_MCPIO',
    'COLE_CODIGO_ICFES'
]

# Convertir columnas a tipo str y verificar que cada entrada sea str
for columna in columnas_para_convertir:
    # Convertir a str explícitamente
    df_Saber11[columna] = df_Saber11[columna].astype(str)
    # Verificar que todos los elementos de la columna sean de tipo str
    if not all(isinstance(val, str) for val in df_Saber11[columna].dropna()):
        print(f"Error: La columna '{columna}' contiene valores que no son de tipo str.")
    else:
        print(f"Éxito: La columna '{columna}' contiene solo valores de tipo str.")
# Out:
# Éxito: La columna 'COLE_COD_DANE_ESTABLECIMIENTO' contiene solo valores de tipo str.
# Éxito: La columna 'COLE_COD_DANE_SEDE' contiene solo valores de tipo str.
# Éxito: La columna 'COLE_COD_DEPTO_UBICACION' contiene solo valores de tipo str.
# Éxito: La columna 'COLE_COD_MCPIO_UBICACION' contiene solo valores de tipo str.
# Éxito: La columna 'ESTU_COD_DEPTO_PRESENTACION' contiene solo valores de tipo str.
# Éxito: La columna 'ESTU_COD_MCPIO_PRESENTACION' contiene solo valores de tipo str.
# Éxito: La columna 'ESTU_COD_RESIDE_DEPTO' contiene solo valores de tipo str.
# Éxito: La columna 'ESTU_COD_RESIDE_MCPIO' contiene solo valores de tipo str.
# Éxito: La columna 'COLE_CODIGO_ICFES' contiene solo valores de tipo str.

# %%
# Conversión para columnas de Saber Pro

# Convertir columnas de códigos de ubicación e instituciones a tipo 'object'
columnas_para_convertir_pro = [
    'ESTU_COD_RESIDE_DEPTO', 'ESTU_COD_RESIDE_MCPIO', 'ESTU_COD_COLE_MCPIO_TERMINO',
    'ESTU_COD_DEPTO_PRESENTACION', 'ESTU_COD_MCPIO_PRESENTACION', 
    'ESTU_INST_CODMUNICIPIO', 'ESTU_PRGM_CODMUNICIPIO',
    'INST_COD_INSTITUCION', 'ESTU_SNIES_PRGMACADEMICO',
]
# Convertir columnas a tipo str y verificar que cada entrada sea str
for columna in columnas_para_convertir_pro:
    # Convertir a str explícitamente
    df_SaberPro_imputed[columna] = df_SaberPro_imputed[columna].astype(str)
    # Verificar que todos los elementos de la columna sean de tipo str
    if not all(isinstance(val, str) for val in df_SaberPro_imputed[columna].dropna()):
        print(f"Error: La columna '{columna}' contiene valores que no son de tipo str.")
    else:
        print(f"Éxito: La columna '{columna}' contiene solo valores de tipo str.")
# Out:
# Éxito: La columna 'ESTU_COD_RESIDE_DEPTO' contiene solo valores de tipo str.
# Éxito: La columna 'ESTU_COD_RESIDE_MCPIO' contiene solo valores de tipo str.
# Éxito: La columna 'ESTU_COD_COLE_MCPIO_TERMINO' contiene solo valores de tipo str.
# Éxito: La columna 'ESTU_COD_DEPTO_PRESENTACION' contiene solo valores de tipo str.
# Éxito: La columna 'ESTU_COD_MCPIO_PRESENTACION' contiene solo valores de tipo str.
# Éxito: La columna 'ESTU_INST_CODMUNICIPIO' contiene solo valores de tipo str.
# Éxito: La columna 'ESTU_PRGM_CODMUNICIPIO' contiene solo valores de tipo str.
# Éxito: La columna 'INST_COD_INSTITUCION' contiene solo valores de tipo str.
# Éxito: La columna 'ESTU_SNIES_PRGMACADEMICO' contiene solo valores de tipo str.

# %%
# Variables categóricas en Saber 11
for columna in df_Saber11.select_dtypes(include='object').columns:
    print(f"Frecuencia de valores en '{columna}' (Saber 11):")
    print(df_Saber11[columna].value_counts())
    print("\n")

# Variables categóricas en Saber Pro
for columna in df_SaberPro.select_dtypes(include='object').columns:
    print(f"Frecuencia de valores en '{columna}' (Saber Pro):")
    print(df_SaberPro_imputed[columna].value_counts())
    print("\n")
# Out:
# Frecuencia de valores en 'COLE_AREA_UBICACION' (Saber 11):
# COLE_AREA_UBICACION
# URBANO    3615357
# RURAL      642064
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'COLE_BILINGUE' (Saber 11):
# COLE_BILINGUE
# N                  3561554
# No especificado     623082
# S                    72785
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'COLE_CALENDARIO' (Saber 11):
# COLE_CALENDARIO
# A       4121883
# B        114513
# OTRO      21025
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'COLE_COD_DANE_ESTABLECIMIENTO' (Saber 11):
# COLE_COD_DANE_ESTABLECIMIENTO
# 105001000108.0    6569
# 105001013340.0    5343
# 313001006701.0    4183
# 176001005813.0    4163
# 111001024732.0    4155
#                   ...
# 311001106126.0       2
# 308001001633.0       1
# 376001038249.0       1
# 376001040596.0       1
# 219355001344.0       1
# Name: count, Length: 11664, dtype: int64
#
#
# Frecuencia de valores en 'COLE_COD_DANE_SEDE' (Saber 11):
# COLE_COD_DANE_SEDE
# 105001000108.0    6569
# 105001013340.0    5343
# 313001006701.0    4183
# 176001005813.0    4163
# 111001024732.0    4155
#                   ...
# 376001038249.0       1
# 219355001344.0       1
# 205055000116.0       1
# 105001002046.0       1
# 308001001633.0       1
# Name: count, Length: 13156, dtype: int64
#
#
# Frecuencia de valores en 'COLE_COD_DEPTO_UBICACION' (Saber 11):
# COLE_COD_DEPTO_UBICACION
# 11.0    684638
# 5.0     561143
# 76.0    360065
# 25.0    285977
# 8.0     238972
# 68.0    199689
# 13.0    192448
# 23.0    153936
# 52.0    128445
# 73.0    126942
# 15.0    126762
# 54.0    122442
# 47.0    121649
# 19.0    108076
# 41.0    105959
# 20.0     98725
# 50.0     91823
# 70.0     83188
# 17.0     82981
# 66.0     80900
# 44.0     62125
# 63.0     50721
# 85.0     43974
# 27.0     32930
# 18.0     32089
# 86.0     30688
# 81.0     23909
# 95.0      7302
# 91.0      5816
# 88.0      4787
# 99.0      3776
# 97.0      2601
# 94.0      1943
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'COLE_COD_MCPIO_UBICACION' (Saber 11):
# COLE_COD_MCPIO_UBICACION
# 11001.0    684638
# 5001.0     219656
# 76001.0    181944
# 8001.0     127191
# 13001.0    101211
#             ...
# 91669.0        62
# 27745.0        59
# 15114.0        36
# 94888.0        21
# 94887.0        14
# Name: count, Length: 1114, dtype: int64
#
#
# Frecuencia de valores en 'COLE_CODIGO_ICFES' (Saber 11):
# COLE_CODIGO_ICFES
# 786.0       4241
# 59.0        3395
# 67652.0     3220
# 79848.0     3081
# 164590.0    3018
#             ...
# 175885.0       1
# 190124.0       1
# 706291.0       1
# 124115.0       1
# 752667.0       1
# Name: count, Length: 20241, dtype: int64
#
#
# Frecuencia de valores en 'COLE_DEPTO_UBICACION' (Saber 11):
# COLE_DEPTO_UBICACION
# ANTIOQUIA          561143
# BOGOTA             372551
# VALLE              360065
# BOGOTÁ             312087
# CUNDINAMARCA       285977
# ATLANTICO          238972
# SANTANDER          199689
# BOLIVAR            192448
# CORDOBA            153936
# NARIÑO             128445
# TOLIMA             126942
# BOYACA             126762
# NORTE SANTANDER    122442
# MAGDALENA          121649
# CAUCA              108076
# HUILA              105959
# CESAR               98725
# META                91823
# SUCRE               83188
# CALDAS              82981
# RISARALDA           80900
# LA GUAJIRA          62125
# QUINDIO             50721
# CASANARE            43974
# CHOCO               32930
# CAQUETA             32089
# PUTUMAYO            30688
# ARAUCA              23909
# GUAVIARE             7302
# AMAZONAS             5816
# SAN ANDRES           4787
# VICHADA              3776
# VAUPES               2601
# GUAINIA              1943
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'COLE_GENERO' (Saber 11):
# COLE_GENERO
# MIXTO        4100850
# FEMENINO      119369
# MASCULINO      37202
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'COLE_JORNADA' (Saber 11):
# COLE_JORNADA
# MAÑANA      2018237
# COMPLETA     802874
# TARDE        521348
# UNICA        436735
# SABATINA     248822
# NOCHE        229405
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'COLE_MCPIO_UBICACION' (Saber 11):
# COLE_MCPIO_UBICACION
# BOGOTÁ D.C.      684638
# CALI             181944
# BARRANQUILLA     127191
# MEDELLIN         113603
# MEDELLÍN         106053
#                   ...
# MORICHAL             21
# PTO SANTANDER        18
# PANA PANA            14
# BUSBANZA             12
# SIPI                  9
# Name: count, Length: 1410, dtype: int64
#
#
# Frecuencia de valores en 'COLE_NATURALEZA' (Saber 11):
# COLE_NATURALEZA
# OFICIAL       3133718
# NO OFICIAL    1123703
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'COLE_NOMBRE_ESTABLECIMIENTO' (Saber 11):
# COLE_NOMBRE_ESTABLECIMIENTO
# INSTITUCION EDUCATIVA SAN JOSE                    10378
# INSTITUCION EDUCATIVA SIMON BOLIVAR                9824
# INSTITUCION EDUCATIVA JORGE ELIECER GAITAN         9381
# INSTITUCION EDUCATIVA FRANCISCO JOSE DE CALDAS     8074
# INSTITUCION EDUCATIVA ALFONSO LOPEZ PUMAREJO       7983
#                                                   ...
# COLEGIO SEMILLA DE MOSTAZA                            1
# INSTITUCION EDUCATIVA ISXIWE´SX YAAKNXI               1
# CORPORACION EDUCATIVA Y TECNICA BOLIVARIANA           1
# CENTRO DE ESTUDIOS FUTUROS                            1
# CENTRO EDUCATIVO PUMBI LAS LAJAS                      1
# Name: count, Length: 11130, dtype: int64
#
#
# Frecuencia de valores en 'COLE_NOMBRE_SEDE' (Saber 11):
# COLE_NOMBRE_SEDE
# INSTITUTO TECNICO INDUSTRIAL                                             6268
# SEDE PRINCIPAL                                                           5747
# INST EDUC CEFA                                                           5577
# JORGE ELIECER GAITAN                                                     5559
# INST EDUC INEM JOSE FELIX DE RESTREPO                                    5343
#                                                                          ...
# CENTRO EDUCATIVO PUMBI LAS LAJAS                                            1
# SEC ESC MARCO FIDEL SUAREZ                                                  1
# FUNDACION EDUCATIVA Y TECNICA HACIA EL PROGRESO INDUSTRIAL - FUNDETEC       1
# LEGIO SEMILLA DE MOSTAZA  - SEDE PRINCIPAL                                  1
# FUND P LA PREVENC Y REHAB INTEGRAL- CINDES                                  1
# Name: count, Length: 15515, dtype: int64
#
#
# Frecuencia de valores en 'COLE_SEDE_PRINCIPAL' (Saber 11):
# COLE_SEDE_PRINCIPAL
# S    4109487
# N     147934
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_COD_DEPTO_PRESENTACION' (Saber 11):
# ESTU_COD_DEPTO_PRESENTACION
# 11.0    696968
# 5.0     561954
# 76.0    361578
# 25.0    269617
# 8.0     243948
# 68.0    198670
# 13.0    185141
# 23.0    153416
# 15.0    129844
# 52.0    128912
# 73.0    124666
# 54.0    123073
# 47.0    120994
# 41.0    106885
# 19.0    106160
# 20.0     99634
# 50.0     91570
# 17.0     86977
# 70.0     83065
# 66.0     79598
# 44.0     62177
# 63.0     49933
# 85.0     44872
# 18.0     32484
# 27.0     32277
# 86.0     30980
# 81.0     25017
# 95.0      7892
# 91.0      5837
# 88.0      4876
# 99.0      3842
# 97.0      2608
# 94.0      1956
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_COD_MCPIO_PRESENTACION' (Saber 11):
# ESTU_COD_MCPIO_PRESENTACION
# 11001.0    696968
# 5001.0     210241
# 76001.0    185269
# 8001.0     143518
# 13001.0    109994
#             ...
# 25743.0        48
# 94663.0        41
# 94883.0        18
# 94888.0        15
# 94887.0        14
# Name: count, Length: 518, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_COD_RESIDE_DEPTO' (Saber 11):
# ESTU_COD_RESIDE_DEPTO
# 11.0       693409
# 5.0        561888
# 76.0       360478
# 25.0       276469
# 8.0        238548
# 68.0       197487
# 13.0       192018
# 23.0       154121
# 52.0       128661
# 73.0       127772
# 15.0       127151
# 54.0       122513
# 47.0       121950
# 19.0       108101
# 41.0       106188
# 20.0        98605
# 50.0        91600
# 17.0        83590
# 70.0        83245
# 66.0        80751
# 44.0        62239
# 63.0        50165
# 85.0        44181
# 27.0        33025
# 18.0        31934
# 86.0        30741
# 81.0        24013
# 95.0         7266
# 91.0         5850
# 88.0         4853
# 99.0         3802
# 97.0         2609
# 94.0         1950
# 99999.0       248
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_COD_RESIDE_MCPIO' (Saber 11):
# ESTU_COD_RESIDE_MCPIO
# 11001.0    693409
# 5001.0     217025
# 76001.0    181464
# 8001.0     129107
# 13001.0    101845
#             ...
# 94887.0        14
# 91430.0         3
# 94886.0         2
# 94885.0         1
# 91530.0         1
# Name: count, Length: 1121, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_DEPTO_PRESENTACION' (Saber 11):
# ESTU_DEPTO_PRESENTACION
# BOGOTÁ             696968
# ANTIOQUIA          561954
# VALLE              361578
# CUNDINAMARCA       269617
# ATLANTICO          243948
# SANTANDER          198670
# BOLIVAR            185141
# CORDOBA            153416
# BOYACA             129844
# NARIÑO             128912
# TOLIMA             124666
# NORTE SANTANDER    123073
# MAGDALENA          120994
# HUILA              106885
# CAUCA              106160
# CESAR               99634
# META                91570
# CALDAS              86977
# SUCRE               83065
# RISARALDA           79598
# LA GUAJIRA          62177
# QUINDIO             49933
# CASANARE            44872
# CAQUETA             32484
# CHOCO               32277
# PUTUMAYO            30980
# ARAUCA              25017
# GUAVIARE             7892
# AMAZONAS             5837
# SAN ANDRES           4876
# VICHADA              3842
# VAUPES               2608
# GUAINIA              1956
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_DEPTO_RESIDE' (Saber 11):
# ESTU_DEPTO_RESIDE
# BOGOTÁ             693409
# ANTIOQUIA          561888
# VALLE              360478
# CUNDINAMARCA       276469
# ATLANTICO          238548
# SANTANDER          197487
# BOLIVAR            192018
# CORDOBA            154121
# NARIÑO             128661
# TOLIMA             127772
# BOYACA             127151
# NORTE SANTANDER    122513
# MAGDALENA          121950
# CAUCA              108101
# HUILA              106188
# CESAR               98605
# META                91600
# CALDAS              83590
# SUCRE               83245
# RISARALDA           80751
# LA GUAJIRA          62239
# QUINDIO             50165
# CASANARE            44181
# CHOCO               33025
# CAQUETA             31934
# PUTUMAYO            30741
# ARAUCA              24013
# GUAVIARE             7266
# AMAZONAS             5850
# SAN ANDRES           4853
# VICHADA              3802
# VAUPES               2609
# GUAINIA              1950
# EXTRANJERO            248
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_ESTUDIANTE' (Saber 11):
# ESTU_ESTUDIANTE
# ESTUDIANTE    4257421
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_GENERO' (Saber 11):
# ESTU_GENERO
# F    2312929
# M    1944492
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_MCPIO_PRESENTACION' (Saber 11):
# ESTU_MCPIO_PRESENTACION
# BOGOTÁ D.C.            696968
# MEDELLÍN               210241
# CALI                   185269
# BARRANQUILLA           143518
# CARTAGENA DE INDIAS    109994
#                         ...
# SILVANIA                   48
# MAPIRIPANA                 41
# SAN FELIPE                 18
# MORICHAL                   15
# PANA PANA                  14
# Name: count, Length: 502, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_MCPIO_RESIDE' (Saber 11):
# ESTU_MCPIO_RESIDE
# BOGOTÁ D.C.            693409
# MEDELLÍN               217025
# CALI                   181464
# BARRANQUILLA           129107
# CARTAGENA DE INDIAS    101845
#                         ...
# MORICHAL                   21
# PANA PANA                  14
# CACAHUAL                    2
# LA GUADALUPE                1
# PUERTO ALEGRÍA              1
# Name: count, Length: 1037, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_NACIONALIDAD' (Saber 11):
# ESTU_NACIONALIDAD
# COLOMBIA                                    4240447
# VENEZUELA                                     14773
# ESTADOS UNIDOS                                  476
# ECUADOR                                         280
# ESPAÑA                                          279
#                                              ...
# BURUNDI                                           1
# ANGOLA                                            1
# LAOS - REPÚBLICA DEMOCRÁTICA POPULAR LAO          1
# ANDORRA                                           1
# ISRAEL                                            1
# Name: count, Length: 90, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_PAIS_RESIDE' (Saber 11):
# ESTU_PAIS_RESIDE
# COLOMBIA                                    4240447
# VENEZUELA                                     14773
# ESTADOS UNIDOS                                  476
# ECUADOR                                         280
# ESPAÑA                                          279
#                                              ...
# BURUNDI                                           1
# ANGOLA                                            1
# LAOS - REPÚBLICA DEMOCRÁTICA POPULAR LAO          1
# ANDORRA                                           1
# ISRAEL                                            1
# Name: count, Length: 90, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_PRIVADO_LIBERTAD' (Saber 11):
# ESTU_PRIVADO_LIBERTAD
# N    4257229
# S        192
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'FAMI_EDUCACIONMADRE' (Saber 11):
# FAMI_EDUCACIONMADRE
# Secundaria (Bachillerato) completa      1152408
# Secundaria (Bachillerato) incompleta     632979
# Primaria incompleta                      620502
# Primaria completa                        507679
# Educación profesional completa           460984
# Técnica o tecnológica completa           389653
# Técnica o tecnológica incompleta         119111
# Postgrado                                104885
# Educación profesional incompleta          95084
# Ninguno                                   90964
# No sabe                                   77790
# No Aplica                                  5382
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'FAMI_EDUCACIONPADRE' (Saber 11):
# FAMI_EDUCACIONPADRE
# Secundaria (Bachillerato) completa      1005680
# Primaria incompleta                      771762
# Secundaria (Bachillerato) incompleta     593589
# Primaria completa                        518355
# Educación profesional completa           400928
# Técnica o tecnológica completa           270444
# No sabe                                  237348
# Ninguno                                  166892
# Postgrado                                 98232
# Técnica o tecnológica incompleta          85413
# Educación profesional incompleta          76508
# No Aplica                                 32270
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'FAMI_ESTRATOVIVIENDA' (Saber 11):
# FAMI_ESTRATOVIVIENDA
# Estrato 1      1499240
# Estrato 2      1493698
# Estrato 3       840295
# Estrato 4       210769
# Sin Estrato      87343
# Estrato 5        79148
# Estrato 6        46928
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'FAMI_TIENEAUTOMOVIL' (Saber 11):
# FAMI_TIENEAUTOMOVIL
# No    3223723
# Si    1033698
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'FAMI_TIENECOMPUTADOR' (Saber 11):
# FAMI_TIENECOMPUTADOR
# Si    2504019
# No    1753402
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'FAMI_TIENEINTERNET' (Saber 11):
# FAMI_TIENEINTERNET
# Si    2588462
# No    1668959
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'FAMI_TIENELAVADORA' (Saber 11):
# FAMI_TIENELAVADORA
# Si    3132019
# No    1125402
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'DESEMP_INGLES' (Saber 11):
# DESEMP_INGLES
# A-    1946365
# A1    1301160
# A2     584097
# B1     311971
# B+     113828
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'PUNT_INGLES' (Saber 11):
# PUNT_INGLES
# 49.0    172619
# 44.0    170469
# 52.0    148931
# 43.0    145835
# 41.0    144400
#          ...
# 17.0         1
# 15           1
# 98           1
# 19           1
# 6            1
# Name: count, Length: 178, dtype: int64
#
#
# Frecuencia de valores en 'PUNT_MATEMATICAS' (Saber 11):
# PUNT_MATEMATICAS
# 50.0    150874
# 52.0    146754
# 47.0    145644
# 55.0    142688
# 49.0    139074
#          ...
# 11.0         3
# 2.0          2
# 10.0         2
# 7            2
# 14           1
# Name: count, Length: 187, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_PAIS_RESIDE' (Saber Pro):
# ESTU_PAIS_RESIDE
# COLOMBIA             1091374
# VENEZUELA                830
# PERÚ                     143
# ECUADOR                  138
# FRANCIA                  111
#                       ...
# UGANDA                     1
# SANTA LUCÍA                1
# ALBANIA                    1
# ANTIGUA Y BARBUDA          1
# MARRUECOS                  1
# Name: count, Length: 80, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_DEPTO_RESIDE' (Saber Pro):
# ESTU_DEPTO_RESIDE
# BOGOTÁ               297057
# ANTIOQUIA            130770
# VALLE                 84623
# CUNDINAMARCA          69037
# ATLANTICO             63110
# SANTANDER             52824
# BOLIVAR               34914
# NORTE SANTANDER       33302
# BOYACA                29670
# TOLIMA                28611
# NARIÑO                27140
# CORDOBA               26356
# HUILA                 24098
# RISARALDA             22121
# META                  21994
# CALDAS                20733
# CAUCA                 20418
# CESAR                 19651
# MAGDALENA             17511
# SUCRE                 14670
# QUINDIO               12351
# LA GUAJIRA            11285
# CHOCO                  7654
# CASANARE               7095
# CAQUETA                6144
# PUTUMAYO               4279
# ARAUCA                 3189
# GUAVIARE                819
# SAN ANDRES              711
# EXTRANJERO              363
# VICHADA                 303
# AMAZONAS                279
# VAUPES                  196
# GUAINIA                 159
# FRANKFURT                 2
# ROMA                      2
# MIAMI                     2
# PARIS                     1
# SACRAMENTO                1
# LIMA                      1
# ATLANTA                   1
# SANTIAGO DE CHILE         1
# TRENTON                   1
# BARCELONA                 1
# QUEBEC                    1
# MADRID                    1
# SAO PAULO                 1
# BUENOS AIRES              1
# SEUL                      1
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_MCPIO_RESIDE' (Saber Pro):
# ESTU_MCPIO_RESIDE
# BOGOTÁ D.C.            297057
# MEDELLÍN                68896
# CALI                    51626
# BARRANQUILLA            41882
# CARTAGENA DE INDIAS     27210
#                         ...
# TRENTON                     1
# BARCELONA                   1
# SAO PAULO                   1
# TAMBORA                     1
# SEUL                        1
# Name: count, Length: 1040, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_CODDANE_COLE_TERMINO' (Saber Pro):
# ESTU_CODDANE_COLE_TERMINO
# NO DEFINIDO       347973
# 105001000108.0      2805
# 105001013340.0      1954
# 305001004293.0      1583
# 111001024732.0      1425
#                    ...
# 244430003562.0         1
# 273686000261.0         1
# 213473000206.0         1
# 270429000146.0         1
# 315176001144.0         1
# Name: count, Length: 12411, dtype: int64
#
#
# Frecuencia de valores en 'INST_CARACTER_ACADEMICO' (Saber Pro):
# INST_CARACTER_ACADEMICO
# UNIVERSIDAD                  672001
# INSTITUCIÓN UNIVERSITARIA    381353
# TÉCNICA PROFESIONAL           21850
# INSTITUCIÓN TECNOLÓGICA       18251
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_NUCLEO_PREGRADO' (Saber Pro):
# ESTU_NUCLEO_PREGRADO
# ADMINISTRACIÓN                                           222304
# EDUCACIÓN                                                 95917
# DERECHO Y AFINES                                          81442
# CONTADURÍA PUBLICA                                        80305
# PSICOLOGÍA                                                77460
# INGENIERÍA INDUSTRIAL Y AFINES                            60045
# INGENIERÍA DE SISTEMAS, TELEMÁTICA Y AFINES               42129
# INGENIERÍA CIVIL Y AFINES                                 37825
# MEDICINA                                                  31797
# SOCIOLOGÍA, TRABAJO SOCIAL Y AFINES                       29189
# COMUNICACIÓN SOCIAL, PERIODISMO Y AFINES                  28309
# INGENIERÍA AMBIENTAL, SANITARIA Y AFINES                  24683
# ARQUITECTURA                                              24293
# ECONOMÍA                                                  23349
# ENFERMERÍA                                                20119
# INGENIERÍA MECÁNICA Y AFINES                              17812
# INGENIERÍA ELECTRÓNICA, TELECOMUNICACIONES Y AFINES       16824
# DISEÑO                                                    15918
# TERAPIAS                                                  15362
# MEDICINA VETERINARIA                                       8902
# SALUD PUBLICA                                              8505
# ODONTOLOGÍA                                                8175
# BIOLOGÍA, MICROBIOLOGÍA Y AFINES                           7697
# INGENIERÍA QUÍMICA Y AFINES                                7575
# CIENCIA POLÍTICA, RELACIONES INTERNACIONALES               7244
# INGENIERÍA ELÉCTRICA Y AFINES                              6581
# DEPORTES, EDUCACIÓN FÍSICA Y RECREACIÓN                    6482
# INGENIERÍA AGROINDUSTRIAL, ALIMENTOS Y AFINES              5685
# ARTES PLÁSTICAS, VISUALES Y AFINES                         5452
# QUÍMICA Y AFINES                                           4734
# INGENIERÍA AGRONÓMICA, PECUARIA Y AFINES                   4561
# OTRAS INGENIERÍAS                                          4556
# LENGUAS MODERNAS, LITERATURA, LINGÜÍSTICA Y AFINES         4212
# NUTRICIÓN Y DIETÉTICA                                      4026
# INGENIERÍA ADMINISTRATIVA Y AFINES                         3663
# PUBLICIDAD Y AFINES                                        3585
# INGENIERÍA BIOMÉDICA Y AFINES                              3442
# ZOOTECNIA                                                  3342
# MÚSICA                                                     3265
# BACTERIOLOGÍA                                              3250
# FORMACIÓN RELACIONADA CON EL CAMPO MILITAR O POLICIAL      3243
# INSTRUMENTACIÓN QUIRÚRGICA                                 3240
# INGENIERÍA DE MINAS, METALURGIA Y AFINES                   3071
# INGENIERÍA AGRÍCOLA, FORESTAL Y AFINES                     2721
# GEOGRAFÍA, HISTORIA                                        2451
# MATEMÁTICAS, ESTADÍSTICA Y AFINES                          2403
# FILOSOFÍA, TEOLOGÍA Y AFINES                               2301
# AGRONOMÍA                                                  2081
# ANTROPOLOGÍA, ARTES LIBERALES                              1827
# BIBLIOTECOLOGÍA, OTROS DE CIENCIAS SOCIALES Y HUMANAS      1826
# OPTOMETRÍA, OTROS PROGRAMAS DE CIENCIAS DE LA SALUD        1764
# SIN CLASIFICAR                                             1742
# GEOLOGÍA, OTROS PROGRAMAS DE CIENCIAS NATURALES            1632
# FÍSICA                                                     1244
# ARTES REPRESENTATIVAS                                      1149
# OTROS PROGRAMAS ASOCIADOS A BELLAS ARTES                    744
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_INST_DEPARTAMENTO' (Saber Pro):
# ESTU_INST_DEPARTAMENTO
# BOGOTÁ             485783
# ANTIOQUIA          127891
# ATLANTICO           69235
# VALLE               64434
# SANTANDER           48836
# BOLIVAR             31789
# NORTE SANTANDER     29945
# BOYACA              21940
# NARIÑO              19512
# TOLIMA              18127
# CUNDINAMARCA        17949
# RISARALDA           17681
# CORDOBA             17081
# CALDAS              16631
# MAGDALENA           15515
# CAUCA               15215
# SUCRE               14426
# QUINDIO             13651
# HUILA               11515
# CESAR                9912
# LA GUAJIRA           7940
# CHOCO                7659
# META                 4647
# CAQUETA              4194
# CASANARE              987
# PUTUMAYO              960
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_INST_MUNICIPIO' (Saber Pro):
# ESTU_INST_MUNICIPIO
# BOGOTÁ D.C.            485783
# MEDELLÍN               112758
# BARRANQUILLA            68361
# CALI                    56955
# BUCARAMANGA             42170
#                         ...
# CARTAGO                   100
# APARTADÓ                   82
# GUADALAJARA DE BUGA        78
# PUERTO BERRÍO              33
# SAN JUAN DEL CESAR          2
# Name: count, Length: 61, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_PRGM_ACADEMICO' (Saber Pro):
# ESTU_PRGM_ACADEMICO
# ADMINISTRACION DE EMPRESAS                                                                 79122
# DERECHO                                                                                    77663
# CONTADURIA PUBLICA                                                                         60397
# PSICOLOGIA                                                                                 50727
# INGENIERIA INDUSTRIAL                                                                      45538
#                                                                                            ...
# LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN HUMANIDADES Y LENGUAS EXTRANJERA-INGLES        1
# LICENCIATURA EN RECREACIÓN  Y TURISMO                                                          1
# MATEM¿TICA APLICADA                                                                            1
# DISEÑO DE MODAS Y ALTA COSTURA                                                                 1
# LICENCIATURA EN EDUCACIÓN BÁSICA CON ÉNFASIS EN HUMANIDADES: ESPAÑOL E INGLÉS                  1
# Name: count, Length: 1007, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_PRGM_DEPARTAMENTO' (Saber Pro):
# ESTU_PRGM_DEPARTAMENTO
# BOGOTÁ             436124
# ANTIOQUIA          130230
# VALLE               70485
# ATLANTICO           66379
# SANTANDER           45822
# NORTE SANTANDER     36344
# BOLIVAR             33458
# BOYACA              23403
# CUNDINAMARCA        22962
# NARIÑO              21559
# CORDOBA             20582
# RISARALDA           20352
# TOLIMA              19299
# CALDAS              18520
# CAUCA               17812
# HUILA               16616
# MAGDALENA           15072
# SUCRE               14129
# CESAR               13622
# META                13165
# QUINDIO             12702
# LA GUAJIRA           7950
# CHOCO                7305
# CAQUETA              4351
# CASANARE             2950
# PUTUMAYO             1246
# ARAUCA                913
# AMAZONAS               43
# GUAVIARE               34
# VAUPES                 20
# SAN ANDRES              6
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_PRGM_MUNICIPIO' (Saber Pro):
# ESTU_PRGM_MUNICIPIO
# BOGOTÁ D.C.      436124
# MEDELLÍN         109929
# BARRANQUILLA      65366
# CALI              56463
# BUCARAMANGA       38637
#                   ...
# LÉRIDA                1
# ANAPOIMA              1
# FUNDACIÓN             1
# MARÍA LA BAJA         1
# AGUADAS               1
# Name: count, Length: 158, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_NIVEL_PRGM_ACADEMICO' (Saber Pro):
# ESTU_NIVEL_PRGM_ACADEMICO
# UNIVERSITARIO    1093455
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_METODO_PRGM' (Saber Pro):
# ESTU_METODO_PRGM
# PRESENCIAL          874956
# DISTANCIA           155699
# DISTANCIA VITUAL     62800
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_VALORMATRICULAUNIVERSIDAD' (Saber Pro):
# ESTU_VALORMATRICULAUNIVERSIDAD
# Entre 1 millón y menos de 2.5 millones      303666
# Entre 2.5 millones y menos de 4 millones    201267
# Menos de 500 mil                            125801
# Más de 7 millones                           119576
# Entre 4 millones y menos de 5.5 millones    116902
# Entre 500 mil y menos de 1 millón           115696
# Entre 5.5 millones y menos de 7 millones     64630
# No pagó matrícula                            45917
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_DEPTO_PRESENTACION' (Saber Pro):
# ESTU_DEPTO_PRESENTACION
# BOGOTÁ                     670925
# ANTIOQUIA                   63329
# VALLE                       42766
# ATLANTICO                   37800
# CUNDINAMARCA                29646
#                             ...
# MONTEVIDEO                      2
# AUCKLAND                        2
# SAN JUAN DE PUERTO RICO         2
# SANTO DOMINGO                   2
# LA HABANA                       1
# Name: count, Length: 74, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_MCPIO_PRESENTACION' (Saber Pro):
# ESTU_MCPIO_PRESENTACION
# BOGOTÁ D.C.                670925
# MEDELLÍN                    38102
# BARRANQUILLA                34686
# CALI                        28896
# BUCARAMANGA                 19847
#                             ...
# MONTEVIDEO                      2
# SAN JUAN DE PUERTO RICO         2
# SANTO DOMINGO                   2
# LA HABANA                       1
# NILO                            1
# Name: count, Length: 160, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_PAGOMATRICULABECA' (Saber Pro):
# ESTU_PAGOMATRICULABECA
# No    862249
# Si    231206
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_PAGOMATRICULACREDITO' (Saber Pro):
# ESTU_PAGOMATRICULACREDITO
# No    747988
# Si    345467
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_HORASSEMANATRABAJA' (Saber Pro):
# ESTU_HORASSEMANATRABAJA
# Más de 30 horas        400276
# 0                      204554
# Entre 11 y 20 horas    190975
# Entre 21 y 30 horas    149886
# Menos de 10 horas      147764
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_PRIVADO_LIBERTAD' (Saber Pro):
# ESTU_PRIVADO_LIBERTAD
# N    1093446
# S          9
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_NACIONALIDAD' (Saber Pro):
# ESTU_NACIONALIDAD
# COLOMBIA             1091374
# VENEZUELA                830
# PERÚ                     143
# ECUADOR                  138
# FRANCIA                  111
#                       ...
# UGANDA                     1
# SANTA LUCÍA                1
# ALBANIA                    1
# ANTIGUA Y BARBUDA          1
# MARRUECOS                  1
# Name: count, Length: 80, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_ESTUDIANTE' (Saber Pro):
# ESTU_ESTUDIANTE
# ESTUDIANTE    1093455
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_GENERO' (Saber Pro):
# ESTU_GENERO
# F    649670
# M    443785
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_COLE_TERMINO' (Saber Pro):
# ESTU_COLE_TERMINO
# NO DEFINIDO                                                   326721
# 0                                                              21252
# INSTITUCION EDUCATIVA CENTRO FORMATIVO DE ANTIOQUIA - CEFA      2220
# INST EDUC INEM JOSE FELIX DE RESTREPO                           1479
# INSTITUTO TECNICO INDUSTRIAL                                    1443
#                                                                ...
# 913                                                                1
# 18007                                                              1
# 19267                                                              1
# 10359                                                              1
# COLEGIO DEPARTAMENTAL AGROPECUARIO DE VILLAFÁTIMA                  1
# Name: count, Length: 25665, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_PAGOMATRICULAPADRES' (Saber Pro):
# ESTU_PAGOMATRICULAPADRES
# Si    571901
# No    521554
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'ESTU_PAGOMATRICULAPROPIO' (Saber Pro):
# ESTU_PAGOMATRICULAPROPIO
# No    571901
# Si    521554
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'FAMI_EDUCACIONPADRE' (Saber Pro):
# FAMI_EDUCACIONPADRE
# Secundaria (Bachillerato) completa      216862
# Primaria incompleta                     196357
# Educación profesional completa          139967
# Secundaria (Bachillerato) incompleta    114440
# Técnica o tecnológica completa          107609
# Primaria completa                        86608
# Postgrado                                75583
# Educación profesional incompleta         45585
# Técnica o tecnológica incompleta         36472
# Ninguno                                  30600
# No sabe                                  28546
# No Aplica                                14826
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'FAMI_TIENEAUTOMOVIL' (Saber Pro):
# FAMI_TIENEAUTOMOVIL
# No    702916
# Si    390539
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'FAMI_TIENELAVADORA' (Saber Pro):
# FAMI_TIENELAVADORA
# Si    940985
# No    152470
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'FAMI_ESTRATOVIVIENDA' (Saber Pro):
# FAMI_ESTRATOVIVIENDA
# Estrato 2      386451
# Estrato 3      341101
# Estrato 1      195637
# Estrato 4      105591
# Estrato 5       38661
# Estrato 6       20922
# Sin Estrato      5092
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'FAMI_TIENECOMPUTADOR' (Saber Pro):
# FAMI_TIENECOMPUTADOR
# Si    992364
# No    101091
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'FAMI_TIENEINTERNET' (Saber Pro):
# FAMI_TIENEINTERNET
# Si    973589
# No    119866
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'FAMI_EDUCACIONMADRE' (Saber Pro):
# FAMI_EDUCACIONMADRE
# Secundaria (Bachillerato) completa      237949
# Técnica o tecnológica completa          155448
# Primaria incompleta                     149885
# Educación profesional completa          147231
# Secundaria (Bachillerato) incompleta    128821
# Primaria completa                        85260
# Postgrado                                80322
# Técnica o tecnológica incompleta         45222
# Educación profesional incompleta         36786
# Ninguno                                  19055
# No sabe                                   4770
# No Aplica                                 2706
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'INST_ORIGEN' (Saber Pro):
# INST_ORIGEN
# NO OFICIAL - CORPORACIÓN    384492
# NO OFICIAL - FUNDACIÓN      345413
# OFICIAL NACIONAL            170307
# OFICIAL DEPARTAMENTAL       168702
# OFICIAL MUNICIPAL            23761
# REGIMEN ESPECIAL               780
# Name: count, dtype: int64
#
#
# Frecuencia de valores en 'MOD_INGLES_DESEM' (Saber Pro):
# MOD_INGLES_DESEM
# A2     420421
# B1     242745
# A1     222750
# B2     113099
# -A1     94440
# Name: count, dtype: int64

# %% [markdown]
# Comentarios sobre la Distribución de Variables Categóricas
#
# Variables con solo un valor o alta concentración en una categoría:
#
# ESTU_ESTUDIANTE en Saber 11, ESTU_NACIONALIDAD y ESTU_PAIS_RESIDE solo tienen un valor, por lo que se van a aliminar.
#
# INST_ORIGEN en Saber Pro muestra mayor proporción de "NO OFICIAL - CORPORACIÓN" y "NO OFICIAL - FUNDACIÓN". Los registros de CORPORACIÓN Y DE FUNDACIÓN se pueden unir en una sola categoría "NO OFICIAL". Por otro lado, el valor "REGIMEN ESPECIAL" tiene muy pocos registros y se pueden eliminar todos ellos. Finalmente, los valores "OFICIAL NACIONAL", "OFICIAL DEPARTAMENTAL" y "OFICIAL MUNICIPAL" se pueden volver un solo valor: "OFICIAL".

# %%
# Se implementan las observaciones pertinentes descritas en el punto anterior.

# 1. Eliminar columnas en Saber 11 que solo tienen un valor
df_Saber11.drop(columns=['ESTU_ESTUDIANTE', 'ESTU_NACIONALIDAD', 'ESTU_PAIS_RESIDE'], inplace=True)

# 2. Modificar la columna INST_ORIGEN en Saber Pro
# Unificar "NO OFICIAL - CORPORACIÓN" y "NO OFICIAL - FUNDACIÓN" en una sola categoría "NO OFICIAL"
df_SaberPro['INST_ORIGEN'] = df_SaberPro['INST_ORIGEN'].replace(
    ['NO OFICIAL - CORPORACIÓN', 'NO OFICIAL - FUNDACIÓN'],
    'NO OFICIAL'
)

# Eliminar registros donde INST_ORIGEN tiene el valor "REGIMEN ESPECIAL"
df_SaberPro = df_SaberPro[df_SaberPro['INST_ORIGEN'] != 'REGIMEN ESPECIAL']

# Unificar "OFICIAL NACIONAL", "OFICIAL DEPARTAMENTAL" y "OFICIAL MUNICIPAL" en una sola categoría "OFICIAL"
df_SaberPro['INST_ORIGEN'] = df_SaberPro['INST_ORIGEN'].replace(
    ['OFICIAL NACIONAL', 'OFICIAL DEPARTAMENTAL', 'OFICIAL MUNICIPAL'],
    'OFICIAL'
)

# Verificar resultados
print("Columnas eliminadas en df_Saber11:")
print(df_Saber11.head())  # Confirma que las columnas fueron eliminadas

print("\nValores únicos en INST_ORIGEN de df_SaberPro después de las modificaciones:")
print(df_SaberPro['INST_ORIGEN'].value_counts())  # Confirma las categorías en INST_ORIGEN
# Out:
# Columnas eliminadas en df_Saber11:
#   COLE_AREA_UBICACION COLE_BILINGUE COLE_CALENDARIO  \
# 1               RURAL             N               A
# 2               RURAL             N               A
# 5              URBANO             N               A
# 6              URBANO             N               A
# 7              URBANO             N               A
#
#   COLE_COD_DANE_ESTABLECIMIENTO COLE_COD_DANE_SEDE COLE_COD_DEPTO_UBICACION  \
# 1                141016000305.0     241016000342.0                     41.0
# 2                141016000305.0     241016000342.0                     41.0
# 5                141396000175.0     141396000175.0                     41.0
# 6                141396000175.0     141396000175.0                     41.0
# 7                176001013310.0     176001013310.0                     76.0
#
#   COLE_COD_MCPIO_UBICACION COLE_CODIGO_ICFES COLE_DEPTO_UBICACION COLE_GENERO  \
# 1                  41016.0          194878.0                HUILA       MIXTO
# 2                  41016.0          194878.0                HUILA       MIXTO
# 5                  41396.0           10066.0                HUILA       MIXTO
# 6                  41396.0           10066.0                HUILA       MIXTO
# 7                  76001.0           17632.0                VALLE       MIXTO
#
#    ... FAMI_TIENELAVADORA DESEMP_INGLES PUNT_INGLES PUNT_MATEMATICAS  \
# 1  ...                 Si            B1        71.0             66.0
# 2  ...                 Si            B1        71.0             66.0
# 5  ...                 No            A-        46.0             43.0
# 6  ...                 No            A-        46.0             43.0
# 7  ...                 Si            A2        59.0             57.0
#
#   PUNT_SOCIALES_CIUDADANAS PUNT_C_NATURALES PUNT_LECTURA_CRITICA PUNT_GLOBAL  \
# 1                     70.0             65.0                 69.0       339.0
# 2                     70.0             65.0                 69.0       339.0
# 5                     31.0             40.0                 43.0       199.0
# 6                     31.0             40.0                 43.0       199.0
# 7                     46.0             57.0                 57.0       272.0
#
#     AÑO EDAD_EXAMEN
# 1  2019        16.0
# 2  2019        16.0
# 5  2019        17.0
# 6  2019        17.0
# 7  2016        16.0
#
# [5 rows x 44 columns]
#
# Valores únicos en INST_ORIGEN de df_SaberPro después de las modificaciones:
# INST_ORIGEN
# NO OFICIAL    729905
# OFICIAL       362770
# Name: count, dtype: int64

# %% [markdown]
# Inconsistencias en los nombres de municipios y departamentos:
#
# Algunos municipios como BOGOTÁ aparecen en mayúsculas y otros en minúsculas, como en COLE_MCPIO_UBICACION. Esto podría unificarse para evitar duplicación de categorías y errores en el análisis. Hay que revisar las inconsistencias en nombres también en Saber 11 y en Saber Pro para mantener la uniformidad en las variables relacionadas con la ubicación.
#
# Variables categóricas extensas:
#
# Algunas categorías, como COLE_COD_DANE_ESTABLECIMIENTO y ESTU_PRGM_ACADEMICO, tienen una gran cantidad de valores únicos, lo cual puede complicar el análisis. Se puede considerar agrupar ciertos códigos o especializaciones si resultan muy específicos y con pocas observaciones.
#
# Para reducir la dimensionalidad, se puede agrupar estas categorías por criterios específicos, como ubicación geográfica o campo académico.

# %%
# Verificar la proporción de valores únicos en la columna "INST_ORIGEN"
print(df_SaberPro['INST_ORIGEN'].value_counts(normalize=True))
# Out:
# INST_ORIGEN
# NO OFICIAL - CORPORACIÓN    0.351630
# NO OFICIAL - FUNDACIÓN      0.315891
# OFICIAL NACIONAL            0.155751
# OFICIAL DEPARTAMENTAL       0.154283
# OFICIAL MUNICIPAL           0.021730
# REGIMEN ESPECIAL            0.000713
# Name: proportion, dtype: float64

# %%
# Verificar si las columnas fueron eliminadas
columnas_eliminadas = ['ESTU_ESTUDIANTE', 'ESTU_NACIONALIDAD', 'ESTU_PAIS_RESIDE']
columnas_presentes = [col for col in columnas_eliminadas if col in df_Saber11.columns]

if not columnas_presentes:
    print("Las columnas fueron eliminadas correctamente.")
else:
    print("Las siguientes columnas aún están presentes:", columnas_presentes)
# Out:
# Las siguientes columnas aún están presentes: ['ESTU_ESTUDIANTE', 'ESTU_NACIONALIDAD', 'ESTU_PAIS_RESIDE']

# %%
# Mostrar las columnas restantes en df_Saber11
print("Columnas restantes en df_Saber11:")
print(df_Saber11.columns)

# Mostrar las columnas restantes en df_SaberPro
print("\nColumnas restantes en df_SaberPro:")
print(df_SaberPro.columns)
# Out:
# Columnas restantes en df_Saber11:
# Index(['COLE_AREA_UBICACION', 'COLE_BILINGUE', 'COLE_CALENDARIO',
#        'COLE_COD_DANE_ESTABLECIMIENTO', 'COLE_COD_DANE_SEDE',
#        'COLE_COD_DEPTO_UBICACION', 'COLE_COD_MCPIO_UBICACION',
#        'COLE_CODIGO_ICFES', 'COLE_DEPTO_UBICACION', 'COLE_GENERO',
#        'COLE_JORNADA', 'COLE_MCPIO_UBICACION', 'COLE_NATURALEZA',
#        'COLE_NOMBRE_ESTABLECIMIENTO', 'COLE_NOMBRE_SEDE',
#        'COLE_SEDE_PRINCIPAL', 'ESTU_COD_DEPTO_PRESENTACION',
#        'ESTU_COD_MCPIO_PRESENTACION', 'ESTU_COD_RESIDE_DEPTO',
#        'ESTU_COD_RESIDE_MCPIO', 'ESTU_DEPTO_PRESENTACION', 'ESTU_DEPTO_RESIDE',
#        'ESTU_GENERO', 'ESTU_MCPIO_PRESENTACION', 'ESTU_MCPIO_RESIDE',
#        'ESTU_PRIVADO_LIBERTAD', 'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONMADRE',
#        'FAMI_EDUCACIONPADRE', 'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR',
#        'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET',
#        'FAMI_TIENELAVADORA', 'DESEMP_INGLES', 'PUNT_INGLES',
#        'PUNT_MATEMATICAS', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_C_NATURALES',
#        'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL', 'AÑO', 'EDAD_EXAMEN'],
#       dtype='object')
#
# Columnas restantes en df_SaberPro:
# Index(['ESTU_PAIS_RESIDE', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_DEPTO_RESIDE',
#        'ESTU_COD_RESIDE_MCPIO', 'ESTU_MCPIO_RESIDE',
#        'ESTU_CODDANE_COLE_TERMINO', 'ESTU_COD_COLE_MCPIO_TERMINO',
#        'ESTU_COD_DEPTO_PRESENTACION', 'INST_COD_INSTITUCION',
#        'INST_CARACTER_ACADEMICO', 'ESTU_NUCLEO_PREGRADO',
#        'ESTU_INST_DEPARTAMENTO', 'ESTU_INST_CODMUNICIPIO',
#        'ESTU_INST_MUNICIPIO', 'ESTU_PRGM_ACADEMICO', 'ESTU_PRGM_DEPARTAMENTO',
#        'ESTU_PRGM_CODMUNICIPIO', 'ESTU_PRGM_MUNICIPIO',
#        'ESTU_NIVEL_PRGM_ACADEMICO', 'ESTU_METODO_PRGM',
#        'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_DEPTO_PRESENTACION',
#        'ESTU_COD_MCPIO_PRESENTACION', 'ESTU_MCPIO_PRESENTACION',
#        'ESTU_PAGOMATRICULABECA', 'ESTU_PAGOMATRICULACREDITO',
#        'ESTU_HORASSEMANATRABAJA', 'ESTU_SNIES_PRGMACADEMICO',
#        'ESTU_PRIVADO_LIBERTAD', 'ESTU_NACIONALIDAD', 'ESTU_ESTUDIANTE',
#        'ESTU_GENERO', 'ESTU_COLE_TERMINO', 'ESTU_PAGOMATRICULAPADRES',
#        'ESTU_PAGOMATRICULAPROPIO', 'FAMI_EDUCACIONPADRE',
#        'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENELAVADORA', 'FAMI_ESTRATOVIVIENDA',
#        'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET', 'FAMI_EDUCACIONMADRE',
#        'INST_ORIGEN', 'MOD_RAZONA_CUANTITAT_PUNT', 'MOD_COMUNI_ESCRITA_PUNT',
#        'MOD_COMUNI_ESCRITA_DESEM', 'MOD_INGLES_DESEM',
#        'MOD_LECTURA_CRITICA_PUNT', 'MOD_INGLES_PUNT',
#        'MOD_COMPETEN_CIUDADA_PUNT', 'AÑO', 'EDAD_EXAMEN'],
#       dtype='object')

# %%
# Valores únicos de 'ESTU_PRIVADO_LIBERTAD' en Saber 11
print("Valores únicos en Saber 11 - 'ESTU_PRIVADO_LIBERTAD':")
print(df_Saber11['ESTU_PRIVADO_LIBERTAD'].unique())

# Valores únicos de 'ESTU_PRIVADO_LIBERTAD' en Saber Pro
print("\nValores únicos en Saber Pro - 'ESTU_PRIVADO_LIBERTAD':")
print(df_SaberPro['ESTU_PRIVADO_LIBERTAD'].unique())

# Valores únicos de 'ESTU_NACIONALIDAD' en Saber Pro
print("\nValores únicos en Saber Pro - 'ESTU_NACIONALIDAD':")
print(df_SaberPro['ESTU_NACIONALIDAD'].unique())
# Out:
# Valores únicos en Saber 11 - 'ESTU_PRIVADO_LIBERTAD':
# ['N' 'S']
#
# Valores únicos en Saber Pro - 'ESTU_PRIVADO_LIBERTAD':
# ['N' 'S']
#
# Valores únicos en Saber Pro - 'ESTU_NACIONALIDAD':
# ['COLOMBIA' 'ECUADOR' 'PERÚ' 'ALEMANIA' 'ESTADOS FEDERADOS DE MICRONESIA'
#  'VENEZUELA' 'ESPAÑA' 'ARMENIA' 'TERRITORIOS PALESTINOS' 'COMORAS'
#  'PANAMÁ' 'COREA DEL NORTE' 'CHILE' 'FRANCIA' 'ALBANIA' 'VIETNAM'
#  'BOLIVIA' 'PAÍSES BAJOS - HOLANDA' 'CIUDAD DEL VATICANO' 'EL SALVADOR'
#  'ESTADOS UNIDOS' 'ANTIGUA Y BARBUDA' 'CUBA' 'ITALIA' 'HAITI'
#  'SANTA LUCÍA' 'KENIA' 'BRASIL' 'REINO UNIDO' 'DINAMARCA' 'ARGENTINA'
#  'PARAGUAY' 'DOMINICA' 'CROACIA' 'COSTA RICA' 'UGANDA' 'MÉXICO'
#  'BIELORRUSIA' 'NICARAGUA' 'CURAZAO' 'HONDURAS' 'GABÓN'
#  'REPÚBLICA DEMOCRÁTICA DEL CONGO' 'CABO VERDE' 'REPÚBLICA DOMINICANA'
#  'GUATEMALA' 'BUTÁN' 'COREA DEL SUR' 'URUGUAY' 'ALAND' 'REUNIÓN' 'CHINA'
#  'PORTUGAL' 'ISRAEL' 'UCRANIA' 'CAMERÚN' 'TURQUÍA' 'SUIZA' 'BURKINA FASO'
#  'TANZANIA' 'INDIA' 'ZIMBABUE' 'MACAO' 'COSTA DE MARFIL'
#  'LAOS - REPÚBLICA DEMOCRÁTICA POPULAR LAO' 'JAPÓN' 'AZERBAIYÁN' 'NORUEGA'
#  'VANUATU' 'RUSIA' 'OMÁN' 'MOZAMBIQUE' 'CANADÁ' 'YEMEN' 'UZBEKISTÁN'
#  'LÍBANO' 'BÉLGICA' 'POLONIA' 'SUECIA' 'MARRUECOS']

# %%
# Filtrar en Saber 11 para dejar solo 'ESTU_PRIVADO_LIBERTAD' = "N"
df_Saber11 = df_Saber11[df_Saber11['ESTU_PRIVADO_LIBERTAD'] == "N"]

# Filtrar en Saber Pro para dejar solo 'ESTU_PRIVADO_LIBERTAD' = "N" y 'ESTU_NACIONALIDAD' = "COLOMBIA"
df_SaberPro = df_SaberPro[
    (df_SaberPro['ESTU_PRIVADO_LIBERTAD'] == "N") &
    (df_SaberPro['ESTU_NACIONALIDAD'] == "COLOMBIA")
]

# Eliminar las columnas dado que ahora tienen solo un valor único
df_Saber11 = df_Saber11.drop(columns=['ESTU_PRIVADO_LIBERTAD'])
df_SaberPro = df_SaberPro.drop(columns=['ESTU_PRIVADO_LIBERTAD', 'ESTU_NACIONALIDAD'])

# Verificar el resultado
print("Columnas de Saber 11 después de la limpieza:", df_Saber11.columns)
print("Columnas de Saber Pro después de la limpieza:", df_SaberPro.columns)
# Out:
# Columnas de Saber 11 después de la limpieza: Index(['COLE_AREA_UBICACION', 'COLE_BILINGUE', 'COLE_CALENDARIO',
#        'COLE_COD_DANE_ESTABLECIMIENTO', 'COLE_COD_DANE_SEDE',
#        'COLE_COD_DEPTO_UBICACION', 'COLE_COD_MCPIO_UBICACION',
#        'COLE_CODIGO_ICFES', 'COLE_DEPTO_UBICACION', 'COLE_GENERO',
#        'COLE_JORNADA', 'COLE_MCPIO_UBICACION', 'COLE_NATURALEZA',
#        'COLE_NOMBRE_ESTABLECIMIENTO', 'COLE_NOMBRE_SEDE',
#        'COLE_SEDE_PRINCIPAL', 'ESTU_COD_DEPTO_PRESENTACION',
#        'ESTU_COD_MCPIO_PRESENTACION', 'ESTU_COD_RESIDE_DEPTO',
#        'ESTU_COD_RESIDE_MCPIO', 'ESTU_DEPTO_PRESENTACION', 'ESTU_DEPTO_RESIDE',
#        'ESTU_GENERO', 'ESTU_MCPIO_PRESENTACION', 'ESTU_MCPIO_RESIDE',
#        'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE',
#        'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR', 'FAMI_TIENEAUTOMOVIL',
#        'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET', 'FAMI_TIENELAVADORA',
#        'DESEMP_INGLES', 'PUNT_INGLES', 'PUNT_MATEMATICAS',
#        'PUNT_SOCIALES_CIUDADANAS', 'PUNT_C_NATURALES', 'PUNT_LECTURA_CRITICA',
#        'PUNT_GLOBAL', 'AÑO', 'EDAD_EXAMEN'],
#       dtype='object')
# Columnas de Saber Pro después de la limpieza: Index(['ESTU_PAIS_RESIDE', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_DEPTO_RESIDE',
#        'ESTU_COD_RESIDE_MCPIO', 'ESTU_MCPIO_RESIDE',
#        'ESTU_CODDANE_COLE_TERMINO', 'ESTU_COD_COLE_MCPIO_TERMINO',
#        'ESTU_COD_DEPTO_PRESENTACION', 'INST_COD_INSTITUCION',
#        'INST_CARACTER_ACADEMICO', 'ESTU_NUCLEO_PREGRADO',
#        'ESTU_INST_DEPARTAMENTO', 'ESTU_INST_CODMUNICIPIO',
#        'ESTU_INST_MUNICIPIO', 'ESTU_PRGM_ACADEMICO', 'ESTU_PRGM_DEPARTAMENTO',
#        'ESTU_PRGM_CODMUNICIPIO', 'ESTU_PRGM_MUNICIPIO',
#        'ESTU_NIVEL_PRGM_ACADEMICO', 'ESTU_METODO_PRGM',
#        'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_DEPTO_PRESENTACION',
#        'ESTU_COD_MCPIO_PRESENTACION', 'ESTU_MCPIO_PRESENTACION',
#        'ESTU_PAGOMATRICULABECA', 'ESTU_PAGOMATRICULACREDITO',
#        'ESTU_HORASSEMANATRABAJA', 'ESTU_SNIES_PRGMACADEMICO',
#        'ESTU_ESTUDIANTE', 'ESTU_GENERO', 'ESTU_COLE_TERMINO',
#        'ESTU_PAGOMATRICULAPADRES', 'ESTU_PAGOMATRICULAPROPIO',
#        'FAMI_EDUCACIONPADRE', 'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENELAVADORA',
#        'FAMI_ESTRATOVIVIENDA', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET',
#        'FAMI_EDUCACIONMADRE', 'INST_ORIGEN', 'MOD_RAZONA_CUANTITAT_PUNT',
#        'MOD_COMUNI_ESCRITA_PUNT', 'MOD_COMUNI_ESCRITA_DESEM',
#        'MOD_INGLES_DESEM', 'MOD_LECTURA_CRITICA_PUNT', 'MOD_INGLES_PUNT',
#        'MOD_COMPETEN_CIUDADA_PUNT', 'AÑO', 'EDAD_EXAMEN'],
#       dtype='object')

# %%
# En ambos casos no importa en dónde presenta los exámenes (es un tema de logística),
# por lo cual se deben borrar esas columnas: 'ESTU_DEPTO_PRESENTACION', 'ESTU_MCPIO_PRESENTACION'

# Eliminar las columnas 'ESTU_DEPTO_PRESENTACION' y 'ESTU_MCPIO_PRESENTACION' en Saber 11
df_Saber11 = df_Saber11.drop(columns=['ESTU_DEPTO_PRESENTACION', 'ESTU_MCPIO_PRESENTACION'], errors='ignore')

# Eliminar las columnas 'ESTU_DEPTO_PRESENTACION' y 'ESTU_MCPIO_PRESENTACION' en Saber Pro
df_SaberPro = df_SaberPro.drop(columns=['ESTU_DEPTO_PRESENTACION', 'ESTU_MCPIO_PRESENTACION'], errors='ignore')

# Verificar el resultado
print("Columnas de Saber 11 después de eliminar las columnas de presentación:", df_Saber11.columns)
print("Columnas de Saber Pro después de eliminar las columnas de presentación:", df_SaberPro.columns)
# Out:
# Columnas de Saber 11 después de eliminar las columnas de presentación: Index(['COLE_AREA_UBICACION', 'COLE_BILINGUE', 'COLE_CALENDARIO',
#        'COLE_COD_DANE_ESTABLECIMIENTO', 'COLE_COD_DANE_SEDE',
#        'COLE_COD_DEPTO_UBICACION', 'COLE_COD_MCPIO_UBICACION',
#        'COLE_CODIGO_ICFES', 'COLE_DEPTO_UBICACION', 'COLE_GENERO',
#        'COLE_JORNADA', 'COLE_MCPIO_UBICACION', 'COLE_NATURALEZA',
#        'COLE_NOMBRE_ESTABLECIMIENTO', 'COLE_NOMBRE_SEDE',
#        'COLE_SEDE_PRINCIPAL', 'ESTU_COD_DEPTO_PRESENTACION',
#        'ESTU_COD_MCPIO_PRESENTACION', 'ESTU_COD_RESIDE_DEPTO',
#        'ESTU_COD_RESIDE_MCPIO', 'ESTU_DEPTO_RESIDE', 'ESTU_GENERO',
#        'ESTU_MCPIO_RESIDE', 'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONMADRE',
#        'FAMI_EDUCACIONPADRE', 'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR',
#        'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET',
#        'FAMI_TIENELAVADORA', 'DESEMP_INGLES', 'PUNT_INGLES',
#        'PUNT_MATEMATICAS', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_C_NATURALES',
#        'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL', 'AÑO', 'EDAD_EXAMEN'],
#       dtype='object')
# Columnas de Saber Pro después de eliminar las columnas de presentación: Index(['ESTU_PAIS_RESIDE', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_DEPTO_RESIDE',
#        'ESTU_COD_RESIDE_MCPIO', 'ESTU_MCPIO_RESIDE',
#        'ESTU_CODDANE_COLE_TERMINO', 'ESTU_COD_COLE_MCPIO_TERMINO',
#        'ESTU_COD_DEPTO_PRESENTACION', 'INST_COD_INSTITUCION',
#        'INST_CARACTER_ACADEMICO', 'ESTU_NUCLEO_PREGRADO',
#        'ESTU_INST_DEPARTAMENTO', 'ESTU_INST_CODMUNICIPIO',
#        'ESTU_INST_MUNICIPIO', 'ESTU_PRGM_ACADEMICO', 'ESTU_PRGM_DEPARTAMENTO',
#        'ESTU_PRGM_CODMUNICIPIO', 'ESTU_PRGM_MUNICIPIO',
#        'ESTU_NIVEL_PRGM_ACADEMICO', 'ESTU_METODO_PRGM',
#        'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_COD_MCPIO_PRESENTACION',
#        'ESTU_PAGOMATRICULABECA', 'ESTU_PAGOMATRICULACREDITO',
#        'ESTU_HORASSEMANATRABAJA', 'ESTU_SNIES_PRGMACADEMICO',
#        'ESTU_ESTUDIANTE', 'ESTU_GENERO', 'ESTU_COLE_TERMINO',
#        'ESTU_PAGOMATRICULAPADRES', 'ESTU_PAGOMATRICULAPROPIO',
#        'FAMI_EDUCACIONPADRE', 'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENELAVADORA',
#        'FAMI_ESTRATOVIVIENDA', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET',
#        'FAMI_EDUCACIONMADRE', 'INST_ORIGEN', 'MOD_RAZONA_CUANTITAT_PUNT',
#        'MOD_COMUNI_ESCRITA_PUNT', 'MOD_COMUNI_ESCRITA_DESEM',
#        'MOD_INGLES_DESEM', 'MOD_LECTURA_CRITICA_PUNT', 'MOD_INGLES_PUNT',
#        'MOD_COMPETEN_CIUDADA_PUNT', 'AÑO', 'EDAD_EXAMEN'],
#       dtype='object')

# %%
# Eliminar columnas de nombres de instituciones en Saber 11 (manteniendo solo los códigos)
df_Saber11 = df_Saber11.drop(columns=[
    'COLE_NOMBRE_ESTABLECIMIENTO', 
    'COLE_NOMBRE_SEDE', 
    'COLE_DEPTO_UBICACION', 
    'COLE_MCPIO_UBICACION'
], errors='ignore')

# Eliminar las columnas relacionadas con el lugar de presentación del examen en Saber 11
df_Saber11 = df_Saber11.drop(columns=[
    'ESTU_COD_DEPTO_PRESENTACION', 
    'ESTU_COD_MCPIO_PRESENTACION'
], errors='ignore')

# Verificar el resultado
print("Columnas de Saber 11 después de eliminar las columnas irrelevantes:", df_Saber11.columns)
# Out:
# Columnas de Saber 11 después de eliminar las columnas irrelevantes: Index(['COLE_AREA_UBICACION', 'COLE_BILINGUE', 'COLE_CALENDARIO',
#        'COLE_COD_DANE_ESTABLECIMIENTO', 'COLE_COD_DANE_SEDE',
#        'COLE_COD_DEPTO_UBICACION', 'COLE_COD_MCPIO_UBICACION',
#        'COLE_CODIGO_ICFES', 'COLE_GENERO', 'COLE_JORNADA', 'COLE_NATURALEZA',
#        'COLE_SEDE_PRINCIPAL', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_COD_RESIDE_MCPIO',
#        'ESTU_DEPTO_RESIDE', 'ESTU_GENERO', 'ESTU_MCPIO_RESIDE',
#        'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE',
#        'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR', 'FAMI_TIENEAUTOMOVIL',
#        'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET', 'FAMI_TIENELAVADORA',
#        'DESEMP_INGLES', 'PUNT_INGLES', 'PUNT_MATEMATICAS',
#        'PUNT_SOCIALES_CIUDADANAS', 'PUNT_C_NATURALES', 'PUNT_LECTURA_CRITICA',
#        'PUNT_GLOBAL', 'AÑO', 'EDAD_EXAMEN'],
#       dtype='object')

# %% [markdown]
# Columnas en Saber Pro que tienen nombres de entidades y se puede mantener solo los códigos o
# que tienen información que no es relevante:
#
# Residencia:
# ESTU_COD_RESIDE_DEPTO y ESTU_DEPTO_RESIDE (puede eliminarse)
# ESTU_COD_RESIDE_MCPIO y ESTU_MCPIO_RESIDE (puede eliminarse)
#
# Institución de estudio (lugar de término del colegio):
# ESTU_CODDANE_COLE_TERMINO
# ESTU_COLE_TERMINO (nombre del colegio, puede eliminarse)
# INST_COD_INSTITUCION (código único de institución)
#
# INST_CARACTER_ACADEMICO (posiblemente solo descriptivo)
#
# Presentación del examen (no es relevante)
# ESTU_COD_DEPTO_PRESENTACION, ESTU_COD_MCPIO_PRESENTACION
#
# Programa académico (posiblemente solo código y descripción):
# ESTU_SNIES_PRGMACADEMICO (código SNIES único de programa académico)
# ESTU_PRGM_ACADEMICO (nombre descriptivo del programa, se puede eliminar)
# ESTU_PRGM_DEPARTAMENTO y ESTU_PRGM_MUNICIPIO (ubicación del programa, se puede eliminar)

# %%
# Eliminar columnas de 'Residencia' con nombres de entidades
df_SaberPro = df_SaberPro.drop(columns=['ESTU_DEPTO_RESIDE', 'ESTU_MCPIO_RESIDE'])

# Eliminar columnas de 'Institución de estudio' con nombres de entidades
df_SaberPro = df_SaberPro.drop(columns=['ESTU_COLE_TERMINO'])

# Eliminar columnas de 'Presentación del examen' que no son relevantes
df_SaberPro = df_SaberPro.drop(columns=['ESTU_COD_DEPTO_PRESENTACION', 'ESTU_COD_MCPIO_PRESENTACION'])

# Eliminar columnas de 'Programa académico' con nombres y ubicaciones
df_SaberPro = df_SaberPro.drop(columns=['ESTU_PRGM_ACADEMICO', 'ESTU_PRGM_DEPARTAMENTO', 'ESTU_PRGM_MUNICIPIO'])

# Verificar las columnas restantes en df_SaberPro
print("Columnas restantes en Saber Pro después de la limpieza:")
print(df_SaberPro.columns)
# Out:
# Columnas restantes en Saber Pro después de la limpieza:
# Index(['ESTU_PAIS_RESIDE', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_COD_RESIDE_MCPIO',
#        'ESTU_CODDANE_COLE_TERMINO', 'ESTU_COD_COLE_MCPIO_TERMINO',
#        'INST_COD_INSTITUCION', 'INST_CARACTER_ACADEMICO',
#        'ESTU_NUCLEO_PREGRADO', 'ESTU_INST_DEPARTAMENTO',
#        'ESTU_INST_CODMUNICIPIO', 'ESTU_INST_MUNICIPIO',
#        'ESTU_PRGM_CODMUNICIPIO', 'ESTU_NIVEL_PRGM_ACADEMICO',
#        'ESTU_METODO_PRGM', 'ESTU_VALORMATRICULAUNIVERSIDAD',
#        'ESTU_PAGOMATRICULABECA', 'ESTU_PAGOMATRICULACREDITO',
#        'ESTU_HORASSEMANATRABAJA', 'ESTU_SNIES_PRGMACADEMICO',
#        'ESTU_ESTUDIANTE', 'ESTU_GENERO', 'ESTU_PAGOMATRICULAPADRES',
#        'ESTU_PAGOMATRICULAPROPIO', 'FAMI_EDUCACIONPADRE',
#        'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENELAVADORA', 'FAMI_ESTRATOVIVIENDA',
#        'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET', 'FAMI_EDUCACIONMADRE',
#        'INST_ORIGEN', 'MOD_RAZONA_CUANTITAT_PUNT', 'MOD_COMUNI_ESCRITA_PUNT',
#        'MOD_COMUNI_ESCRITA_DESEM', 'MOD_INGLES_DESEM',
#        'MOD_LECTURA_CRITICA_PUNT', 'MOD_INGLES_PUNT',
#        'MOD_COMPETEN_CIUDADA_PUNT', 'AÑO', 'EDAD_EXAMEN'],
#       dtype='object')

# %%
print(df_Saber11.columns)
# Out:
# Index(['COLE_AREA_UBICACION', 'COLE_BILINGUE', 'COLE_CALENDARIO',
#        'COLE_COD_DANE_ESTABLECIMIENTO', 'COLE_COD_DANE_SEDE',
#        'COLE_COD_DEPTO_UBICACION', 'COLE_COD_MCPIO_UBICACION',
#        'COLE_CODIGO_ICFES', 'COLE_GENERO', 'COLE_JORNADA', 'COLE_NATURALEZA',
#        'COLE_SEDE_PRINCIPAL', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_COD_RESIDE_MCPIO',
#        'ESTU_DEPTO_RESIDE', 'ESTU_GENERO', 'ESTU_MCPIO_RESIDE',
#        'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE',
#        'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR', 'FAMI_TIENEAUTOMOVIL',
#        'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET', 'FAMI_TIENELAVADORA',
#        'DESEMP_INGLES', 'PUNT_INGLES', 'PUNT_MATEMATICAS',
#        'PUNT_SOCIALES_CIUDADANAS', 'PUNT_C_NATURALES', 'PUNT_LECTURA_CRITICA',
#        'PUNT_GLOBAL', 'AÑO', 'EDAD_EXAMEN'],
#       dtype='object')

# %% [markdown]
# Ahora columnas que pueden eliminarse de Saber 11:
#
# Residencia del Estudiante
# Mantener:
# ESTU_COD_RESIDE_DEPTO y ESTU_COD_RESIDE_MCPIO: Estos códigos únicos identifican la ubicación de residencia del estudiante.
# Eliminar:
# ESTU_DEPTO_RESIDE y ESTU_MCPIO_RESIDE: Son nombres descriptivos de la ubicación de residencia que no aportan información adicional relevante.

# %%
# Eliminar columnas descriptivas de la ubicación de residencia en Saber 11
 df_Saber11.drop(columns=['ESTU_DEPTO_RESIDE', 'ESTU_MCPIO_RESIDE'], inplace=True)

# Verificar que las columnas se eliminaron correctamente
print("Columnas restantes en df_Saber11 después de la eliminación:")
print(df_Saber11.columns)
# Out:
# Columnas restantes en df_Saber11 después de la eliminación:
# Index(['COLE_AREA_UBICACION', 'COLE_BILINGUE', 'COLE_CALENDARIO',
#        'COLE_COD_DANE_ESTABLECIMIENTO', 'COLE_COD_DANE_SEDE',
#        'COLE_COD_DEPTO_UBICACION', 'COLE_COD_MCPIO_UBICACION',
#        'COLE_CODIGO_ICFES', 'COLE_GENERO', 'COLE_JORNADA', 'COLE_NATURALEZA',
#        'COLE_SEDE_PRINCIPAL', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_COD_RESIDE_MCPIO',
#        'ESTU_GENERO', 'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONMADRE',
#        'FAMI_EDUCACIONPADRE', 'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR',
#        'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET',
#        'FAMI_TIENELAVADORA', 'DESEMP_INGLES', 'PUNT_INGLES',
#        'PUNT_MATEMATICAS', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_C_NATURALES',
#        'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL', 'AÑO', 'EDAD_EXAMEN'],
#       dtype='object')

# %%
# Código para obtener valores únicos de columnas en df_Saber11
valores_unicos = {
    'COLE_CALENDARIO': df_Saber11['COLE_CALENDARIO'].unique(),
    'COLE_GENERO': df_Saber11['COLE_GENERO'].unique(),
    'COLE_JORNADA': df_Saber11['COLE_JORNADA'].unique(),
    'COLE_NATURALEZA': df_Saber11['COLE_NATURALEZA'].unique()
}

# Mostrar los resultados
for columna, valores in valores_unicos.items():
    print(f"Valores únicos en {columna}: {valores}")
# Out:
# Valores únicos en COLE_CALENDARIO: ['A' 'OTRO' 'B']
# Valores únicos en COLE_GENERO: ['MIXTO' 'FEMENINO' 'MASCULINO']
# Valores únicos en COLE_JORNADA: ['COMPLETA' 'MAÑANA' 'SABATINA' 'TARDE' 'UNICA' 'NOCHE']
# Valores únicos en COLE_NATURALEZA: ['OFICIAL' 'NO OFICIAL']

# %%
# Estadísticas descriptivas de variables numéricas
print("Estadísticas descriptivas - Saber 11:")
print(df_Saber11.describe())

print("\nEstadísticas descriptivas - Saber Pro:")
print(df_SaberPro_imputed.describe())
# Out:
# Estadísticas descriptivas - Saber 11:
#        FAMI_CUARTOSHOGAR  FAMI_PERSONASHOGAR   PUNT_INGLES  PUNT_MATEMATICAS  \
# count       4.257229e+06        4.257229e+06  4.257229e+06      4.257229e+06
# mean        2.812142e+00        4.796400e+00  5.062153e+01      5.106547e+01
# std         1.003552e+00        1.665300e+00  1.247701e+01      1.191113e+01
# min         1.000000e+00        1.000000e+00  0.000000e+00      0.000000e+00
# 25%         2.000000e+00        4.000000e+00  4.200000e+01      4.300000e+01
# 50%         3.000000e+00        4.000000e+00  4.900000e+01      5.100000e+01
# 75%         3.000000e+00        6.000000e+00  5.700000e+01      5.900000e+01
# max         1.000000e+01        1.200000e+01  1.000000e+02      1.000000e+02
#
#        PUNT_SOCIALES_CIUDADANAS  PUNT_C_NATURALES  PUNT_LECTURA_CRITICA  \
# count              4.257229e+06      4.257229e+06          4.257229e+06
# mean               4.915460e+01      5.044494e+01          5.241406e+01
# std                1.167626e+01      1.047712e+01          1.030297e+01
# min                0.000000e+00      0.000000e+00          0.000000e+00
# 25%                4.000000e+01      4.300000e+01          4.500000e+01
# 50%                4.900000e+01      5.000000e+01          5.200000e+01
# 75%                5.700000e+01      5.800000e+01          6.000000e+01
# max                1.000000e+02      1.000000e+02          1.000000e+02
#
#         PUNT_GLOBAL           AÑO   EDAD_EXAMEN
# count  4.257229e+06  4.257229e+06  4.257229e+06
# mean   2.537921e+02  2.017918e+03  1.758839e+01
# std    5.002124e+01  2.805401e+00  2.144199e+00
# min    0.000000e+00  2.014000e+03  4.000000e+00
# 25%    2.170000e+02  2.015000e+03  1.700000e+01
# 50%    2.500000e+02  2.017000e+03  1.700000e+01
# 75%    2.880000e+02  2.019000e+03  1.800000e+01
# max    4.950000e+02  2.022000e+03  4.000000e+01
#
# Estadísticas descriptivas - Saber Pro:
#        MOD_RAZONA_CUANTITAT_PUNT  MOD_COMUNI_ESCRITA_PUNT  \
# count               1.093455e+06             1.093455e+06
# mean                1.476541e+02             1.395027e+02
# std                 3.209693e+01             4.207519e+01
# min                 0.000000e+00             0.000000e+00
# 25%                 1.250000e+02             1.240000e+02
# 50%                 1.470000e+02             1.400000e+02
# 75%                 1.700000e+02             1.650000e+02
# max                 3.000000e+02             3.000000e+02
#
#        MOD_COMUNI_ESCRITA_DESEM  MOD_LECTURA_CRITICA_PUNT  MOD_INGLES_PUNT  \
# count              1.093455e+06              1.093455e+06     1.093455e+06
# mean               2.306713e+00              1.502050e+02     1.557742e+02
# std                8.588858e-01              3.071722e+01     3.157697e+01
# min                1.000000e+00              0.000000e+00     0.000000e+00
# 25%                2.000000e+00              1.280000e+02     1.330000e+02
# 50%                2.000000e+00              1.500000e+02     1.520000e+02
# 75%                3.000000e+00              1.720000e+02     1.760000e+02
# max                4.000000e+00              3.000000e+02     3.000000e+02
#
#        MOD_COMPETEN_CIUDADA_PUNT           AÑO   EDAD_EXAMEN
# count               1.093455e+06  1.093455e+06  1.093455e+06
# mean                1.460999e+02  2.020012e+03  2.535617e+01
# std                 3.316025e+01  1.377339e+00  4.543765e+00
# min                 0.000000e+00  2.018000e+03  9.000000e+00
# 25%                 1.220000e+02  2.019000e+03  2.200000e+01
# 50%                 1.470000e+02  2.020000e+03  2.400000e+01
# 75%                 1.700000e+02  2.021000e+03  2.700000e+01
# max                 3.000000e+02  2.022000e+03  4.000000e+01

# %%
# Columnas de puntajes
puntaje_columnas_saber11 = ['PUNT_INGLES', 'PUNT_MATEMATICAS', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_C_NATURALES', 'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL']
puntaje_columnas_saberpro = ['MOD_RAZONA_CUANTITAT_PUNT', 'MOD_COMUNI_ESCRITA_PUNT', 'MOD_LECTURA_CRITICA_PUNT', 'MOD_INGLES_PUNT', 'MOD_COMPETEN_CIUDADA_PUNT']

# %%
# Convertir las columnas de puntajes a tipo numérico (por un error que se obtuvo al graficar, nos dimos cuenta que 
# había que hacer la conversión de las columnas de puntajes a numéricas)

# Convertir columnas de puntajes en Saber11 a numéricas
for columna in puntaje_columnas_saber11:
    df_Saber11[columna] = pd.to_numeric(df_Saber11[columna], errors='coerce')

# Convertir columnas de puntajes en SaberPro a numéricas
for columna in puntaje_columnas_saberpro:
    df_SaberPro_imputed[columna] = pd.to_numeric(df_SaberPro_imputed[columna], errors='coerce')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Función para graficar líneas de tendencia
def graficar_lineas_tendencia(df, puntaje_columnas, titulo_base):
    for columna in puntaje_columnas:
        plt.figure(figsize=(10, 6))
        data = df.groupby('AÑO')[columna].mean()
        plt.plot(data.index, data.values, marker='o', linestyle='-', color='b')
        plt.title(f"Tendencia de {columna} a lo largo de los años en {titulo_base}")
        plt.xlabel("Año")
        plt.ylabel(f"Media en {columna}")
        plt.grid(True)
        plt.show()

# Generar gráficas de tendencia con la media de puntajes por año
graficar_lineas_tendencia(df_Saber11, puntaje_columnas_saber11, "Saber 11")
graficar_lineas_tendencia(df_SaberPro, puntaje_columnas_saberpro, "Saber Pro")

# Función para graficar boxplots por año
def graficar_boxplots_por_año(df, puntaje_columnas, titulo_base):
    for columna in puntaje_columnas:
        plt.figure(figsize=(12, 6))
        sns.boxplot(data=df, x='AÑO', y=columna)
        plt.title(f"Distribución de {columna} por año en {titulo_base}")
        plt.xlabel("Año")
        plt.ylabel(f"Puntaje en {columna}")
        plt.grid(True)
        plt.show()

# Generar gráficas de cajas por año
graficar_boxplots_por_año(df_Saber11, puntaje_columnas_saber11, "Saber 11")
graficar_boxplots_por_año(df_SaberPro, puntaje_columnas_saberpro, "Saber Pro")

# Función para graficar barras de la media por año
def graficar_barras_media_por_año(df, puntaje_columnas, titulo_base):
    for columna in puntaje_columnas:
        plt.figure(figsize=(10, 6))
        data = df.groupby('AÑO')[columna].mean()
        data.plot(kind='bar', color='skyblue', edgecolor='black')
        plt.title(f"Media de {columna} por año en {titulo_base}")
        plt.xlabel("Año")
        plt.ylabel(f"Media en {columna}")
        plt.grid(True)
        plt.show()

# Generar gráficas de barras de la media de puntajes por año
graficar_barras_media_por_año(df_Saber11, puntaje_columnas_saber11, "Saber 11")
graficar_barras_media_por_año(df_SaberPro, puntaje_columnas_saberpro, "Saber Pro")

# %%
# Generar resumen estadístico para las columnas de puntajes en Saber 11
resumen_saber11 = df_Saber11[puntaje_columnas_saber11].describe(percentiles=[0.25, 0.5, 0.75])
print("Resumen Estadístico de Puntajes en Saber 11")
print(resumen_saber11)

# Generar resumen estadístico para las columnas de puntajes en Saber Pro
resumen_saberpro = df_SaberPro[puntaje_columnas_saberpro].describe(percentiles=[0.25, 0.5, 0.75])
print("\nResumen Estadístico de Puntajes en Saber Pro")
print(resumen_saberpro)
# Out:
# Resumen Estadístico de Puntajes en Saber 11
#         PUNT_INGLES  PUNT_MATEMATICAS  PUNT_SOCIALES_CIUDADANAS  \
# count  4.257229e+06      4.257229e+06              4.257229e+06
# mean   5.062153e+01      5.106547e+01              4.915460e+01
# std    1.247701e+01      1.191113e+01              1.167626e+01
# min    0.000000e+00      0.000000e+00              0.000000e+00
# 25%    4.200000e+01      4.300000e+01              4.000000e+01
# 50%    4.900000e+01      5.100000e+01              4.900000e+01
# 75%    5.700000e+01      5.900000e+01              5.700000e+01
# max    1.000000e+02      1.000000e+02              1.000000e+02
#
#        PUNT_C_NATURALES  PUNT_LECTURA_CRITICA   PUNT_GLOBAL
# count      4.257229e+06          4.257229e+06  4.257229e+06
# mean       5.044494e+01          5.241406e+01  2.537921e+02
# std        1.047712e+01          1.030297e+01  5.002124e+01
# min        0.000000e+00          0.000000e+00  0.000000e+00
# 25%        4.300000e+01          4.500000e+01  2.170000e+02
# 50%        5.000000e+01          5.200000e+01  2.500000e+02
# 75%        5.800000e+01          6.000000e+01  2.880000e+02
# max        1.000000e+02          1.000000e+02  4.950000e+02
#
# Resumen Estadístico de Puntajes en Saber Pro
#        MOD_RAZONA_CUANTITAT_PUNT  MOD_COMUNI_ESCRITA_PUNT  \
# count               1.090585e+06             1.090585e+06
# mean                1.476390e+02             1.394922e+02
# std                 3.209112e+01             4.206631e+01
# min                 0.000000e+00             0.000000e+00
# 25%                 1.250000e+02             1.240000e+02
# 50%                 1.470000e+02             1.400000e+02
# 75%                 1.700000e+02             1.650000e+02
# max                 3.000000e+02             3.000000e+02
#
#        MOD_LECTURA_CRITICA_PUNT  MOD_INGLES_PUNT  MOD_COMPETEN_CIUDADA_PUNT
# count              1.090585e+06     1.090585e+06               1.090585e+06
# mean               1.501969e+02     1.557120e+02               1.460956e+02
# std                3.070994e+01     3.153767e+01               3.315598e+01
# min                0.000000e+00     0.000000e+00               0.000000e+00
# 25%                1.280000e+02     1.330000e+02               1.220000e+02
# 50%                1.500000e+02     1.520000e+02               1.470000e+02
# 75%                1.720000e+02     1.760000e+02               1.700000e+02
# max                3.000000e+02     3.000000e+02               3.000000e+02

# %%
df_SaberPro_imputed.columns
# Out:
# Index(['ESTU_PAIS_RESIDE', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_DEPTO_RESIDE',
#        'ESTU_COD_RESIDE_MCPIO', 'ESTU_MCPIO_RESIDE',
#        'ESTU_CODDANE_COLE_TERMINO', 'ESTU_COD_COLE_MCPIO_TERMINO',
#        'ESTU_COD_DEPTO_PRESENTACION', 'INST_COD_INSTITUCION',
#        'INST_CARACTER_ACADEMICO', 'ESTU_NUCLEO_PREGRADO',
#        'ESTU_INST_DEPARTAMENTO', 'ESTU_INST_CODMUNICIPIO',
#        'ESTU_INST_MUNICIPIO', 'ESTU_PRGM_ACADEMICO', 'ESTU_PRGM_DEPARTAMENTO',
#        'ESTU_PRGM_CODMUNICIPIO', 'ESTU_PRGM_MUNICIPIO',
#        'ESTU_NIVEL_PRGM_ACADEMICO', 'ESTU_METODO_PRGM',
#        'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_DEPTO_PRESENTACION',
#        'ESTU_COD_MCPIO_PRESENTACION', 'ESTU_MCPIO_PRESENTACION',
#        'ESTU_PAGOMATRICULABECA', 'ESTU_PAGOMATRICULACREDITO',
#        'ESTU_HORASSEMANATRABAJA', 'ESTU_SNIES_PRGMACADEMICO',
#        'ESTU_PRIVADO_LIBERTAD', 'ESTU_NACIONALIDAD', 'ESTU_ESTUDIANTE',
#        'ESTU_GENERO', 'ESTU_COLE_TERMINO', 'ESTU_PAGOMATRICULAPADRES',
#        'ESTU_PAGOMATRICULAPROPIO', 'FAMI_EDUCACIONPADRE',
#        'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENELAVADORA', 'FAMI_ESTRATOVIVIENDA',
#        'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET', 'FAMI_EDUCACIONMADRE',
#        'INST_ORIGEN', 'MOD_RAZONA_CUANTITAT_PUNT', 'MOD_COMUNI_ESCRITA_PUNT',
#        'MOD_COMUNI_ESCRITA_DESEM', 'MOD_INGLES_DESEM',
#        'MOD_LECTURA_CRITICA_PUNT', 'MOD_INGLES_PUNT',
#        'MOD_COMPETEN_CIUDADA_PUNT', 'AÑO', 'EDAD_EXAMEN'],
#       dtype='object')

# %%
# Cargar el archivo de Excel
ruta_excel = r"C:\Users\jaime\ALUNA Dropbox\JAIME ARTURO RAMIREZ\MIAD-Proyecto\COD_DEP_MUN.xlsx"
df_cod_dep_mun = pd.read_excel(ruta_excel)

# %%
# Convertir 'ESTU_COD_RESIDE_MCPIO' en df_Saber11 a string de 5 dígitos
df_Saber11['ESTU_COD_RESIDE_MCPIO'] = df_Saber11['ESTU_COD_RESIDE_MCPIO'].fillna(0).astype(float).astype(int).astype(str).str.zfill(5)

# Convertir 'COD_MPIO' en df_cod_dep_mun a string de 5 dígitos
df_cod_dep_mun['COD_MPIO'] = df_cod_dep_mun['COD_MPIO'].astype(str).str.zfill(5)

# Verificar los primeros valores después de la conversión
print(df_Saber11['ESTU_COD_RESIDE_MCPIO'].head())
print(df_cod_dep_mun['COD_MPIO'].head())
# Out:
# 1    41016
# 2    41016
# 5    41396
# 6    41396
# 7    76001
# Name: ESTU_COD_RESIDE_MCPIO, dtype: object
# 0    70221
# 1    15600
# 2    20400
# 3    23300
# 4    25200
# Name: COD_MPIO, dtype: object

# %%
# Fusionar df_Saber11 con df_cod_dep_mun usando el código de municipio
df_Saber11 = df_Saber11.merge(df_cod_dep_mun[['COD_MPIO', 'CATEGORIA']], 
                              left_on='ESTU_COD_RESIDE_MCPIO', 
                              right_on='COD_MPIO', 
                              how='left')

# Verificar si la columna 'CATEGORIA' se agregó correctamente
print(df_Saber11[['ESTU_COD_RESIDE_MCPIO', 'CATEGORIA']].head())
# Out:
#   ESTU_COD_RESIDE_MCPIO  CATEGORIA
# 0                 41016        6.0
# 1                 41016        6.0
# 2                 41396        6.0
# 3                 41396        6.0
# 4                 76001        7.0

# %%
# Contar los valores NaN en la columna 'CATEGORIA'
num_nan_categorias = df_Saber11['CATEGORIA'].isna().sum()

# Calcular el porcentaje de municipios sin categoría
porcentaje_nan_categorias = (num_nan_categorias / len(df_Saber11)) * 100

print(f"Cantidad de municipios sin categoría: {num_nan_categorias}")
print(f"Porcentaje de municipios sin categoría: {porcentaje_nan_categorias:.2f}%")
# Out:
# Cantidad de municipios sin categoría: 11661
# Porcentaje de municipios sin categoría: 0.27%

# %%
# Filtrar los registros sin categoría
municipios_sin_categoria = df_Saber11[df_Saber11['CATEGORIA'].isna()]

# Obtener una lista única de códigos de municipios sin categoría
municipios_unicos_sin_categoria = municipios_sin_categoria['ESTU_COD_RESIDE_MCPIO'].unique()

print("Municipios sin categoría:", municipios_unicos_sin_categoria)
print("Cantidad de municipios sin categoría:", len(municipios_unicos_sin_categoria))
# Out:
# Municipios sin categoría: ['23815' '88001' '23682' '19300' '91798' '27086' '91405' '97889' '91407'
#  '91263' '94343' '91460' '94883' '13490' '94663' '99999' '94888' '97511'
#  '91430' '91669' '94887' '94885' '91530' '94886']
# Cantidad de municipios sin categoría: 24

# %%
# Filtrar los registros de df_Saber11 que no tienen categoría
municipios_sin_categoria = df_Saber11[df_Saber11['CATEGORIA'].isna()]

# Seleccionar columnas de interés, incluyendo el código y el nombre del municipio
municipios_info_sin_categoria = municipios_sin_categoria['ESTU_COD_RESIDE_MCPIO'].drop_duplicates()

# Mostrar resultados
print("Información de municipios sin categoría:")
print(municipios_info_sin_categoria)
print(f"Cantidad de municipios sin categoría: {len(municipios_info_sin_categoria)}")
# Out:
# Información de municipios sin categoría:
# 341        23815
# 1161       88001
# 3812       23682
# 4611       19300
# 5766       91798
# 10487      27086
# 14468      91405
# 22021      97889
# 26300      91407
# 28085      91263
# 29511      94343
# 36604      91460
# 54952      94883
# 60132      13490
# 67488      94663
# 99319      99999
# 134154     94888
# 149738     97511
# 151719     91430
# 601523     91669
# 1096602    94887
# 1143820    94885
# 2549265    91530
# 3335502    94886
# Name: ESTU_COD_RESIDE_MCPIO, dtype: object
# Cantidad de municipios sin categoría: 24

# %%
# Por los còdigos de los municipios que no tienen nombre de categoría en la BD df_cod_dep_mun
# que son totalmente desconocidos, se tiene una muy alta certeza de que son categoría 6.

# Identificar los municipios sin categoría en df_Saber11
municipios_sin_categoria = df_Saber11[df_Saber11['CATEGORIA'].isna()]

# Asignar categoría 6 a los municipios desconocidos en df_Saber11
df_Saber11.loc[municipios_sin_categoria.index, 'CATEGORIA'] = 6

# %%
# Verificar y eliminar columnas duplicadas antes del merge
df_SaberPro = df_SaberPro.drop(columns=['CATEGORIA'], errors='ignore')
df_SaberPro = df_SaberPro.drop(columns=['COD_MPIO'], errors='ignore')

# Realizar el merge nuevamente para agregar 'CATEGORIA'
df_SaberPro = df_SaberPro.merge(
    df_cod_dep_mun[['COD_MPIO', 'CATEGORIA']],
    left_on='ESTU_COD_RESIDE_MCPIO',
    right_on='COD_MPIO',
    how='left'
)

# %%
# Verificar la cantidad de valores nulos en 'CATEGORIA'
nulos_categoria = df_SaberPro['CATEGORIA'].isna().sum()
print(f"Cantidad de valores nulos en 'CATEGORIA' después del merge: {nulos_categoria}")

# Mostrar ejemplos de filas para revisar que el merge se realizó correctamente
print("\nEjemplos de filas en 'df_SaberPro' con columna 'CATEGORIA':")
print(df_SaberPro[['ESTU_COD_RESIDE_MCPIO', 'CATEGORIA']].head(10))

# Verificar los valores únicos en 'CATEGORIA' para asegurarse de que corresponden a los municipios
print("\nValores únicos en 'CATEGORIA':")
print(df_SaberPro['CATEGORIA'].unique())
# Out:
# Cantidad de valores nulos en 'CATEGORIA' después del merge: 194946
#
# Ejemplos de filas en 'df_SaberPro' con columna 'CATEGORIA':
#   ESTU_COD_RESIDE_MCPIO  CATEGORIA
# 0                 70001        2.0
# 1                 23417        6.0
# 2                  8685        NaN
# 3                 23466        5.0
# 4                 13001        7.0
# 5                 81001        4.0
# 6                  5837        NaN
# 7                 23162        5.0
# 8                 68432        6.0
# 9                 25754        1.0
#
# Valores únicos en 'CATEGORIA':
# [ 2.  6. nan  5.  7.  4.  1.  3.]

# %%
# Eliminar columnas duplicadas de 'df_SaberPro' antes del merge
df_SaberPro = df_SaberPro.drop(columns=['CATEGORIA', 'COD_MPIO'], errors='ignore')

# Convertir 'ESTU_COD_RESIDE_MCPIO' a string de 5 dígitos
df_SaberPro['ESTU_COD_RESIDE_MCPIO'] = df_SaberPro['ESTU_COD_RESIDE_MCPIO'].apply(
    lambda x: str(int(x)).zfill(5)
)
df_cod_dep_mun['COD_MPIO'] = df_cod_dep_mun['COD_MPIO'].astype(str)

# Realizar el merge para agregar 'CATEGORIA' al DataFrame de SaberPro
df_SaberPro = df_SaberPro.merge(
    df_cod_dep_mun[['COD_MPIO', 'CATEGORIA']],
    left_on='ESTU_COD_RESIDE_MCPIO',
    right_on='COD_MPIO',
    how='left'
)

# Verificar la cantidad de valores nulos en 'CATEGORIA' después del merge
nulos_categoria = df_SaberPro['CATEGORIA'].isna().sum()
print(f"Cantidad de valores nulos en 'CATEGORIA' después de ajustar códigos y volver a hacer merge: {nulos_categoria}")

# Mostrar algunos ejemplos de filas para confirmar que el proceso fue exitoso
print(df_SaberPro[['ESTU_COD_RESIDE_MCPIO', 'CATEGORIA']].head(10))
# Out:
# Cantidad de valores nulos en 'CATEGORIA' después de ajustar códigos y volver a hacer merge: 1533
#   ESTU_COD_RESIDE_MCPIO  CATEGORIA
# 0                 70001        2.0
# 1                 23417        6.0
# 2                 08685        6.0
# 3                 23466        5.0
# 4                 13001        7.0
# 5                 81001        4.0
# 6                 05837        5.0
# 7                 23162        5.0
# 8                 68432        6.0
# 9                 25754        1.0

# %%
# Asignar la categoría predeterminada 6 a los valores nulos en 'CATEGORIA'
df_SaberPro['CATEGORIA'] = df_SaberPro['CATEGORIA'].fillna(6).astype(int)

# Confirmar que no hay valores nulos restantes en 'CATEGORIA'
print("Cantidad de valores nulos en 'CATEGORIA' después de rellenar:", df_SaberPro['CATEGORIA'].isna().sum())
# Out:
# Cantidad de valores nulos en 'CATEGORIA' después de rellenar: 0

# %%
# Eliminar Columnas Duplicadas en SaberPro

# Eliminar columnas duplicadas en SaberPro
df_SaberPro = df_SaberPro.drop(columns=['COD_MPIO_x', 'COD_MPIO_y', 'CATEGORIA_x', 'CATEGORIA_y'])

# Verificar que queden solo las columnas deseadas
print("Columnas en SaberPro después de eliminar duplicados:", df_SaberPro.columns)
# Out:
# Columnas en SaberPro después de eliminar duplicados: Index(['ESTU_PAIS_RESIDE', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_COD_RESIDE_MCPIO',
#        'ESTU_CODDANE_COLE_TERMINO', 'ESTU_COD_COLE_MCPIO_TERMINO',
#        'INST_COD_INSTITUCION', 'INST_CARACTER_ACADEMICO',
#        'ESTU_NUCLEO_PREGRADO', 'ESTU_INST_DEPARTAMENTO',
#        'ESTU_INST_CODMUNICIPIO', 'ESTU_INST_MUNICIPIO',
#        'ESTU_PRGM_CODMUNICIPIO', 'ESTU_NIVEL_PRGM_ACADEMICO',
#        'ESTU_METODO_PRGM', 'ESTU_VALORMATRICULAUNIVERSIDAD',
#        'ESTU_PAGOMATRICULABECA', 'ESTU_PAGOMATRICULACREDITO',
#        'ESTU_HORASSEMANATRABAJA', 'ESTU_SNIES_PRGMACADEMICO',
#        'ESTU_ESTUDIANTE', 'ESTU_GENERO', 'ESTU_PAGOMATRICULAPADRES',
#        'ESTU_PAGOMATRICULAPROPIO', 'FAMI_EDUCACIONPADRE',
#        'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENELAVADORA', 'FAMI_ESTRATOVIVIENDA',
#        'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET', 'FAMI_EDUCACIONMADRE',
#        'INST_ORIGEN', 'MOD_RAZONA_CUANTITAT_PUNT', 'MOD_COMUNI_ESCRITA_PUNT',
#        'MOD_COMUNI_ESCRITA_DESEM', 'MOD_INGLES_DESEM',
#        'MOD_LECTURA_CRITICA_PUNT', 'MOD_INGLES_PUNT',
#        'MOD_COMPETEN_CIUDADA_PUNT', 'AÑO', 'EDAD_EXAMEN', 'COD_MPIO',
#        'CATEGORIA'],
#       dtype='object')

# %% [markdown]
# **Preparación para reducción de dimensiones en la base de datos de Saber 11**
#
# 1) Lista de columnas finales en cada base de datos, para verificar que todas las variables relevantes estén presentes.
#
# 2) Tipos de datos de cada columna para asegurarnos de que estén en el formato correcto para el análisis.
#
# 3) Descripción estadística de las variables numéricas y categóricas para entender su distribución y rango, y así identificar posibles valores extremos o desbalances en categorías.
#
# 4) Cantidad de valores únicos en cada columna para verificar qué variables son de interés para la predicción y cuáles pueden ser eliminadas por tener un solo valor o valores no significativos.

# %%
# Listar las Columnas y los Tipos de Datos en cada Base de Datos

# Columnas y tipos de datos en df_Saber11
print("Columnas y tipos de datos en Saber11:")
print(df_Saber11.dtypes)

# Columnas y tipos de datos en df_SaberPro
print("\nColumnas y tipos de datos en SaberPro:")
print(df_SaberPro.dtypes)
# Out:
# Columnas y tipos de datos en Saber11:
# COLE_AREA_UBICACION               object
# COLE_BILINGUE                     object
# COLE_CALENDARIO                   object
# COLE_COD_DANE_ESTABLECIMIENTO     object
# COLE_COD_DANE_SEDE                object
# COLE_COD_DEPTO_UBICACION          object
# COLE_COD_MCPIO_UBICACION          object
# COLE_CODIGO_ICFES                 object
# COLE_GENERO                       object
# COLE_JORNADA                      object
# COLE_NATURALEZA                   object
# COLE_SEDE_PRINCIPAL               object
# ESTU_COD_RESIDE_DEPTO             object
# ESTU_COD_RESIDE_MCPIO             object
# ESTU_GENERO                       object
# FAMI_CUARTOSHOGAR                float64
# FAMI_EDUCACIONMADRE               object
# FAMI_EDUCACIONPADRE               object
# FAMI_ESTRATOVIVIENDA              object
# FAMI_PERSONASHOGAR               float64
# FAMI_TIENEAUTOMOVIL               object
# FAMI_TIENECOMPUTADOR              object
# FAMI_TIENEINTERNET                object
# FAMI_TIENELAVADORA                object
# DESEMP_INGLES                     object
# PUNT_INGLES                      float64
# PUNT_MATEMATICAS                 float64
# PUNT_SOCIALES_CIUDADANAS         float64
# PUNT_C_NATURALES                 float64
# PUNT_LECTURA_CRITICA             float64
# PUNT_GLOBAL                      float64
# AÑO                                int64
# EDAD_EXAMEN                      float64
# COD_MPIO                          object
# CATEGORIA                        float64
# dtype: object
#
# Columnas y tipos de datos en SaberPro:
# ESTU_PAIS_RESIDE                   object
# ESTU_COD_RESIDE_DEPTO             float64
# ESTU_COD_RESIDE_MCPIO              object
# ESTU_CODDANE_COLE_TERMINO          object
# ESTU_COD_COLE_MCPIO_TERMINO       float64
# INST_COD_INSTITUCION                int64
# INST_CARACTER_ACADEMICO            object
# ESTU_NUCLEO_PREGRADO               object
# ESTU_INST_DEPARTAMENTO             object
# ESTU_INST_CODMUNICIPIO              int64
# ESTU_INST_MUNICIPIO                object
# ESTU_PRGM_CODMUNICIPIO              int64
# ESTU_NIVEL_PRGM_ACADEMICO          object
# ESTU_METODO_PRGM                   object
# ESTU_VALORMATRICULAUNIVERSIDAD     object
# ESTU_PAGOMATRICULABECA             object
# ESTU_PAGOMATRICULACREDITO          object
# ESTU_HORASSEMANATRABAJA            object
# ESTU_SNIES_PRGMACADEMICO          float64
# ESTU_ESTUDIANTE                    object
# ESTU_GENERO                        object
# ESTU_PAGOMATRICULAPADRES           object
# ESTU_PAGOMATRICULAPROPIO           object
# FAMI_EDUCACIONPADRE                object
# FAMI_TIENEAUTOMOVIL                object
# FAMI_TIENELAVADORA                 object
# FAMI_ESTRATOVIVIENDA               object
# FAMI_TIENECOMPUTADOR               object
# FAMI_TIENEINTERNET                 object
# FAMI_EDUCACIONMADRE                object
# INST_ORIGEN                        object
# MOD_RAZONA_CUANTITAT_PUNT           int64
# MOD_COMUNI_ESCRITA_PUNT           float64
# MOD_COMUNI_ESCRITA_DESEM          float64
# MOD_INGLES_DESEM                   object
# MOD_LECTURA_CRITICA_PUNT            int64
# MOD_INGLES_PUNT                   float64
# MOD_COMPETEN_CIUDADA_PUNT           int64
# AÑO                                 int64
# EDAD_EXAMEN                       float64
# COD_MPIO                           object
# CATEGORIA                           int32
# dtype: object

# %% [markdown]
# La variable CATEGORIA que se adicionó al análisis, es la categoría del municipio en Colombia. Va de 1 a 6 donde 1 son los municipios más grandes y 6 son los más pequeños y, es en estos últimos, los que normalmente tienen un desempeño educativo muy deficiente, por lo que se esperaría que esa variable tuviera una correlación alta con el puntaje global. Sin embargo, hay un valor de los municipios más grandes de todos que son los ESP (categoría especial). En la conversión a número se le puso 7 a esa categoría especial. Suponemos que es mejor que tenga el valor de 0 (cero), de tal manera que 0 serían los grandes, 1 los que siguen, 2 los siguientes, etc., hasta 6.

# %%
# Cambiar los valores de 7 a 0 para la categoría especial
df_Saber11['CATEGORIA'] = df_Saber11['CATEGORIA'].replace(7, 0)
df_SaberPro['CATEGORIA'] = df_SaberPro['CATEGORIA'].replace(7, 0)

# Verificar los valores únicos para confirmar el cambio
print("Valores únicos de CATEGORIA en Saber11:", df_Saber11['CATEGORIA'].unique())
print("Valores únicos de CATEGORIA en SaberPro:", df_SaberPro['CATEGORIA'].unique())
# Out:
# Valores únicos de CATEGORIA en Saber11: [6. 0. 2. 1. 5. 4. 3.]
# Valores únicos de CATEGORIA en SaberPro: [2 6 5 0 4 1 3]

# %%
# Convertir CATEGORIA a tipo entero en ambas bases de datos para mantener consistencia
df_Saber11['CATEGORIA'] = df_Saber11['CATEGORIA'].astype(int)
df_SaberPro['CATEGORIA'] = df_SaberPro['CATEGORIA'].astype(int)

# Verificar que ambos conjuntos de datos tengan el mismo formato
print("Valores únicos de CATEGORIA en Saber11 (convertido):", df_Saber11['CATEGORIA'].unique())
print("Valores únicos de CATEGORIA en SaberPro (convertido):", df_SaberPro['CATEGORIA'].unique())
# Out:
# Valores únicos de CATEGORIA en Saber11 (convertido): [6 0 2 1 5 4 3]
# Valores únicos de CATEGORIA en SaberPro (convertido): [2 6 5 0 4 1 3]

# %%
# 
# Excluir columnas de puntajes académicos en Saber11
socioeconomic_cols_saber11 = df_Saber11.drop(columns=[
    'PUNT_INGLES', 'PUNT_MATEMATICAS', 'PUNT_SOCIALES_CIUDADANAS', 
    'PUNT_C_NATURALES', 'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL'
])

# Descripción estadística de variables numéricas contextuales en Saber11
print("\nDescripción estadística de variables numéricas contextuales en Saber11:")
print(socioeconomic_cols_saber11.select_dtypes(include=['number']).describe())

# Excluir columnas de puntajes académicos en SaberPro
socioeconomic_cols_saberpro = df_SaberPro.drop(columns=[
    'MOD_RAZONA_CUANTITAT_PUNT', 'MOD_COMUNI_ESCRITA_PUNT', 
    'MOD_LECTURA_CRITICA_PUNT', 'MOD_INGLES_PUNT', 'MOD_COMPETEN_CIUDADA_PUNT'
])

# Descripción estadística de variables numéricas contextuales en SaberPro
print("\nDescripción estadística de variables numéricas contextuales en SaberPro:")
print(socioeconomic_cols_saberpro.select_dtypes(include=['number']).describe())
# Out:
# Descripción estadística de variables numéricas contextuales en Saber11:
#        FAMI_CUARTOSHOGAR  FAMI_PERSONASHOGAR           AÑO   EDAD_EXAMEN  \
# count       4.257229e+06        4.257229e+06  4.257229e+06  4.257229e+06
# mean        2.812142e+00        4.796400e+00  2.017918e+03  1.758839e+01
# std         1.003552e+00        1.665300e+00  2.805401e+00  2.144199e+00
# min         1.000000e+00        1.000000e+00  2.014000e+03  4.000000e+00
# 25%         2.000000e+00        4.000000e+00  2.015000e+03  1.700000e+01
# 50%         3.000000e+00        4.000000e+00  2.017000e+03  1.700000e+01
# 75%         3.000000e+00        6.000000e+00  2.019000e+03  1.800000e+01
# max         1.000000e+01        1.200000e+01  2.022000e+03  4.000000e+01
#
#           CATEGORIA
# count  4.257229e+06
# mean   2.546122e+00
# std    2.523629e+00
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    1.000000e+00
# 75%    6.000000e+00
# max    6.000000e+00
#
# Descripción estadística de variables numéricas contextuales en SaberPro:
#        ESTU_COD_RESIDE_DEPTO  ESTU_COD_COLE_MCPIO_TERMINO  \
# count           1.090585e+06                 1.090585e+06
# mean            5.913275e+01                 2.254468e+04
# std             1.712368e+03                 2.665561e+04
# min             0.000000e+00                 0.000000e+00
# 25%             1.100000e+01                 0.000000e+00
# 50%             1.500000e+01                 1.100100e+04
# 75%             5.200000e+01                 4.166000e+04
# max             9.999900e+04                 9.977300e+04
#
#        INST_COD_INSTITUCION  ESTU_INST_CODMUNICIPIO  ESTU_PRGM_CODMUNICIPIO  \
# count          1.090585e+06            1.090585e+06            1.090585e+06
# mean           2.299599e+03            2.411344e+04            2.560602e+04
# std            1.379500e+03            2.374696e+04            2.435851e+04
# min            1.101000e+03            5.001000e+03            5.001000e+03
# 25%            1.701000e+03            1.100100e+04            1.100100e+04
# 50%            1.820000e+03            1.100100e+04            1.100100e+04
# 75%            2.810000e+03            2.700100e+04            4.700100e+04
# max            9.932000e+03            8.600100e+04            9.700100e+04
#
#        ESTU_SNIES_PRGMACADEMICO  MOD_COMUNI_ESCRITA_DESEM           AÑO  \
# count              1.090585e+06              1.090585e+06  1.090585e+06
# mean               3.849468e+04              2.306447e+00  2.020012e+03
# std                4.040849e+04              8.587560e-01  1.377254e+00
# min                1.000000e+00              1.000000e+00  2.018000e+03
# 25%                2.850000e+03              2.000000e+00  2.019000e+03
# 50%                1.542200e+04              2.000000e+00  2.020000e+03
# 75%                9.059600e+04              3.000000e+00  2.021000e+03
# max                1.108320e+05              4.000000e+00  2.022000e+03
#
#         EDAD_EXAMEN     CATEGORIA
# count  1.090585e+06  1.090585e+06
# mean   2.535487e+01  1.420281e+00
# std    4.543117e+00  1.983461e+00
# min    9.000000e+00  0.000000e+00
# 25%    2.200000e+01  0.000000e+00
# 50%    2.400000e+01  1.000000e+00
# 75%    2.700000e+01  2.000000e+00
# max    4.000000e+01  6.000000e+00

# %%
# Obtener valores únicos de las columnas 'FAMI_ESTRATOVIVIENDA', 'FAMI_EDUCACIONMADRE', y 'FAMI_EDUCACIONPADRE'
estrato_unicos = df_Saber11['FAMI_ESTRATOVIVIENDA'].dropna().unique().tolist()
educacion_madre_unicos = df_Saber11['FAMI_EDUCACIONMADRE'].dropna().unique().tolist()
educacion_padre_unicos = df_Saber11['FAMI_EDUCACIONPADRE'].dropna().unique().tolist()

# Mostrar resultados
print("Valores únicos de FAMI_ESTRATOVIVIENDA:", estrato_unicos)
print("Valores únicos de FAMI_EDUCACIONMADRE:", educacion_madre_unicos)
print("Valores únicos de FAMI_EDUCACIONPADRE:", educacion_padre_unicos)
# Out:
# Valores únicos de FAMI_ESTRATOVIVIENDA: ['Estrato 2', 'Estrato 1', 'Estrato 5', 'Estrato 3', 'Estrato 4', 'Sin Estrato', 'Estrato 6']
# Valores únicos de FAMI_EDUCACIONMADRE: ['Postgrado', 'Primaria incompleta', 'Secundaria (Bachillerato) incompleta', 'Educación profesional incompleta', 'Secundaria (Bachillerato) completa', 'Técnica o tecnológica completa', 'Primaria completa', 'Educación profesional completa', 'No sabe', 'Técnica o tecnológica incompleta', 'Ninguno', 'No Aplica']
# Valores únicos de FAMI_EDUCACIONPADRE: ['Primaria completa', 'Primaria incompleta', 'Secundaria (Bachillerato) completa', 'Técnica o tecnológica completa', 'Secundaria (Bachillerato) incompleta', 'Ninguno', 'Educación profesional incompleta', 'No sabe', 'Postgrado', 'Educación profesional completa', 'Técnica o tecnológica incompleta', 'No Aplica']

# %%
# Transformación de variables  categóricas

# Asignar valores numéricos a FAMI_ESTRATOVIVIENDA
estrato_map = {
    'Estrato 1': 1,
    'Estrato 2': 2,
    'Estrato 3': 3,
    'Estrato 4': 4,
    'Estrato 5': 5,
    'Estrato 6': 6,
    'Sin Estrato': 7  # Opcional, o podrías usar np.nan y luego imputar
}
df_Saber11['FAMI_ESTRATOVIVIENDA'] = df_Saber11['FAMI_ESTRATOVIVIENDA'].map(estrato_map)

# Definir el mapeo de niveles educativos para FAMI_EDUCACIONMADRE y FAMI_EDUCACIONPADRE
educacion_map = {
    'Ninguno': 1, 'Primaria completa': 1, 'Primaria incompleta': 1,
    'Secundaria (Bachillerato) incompleta': 2,
    'Secundaria (Bachillerato) completa': 3,
    'Técnica o tecnológica completa': 4,
    'Educación profesional incompleta': 4,
    'Educación profesional completa': 5,
    'Postgrado': 6,
    'Técnica o tecnológica incompleta': 3,  # Basado en no tener el título completo
    'No sabe': np.nan,  # Puedes asignarle un valor específico o imputar luego
    'No Aplica': np.nan  # Mismo caso que "No sabe"
}

# Aplicar mapeo a ambas columnas de nivel educativo
df_Saber11['FAMI_EDUCACIONMADRE'] = df_Saber11['FAMI_EDUCACIONMADRE'].map(educacion_map)
df_Saber11['FAMI_EDUCACIONPADRE'] = df_Saber11['FAMI_EDUCACIONPADRE'].map(educacion_map)

# Verificar los resultados
print("\nValores después de la transformación en FAMI_ESTRATOVIVIENDA:")
print(df_Saber11['FAMI_ESTRATOVIVIENDA'].unique())

print("\nValores después de la transformación en FAMI_EDUCACIONMADRE:")
print(df_Saber11['FAMI_EDUCACIONMADRE'].unique())

print("\nValores después de la transformación en FAMI_EDUCACIONPADRE:")
print(df_Saber11['FAMI_EDUCACIONPADRE'].unique())
# Out:
# Valores después de la transformación en FAMI_ESTRATOVIVIENDA:
# [2 1 5 3 4 7 6]
#
# Valores después de la transformación en FAMI_EDUCACIONMADRE:
# [ 6.  1.  2.  4.  3.  5. nan]
#
# Valores después de la transformación en FAMI_EDUCACIONPADRE:
# [ 1.  3.  4.  2. nan  6.  5.]

# %%
# Llenar NaN con 0 y luego convertir a entero
df_Saber11['FAMI_EDUCACIONMADRE'] = df_Saber11['FAMI_EDUCACIONMADRE'].fillna(0).astype(int)
df_Saber11['FAMI_EDUCACIONPADRE'] = df_Saber11['FAMI_EDUCACIONPADRE'].fillna(0).astype(int)
df_Saber11['FAMI_ESTRATOVIVIENDA'] = df_Saber11['FAMI_ESTRATOVIVIENDA'].fillna(0).astype(int)

# Verificar resultados
print("\nValores después de transformar a enteros en FAMI_ESTRATOVIVIENDA:")
print(df_Saber11['FAMI_ESTRATOVIVIENDA'].unique())
print("\nValores después de transformar a enteros en FAMI_EDUCACIONMADRE:")
print(df_Saber11['FAMI_EDUCACIONMADRE'].unique())
print("\nValores después de transformar a enteros en FAMI_EDUCACIONPADRE:")
print(df_Saber11['FAMI_EDUCACIONPADRE'].unique())
# Out:
# Valores después de transformar a enteros en FAMI_ESTRATOVIVIENDA:
# [2 1 5 3 4 7 6]
#
# Valores después de transformar a enteros en FAMI_EDUCACIONMADRE:
# [6 1 2 4 3 5 0]
#
# Valores después de transformar a enteros en FAMI_EDUCACIONPADRE:
# [1 3 4 2 0 6 5]

# %%
# Reemplazar el valor 7 en FAMI_ESTRATOVIVIENDA con 0 para representar "Sin Estrato"
df_Saber11['FAMI_ESTRATOVIVIENDA'] = df_Saber11['FAMI_ESTRATOVIVIENDA'].replace(7, 0)

# Verificar los valores únicos después de la corrección
print("\nValores después de la corrección en FAMI_ESTRATOVIVIENDA:")
print(df_Saber11['FAMI_ESTRATOVIVIENDA'].unique())
# Out:
# Valores después de la corrección en FAMI_ESTRATOVIVIENDA:
# [2 1 5 3 4 0 6]

# %%
# Aplicar las mismas transformaciones a FAMI_ESTRATOVIVIENDA en SaberPro
df_SaberPro['FAMI_ESTRATOVIVIENDA'] = df_SaberPro['FAMI_ESTRATOVIVIENDA'].map({
    'Estrato 1': 1, 'Estrato 2': 2, 'Estrato 3': 3,
    'Estrato 4': 4, 'Estrato 5': 5, 'Estrato 6': 6, 'Sin Estrato': 0
}).fillna(0).astype(int)

# Aplicar las mismas transformaciones a FAMI_EDUCACIONMADRE y FAMI_EDUCACIONPADRE en SaberPro
education_mapping = {
    'Ninguno': 1, 'Primaria completa': 1, 'Primaria incompleta': 1,
    'Secundaria (Bachillerato) incompleta': 2, 'Secundaria (Bachillerato) completa': 3,
    'Técnica o tecnológica incompleta': 4, 'Técnica o tecnológica completa': 5,
    'Educación profesional completa': 6, 'Postgrado': 7, 'No sabe': 0, 'No Aplica': 0
}

df_SaberPro['FAMI_EDUCACIONMADRE'] = df_SaberPro['FAMI_EDUCACIONMADRE'].map(education_mapping).fillna(0).astype(int)
df_SaberPro['FAMI_EDUCACIONPADRE'] = df_SaberPro['FAMI_EDUCACIONPADRE'].map(education_mapping).fillna(0).astype(int)

# Verificar los valores únicos después de la transformación
print("\nValores después de la transformación en FAMI_ESTRATOVIVIENDA en SaberPro:")
print(df_SaberPro['FAMI_ESTRATOVIVIENDA'].unique())

print("\nValores después de la transformación en FAMI_EDUCACIONMADRE en SaberPro:")
print(df_SaberPro['FAMI_EDUCACIONMADRE'].unique())

print("\nValores después de la transformación en FAMI_EDUCACIONPADRE en SaberPro:")
print(df_SaberPro['FAMI_EDUCACIONPADRE'].unique())
# Out:
# Valores después de la transformación en FAMI_ESTRATOVIVIENDA en SaberPro:
# [1 2 3 4 5 6 0]
#
# Valores después de la transformación en FAMI_EDUCACIONMADRE en SaberPro:
# [1 5 6 7 3 4 2 0]
#
# Valores después de la transformación en FAMI_EDUCACIONPADRE en SaberPro:
# [0 3 1 5 6 2 4 7]

# %% [markdown]
# **Estrategia del Modelo**
#
# *Estrategia de Selección de Variables*
#
# *Priorizar Matemáticas y Comprensión de Lectura en Ambos Conjuntos:* Matemáticas y comprensión de lectura son ampliamente reconocidas como indicadores del éxito académico futuro. En el contexto colombiano y en muchos otros, estos puntajes son críticos no solo para estudios académicos, sino también para las predicciones de éxito en el mercado laboral y el rendimiento en estudios superiores. Así que tiene sentido tratarlas como predictores clave tanto en Saber11 como en SaberPro.
#
# *Considerar Puntaje Global solo en Saber11:* La razón por la que el Puntaje Global no aparece en SaberPro refleja la naturaleza diferente de estas evaluaciones. Saber11 busca una evaluación integral de habilidades y conocimientos previos a la educación superior, mientras que SaberPro está más orientado a evaluar competencias específicas en áreas técnicas y profesionales. Usar el Puntaje Global en Saber11 ayuda a encapsular una visión general del rendimiento educativo en ese nivel, lo cual es útil para modelos que buscan predecir desempeños futuros o clasificar según rendimiento general.
#
# *Incluir Todas las Áreas en SaberPro para Identificar Patrones de Competencia Técnica y Profesional:* En SaberPro, incluir todos los puntajes específicos tiene una ventaja en la creación de modelos que identifiquen habilidades diferenciadas y patrones de desempeño en áreas específicas. La combinación de áreas puede ser útil en análisis de clustering o para modelos que evalúan competencias laborales, ya que muchos estudios sugieren que las habilidades técnicas y comunicativas avanzadas son claves para el éxito en el mercado laboral.
#
# *Aprovechar las Variables Socioeconómicas Contextuales:* Las variables socioeconómicas, como el nivel educativo de los padres, el estrato socioeconómico, y el lugar de residencia (CATEGORIA), proporcionan información contextual crucial. Estudios indican que estas variables tienen una fuerte relación con los logros académicos y las oportunidades futuras, y en este caso, hay respaldo estadístico en la correlación positiva de estas variables con los puntajes clave. Mantener estas variables permitirá capturar el contexto social en el análisis y será valioso en la creación de modelos más interpretables.
#
# **Análisis en el Contexto de Reducción de Dimensionalidad**
#
# Para una reducción de dimensionalidad en ambos conjuntos de datos:
#
# *Saber11:* Nos enfocamos en PUNT_MATEMATICAS, PUNT_LECTURA_CRITICA, PUNT_GLOBAL y las variables socioeconómicas relevantes.
#
# *SaberPro:* Se incluyen todos los puntajes de las áreas clave (MOD_RAZONA_CUANTITAT_PUNT, MOD_LECTURA_CRITICA_PUNT, MOD_COMUNI_ESCRITA_PUNT, MOD_INGLES_PUNT, MOD_COMPETEN_CIUDADA_PUNT) y las variables socioeconómicas relevantes.
#
# Para la reducción de dimensionalidad, el método más adecuado puede ser PCA (Análisis de Componentes Principales) debido a la mezcla de variables categóricas y numéricas transformadas. Este método captura la varianza principal y permite reducir la carga computacional sin perder significancia estadística, manteniendo los patrones de correlación en el conjunto.

# %%
# Código para convertir las variables categóricas

from sklearn.preprocessing import LabelEncoder

# Listado de variables categóricas a convertir
categorical_vars_saber11 = ['COLE_AREA_UBICACION', 'COLE_BILINGUE', 'COLE_CALENDARIO', 
                            'COLE_GENERO', 'COLE_JORNADA', 'COLE_NATURALEZA', 
                            'COLE_SEDE_PRINCIPAL', 'ESTU_GENERO', 'FAMI_TIENEAUTOMOVIL', 
                            'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET', 'FAMI_TIENELAVADORA']

categorical_vars_saberpro = ['ESTU_PAIS_RESIDE', 'INST_CARACTER_ACADEMICO', 'ESTU_NUCLEO_PREGRADO', 
                             'ESTU_INST_DEPARTAMENTO', 'ESTU_INST_MUNICIPIO', 'ESTU_GENERO', 
                             'ESTU_NIVEL_PRGM_ACADEMICO', 'ESTU_METODO_PRGM', 
                             'ESTU_ESTUDIANTE', 'INST_ORIGEN', 'MOD_INGLES_DESEM']

# Codificar variables categóricas en Saber11
for var in categorical_vars_saber11:
    if var in df_Saber11.columns:
        df_Saber11[var] = LabelEncoder().fit_transform(df_Saber11[var].astype(str))

# Codificar variables categóricas en SaberPro
for var in categorical_vars_saberpro:
    if var in df_SaberPro.columns:
        df_SaberPro[var] = LabelEncoder().fit_transform(df_SaberPro[var].astype(str))

print("Transformación de variables categóricas completada.")
# Out:
# Transformación de variables categóricas completada.

# %%
# Definir las columnas de puntajes clave en Saber11 y SaberPro
scores_saber11 = ['PUNT_MATEMATICAS', 'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL']
socioeconomic_vars_saber11 = ['FAMI_CUARTOSHOGAR', 'FAMI_PERSONASHOGAR', 'FAMI_ESTRATOVIVIENDA', 
                              'FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE', 'CATEGORIA', 'EDAD_EXAMEN']

scores_saberpro = ['MOD_RAZONA_CUANTITAT_PUNT', 'MOD_LECTURA_CRITICA_PUNT', 
                   'MOD_COMUNI_ESCRITA_PUNT', 'MOD_INGLES_PUNT', 'MOD_COMPETEN_CIUDADA_PUNT']
socioeconomic_vars_saberpro = ['FAMI_ESTRATOVIVIENDA', 'FAMI_EDUCACIONMADRE', 
                               'FAMI_EDUCACIONPADRE', 'CATEGORIA', 'EDAD_EXAMEN']

# Correlación de variables socioeconómicas en Saber11 con los puntajes clave
print("\nCorrelación de variables socioeconómicas en Saber11 con los puntajes clave:")
numeric_cols_saber11 = df_Saber11.select_dtypes(include=['number']).corr()
for score in scores_saber11:
    print(f"\nCorrelación con {score}:")
    print(numeric_cols_saber11[score][socioeconomic_vars_saber11])

# Correlación de variables socioeconómicas en SaberPro con los puntajes clave
print("\nCorrelación de variables socioeconómicas en SaberPro con los puntajes clave:")
numeric_cols_saberpro = df_SaberPro.select_dtypes(include=['number']).corr()
for score in scores_saberpro:
    print(f"\nCorrelación con {score}:")
    print(numeric_cols_saberpro[score][socioeconomic_vars_saberpro])
# Out:
# Correlación de variables socioeconómicas en Saber11 con los puntajes clave:
#
# Correlación con PUNT_MATEMATICAS:
# FAMI_CUARTOSHOGAR       0.024037
# FAMI_PERSONASHOGAR     -0.105316
# FAMI_ESTRATOVIVIENDA    0.282156
# FAMI_EDUCACIONMADRE     0.345269
# FAMI_EDUCACIONPADRE     0.298882
# CATEGORIA              -0.212636
# EDAD_EXAMEN            -0.256238
# Name: PUNT_MATEMATICAS, dtype: float64
#
# Correlación con PUNT_LECTURA_CRITICA:
# FAMI_CUARTOSHOGAR       0.013848
# FAMI_PERSONASHOGAR     -0.116991
# FAMI_ESTRATOVIVIENDA    0.289610
# FAMI_EDUCACIONMADRE     0.352407
# FAMI_EDUCACIONPADRE     0.300433
# CATEGORIA              -0.244094
# EDAD_EXAMEN            -0.234919
# Name: PUNT_LECTURA_CRITICA, dtype: float64
#
# Correlación con PUNT_GLOBAL:
# FAMI_CUARTOSHOGAR       0.024486
# FAMI_PERSONASHOGAR     -0.131984
# FAMI_ESTRATOVIVIENDA    0.322023
# FAMI_EDUCACIONMADRE     0.385854
# FAMI_EDUCACIONPADRE     0.338292
# CATEGORIA              -0.256533
# EDAD_EXAMEN            -0.256526
# Name: PUNT_GLOBAL, dtype: float64
#
# Correlación de variables socioeconómicas en SaberPro con los puntajes clave:
#
# Correlación con MOD_RAZONA_CUANTITAT_PUNT:
# FAMI_ESTRATOVIVIENDA    0.202263
# FAMI_EDUCACIONMADRE     0.180689
# FAMI_EDUCACIONPADRE     0.163212
# CATEGORIA              -0.148262
# EDAD_EXAMEN            -0.222632
# Name: MOD_RAZONA_CUANTITAT_PUNT, dtype: float64
#
# Correlación con MOD_LECTURA_CRITICA_PUNT:
# FAMI_ESTRATOVIVIENDA    0.209256
# FAMI_EDUCACIONMADRE     0.197881
# FAMI_EDUCACIONPADRE     0.175998
# CATEGORIA              -0.162727
# EDAD_EXAMEN            -0.233491
# Name: MOD_LECTURA_CRITICA_PUNT, dtype: float64
#
# Correlación con MOD_COMUNI_ESCRITA_PUNT:
# FAMI_ESTRATOVIVIENDA    0.125182
# FAMI_EDUCACIONMADRE     0.088131
# FAMI_EDUCACIONPADRE     0.084428
# CATEGORIA              -0.085158
# EDAD_EXAMEN            -0.117269
# Name: MOD_COMUNI_ESCRITA_PUNT, dtype: float64
#
# Correlación con MOD_INGLES_PUNT:
# FAMI_ESTRATOVIVIENDA    0.402959
# FAMI_EDUCACIONMADRE     0.328531
# FAMI_EDUCACIONPADRE     0.307398
# CATEGORIA              -0.251178
# EDAD_EXAMEN            -0.288628
# Name: MOD_INGLES_PUNT, dtype: float64
#
# Correlación con MOD_COMPETEN_CIUDADA_PUNT:
# FAMI_ESTRATOVIVIENDA    0.203029
# FAMI_EDUCACIONMADRE     0.184461
# FAMI_EDUCACIONPADRE     0.160790
# CATEGORIA              -0.145865
# EDAD_EXAMEN            -0.174755
# Name: MOD_COMPETEN_CIUDADA_PUNT, dtype: float64

# %% [markdown]
# **Análisis de Resultados de Correlación entre Variables Socioeconómicas y Desempeño Académico en Saber11 y SaberPro**
#
# **1. Análisis de Correlación en Saber11**
#
# En el conjunto de datos de Saber11, se observan relaciones importantes entre las variables socioeconómicas y los puntajes en áreas clave, como Matemáticas, Lectura Crítica y el Puntaje Global, lo cual permite inferir el impacto del contexto socioeconómico en el desempeño escolar:
#
# *Educación de los Padres:* Tanto el nivel educativo de la madre como del padre muestran una correlación positiva moderada con los puntajes en Matemáticas (0.345 y 0.298, respectivamente), en Lectura Crítica (0.352 y 0.300), y con el Puntaje Global (0.386 y 0.338). Estos valores sugieren que un mayor nivel educativo de los padres puede ser un factor de influencia positiva en el desempeño académico de los estudiantes.
#
# *Estrato Socioeconómico:* La variable FAMI_ESTRATOVIVIENDA, que refleja el estrato socioeconómico, también tiene una correlación positiva con los puntajes, especialmente con el Puntaje Global (0.322). Este patrón indica que estudiantes de estratos socioeconómicos más altos tienden a obtener mejores resultados en las áreas evaluadas.
#
# *Categoría del Municipio (CATEGORIA):* Existe una correlación negativa entre la categoría del municipio y los puntajes, especialmente en el Puntaje Global (-0.257). Esto sugiere que los estudiantes en municipios con menores recursos (mayores valores en la categoría) enfrentan mayores desafíos en su rendimiento académico.
#
# *Edad al Momento del Examen (EDAD_EXAMEN):* La edad del estudiante muestra una correlación negativa con todos los puntajes evaluados, siendo más alta en el caso de Matemáticas (-0.256). Este patrón puede deberse a que los estudiantes que repiten grados o retrasan su educación a menudo presentan un desempeño menor, lo cual es un aspecto relevante a considerar en políticas educativas.
#
# **2. Análisis de Correlación en SaberPro**
#
# En el caso de SaberPro, el análisis de correlación arroja datos significativos en cuanto a la influencia del contexto socioeconómico en el rendimiento académico en el nivel universitario y en habilidades técnicas específicas:
#
# *Estrato Socioeconómico y Educación de los Padres:* Al igual que en Saber11, el estrato y el nivel educativo de los padres muestran correlaciones positivas con los puntajes en diversas áreas. Notablemente, FAMI_ESTRATOVIVIENDA tiene una correlación de 0.403 con el puntaje en inglés (MOD_INGLES_PUNT), indicando que el estrato podría tener una incidencia importante en el acceso y la exposición a este idioma. Igualmente, el nivel educativo de la madre (0.329) y del padre (0.307) se relacionan positivamente con el desempeño en inglés.
#
# *Categoría del Municipio (CATEGORIA):* Nuevamente, la categoría del municipio presenta una correlación negativa con los puntajes en áreas como Matemáticas (-0.148), Lectura Crítica (-0.163), Inglés (-0.251), y Competencias Ciudadanas (-0.146). Esto subraya el impacto adverso de vivir en municipios con menos recursos, que parece persistir en la educación superior.
#
# *Edad del Estudiante al Momento del Examen (EDAD_EXAMEN):* La edad muestra una correlación negativa con los puntajes en áreas clave, especialmente en Inglés (-0.289) y Matemáticas (-0.223). Esto podría reflejar la dificultad adicional que enfrentan los estudiantes que retoman o retrasan su educación en completar los estudios universitarios con éxito en comparación con sus pares más jóvenes.
#
# **3. Conclusiones Generales**
#
# En resumen, los resultados de este análisis de correlación destacan varias tendencias importantes en ambas bases de datos:
#
# Las variables socioeconómicas, especialmente el nivel educativo de los padres y el estrato socioeconómico, tienen una relación positiva con el rendimiento académico, siendo indicadores de apoyo que los entornos más favorecidos contribuyen al éxito escolar y universitario.
# La categoría del municipio, que representa el acceso a recursos y calidad de vida, tiene un impacto adverso en el desempeño académico, señalando una brecha educativa que persiste entre los estudiantes de municipios de diferentes categorías.
# Finalmente, la edad al momento de presentar los exámenes tiende a relacionarse negativamente con el rendimiento, lo cual puede deberse a la pérdida de continuidad en la educación.
# Estos hallazgos refuerzan la importancia de los factores socioeconómicos en el desarrollo académico y sugieren áreas de intervención para políticas públicas orientadas a reducir la desigualdad educativa y apoyar a estudiantes de entornos menos favorecidos.

# %%
# Mostrar las columnas actuales en el DataFrame de Saber11
print("Columnas en Saber11:")
print(df_Saber11.columns)

# Mostrar las columnas actuales en el DataFrame de SaberPro
print("\nColumnas en SaberPro:")
print(df_SaberPro.columns)
# Out:
# Columnas en Saber11:
# Index(['COLE_AREA_UBICACION', 'COLE_BILINGUE', 'COLE_CALENDARIO',
#        'COLE_COD_DANE_ESTABLECIMIENTO', 'COLE_COD_DANE_SEDE',
#        'COLE_COD_DEPTO_UBICACION', 'COLE_COD_MCPIO_UBICACION',
#        'COLE_CODIGO_ICFES', 'COLE_GENERO', 'COLE_JORNADA', 'COLE_NATURALEZA',
#        'COLE_SEDE_PRINCIPAL', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_COD_RESIDE_MCPIO',
#        'ESTU_GENERO', 'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONMADRE',
#        'FAMI_EDUCACIONPADRE', 'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR',
#        'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET',
#        'FAMI_TIENELAVADORA', 'DESEMP_INGLES', 'PUNT_INGLES',
#        'PUNT_MATEMATICAS', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_C_NATURALES',
#        'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL', 'AÑO', 'EDAD_EXAMEN', 'COD_MPIO',
#        'CATEGORIA'],
#       dtype='object')
#
# Columnas en SaberPro:
# Index(['ESTU_PAIS_RESIDE', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_COD_RESIDE_MCPIO',
#        'ESTU_CODDANE_COLE_TERMINO', 'ESTU_COD_COLE_MCPIO_TERMINO',
#        'INST_COD_INSTITUCION', 'INST_CARACTER_ACADEMICO',
#        'ESTU_NUCLEO_PREGRADO', 'ESTU_INST_DEPARTAMENTO',
#        'ESTU_INST_CODMUNICIPIO', 'ESTU_INST_MUNICIPIO',
#        'ESTU_PRGM_CODMUNICIPIO', 'ESTU_NIVEL_PRGM_ACADEMICO',
#        'ESTU_METODO_PRGM', 'ESTU_VALORMATRICULAUNIVERSIDAD',
#        'ESTU_PAGOMATRICULABECA', 'ESTU_PAGOMATRICULACREDITO',
#        'ESTU_HORASSEMANATRABAJA', 'ESTU_SNIES_PRGMACADEMICO',
#        'ESTU_ESTUDIANTE', 'ESTU_GENERO', 'ESTU_PAGOMATRICULAPADRES',
#        'ESTU_PAGOMATRICULAPROPIO', 'FAMI_EDUCACIONPADRE',
#        'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENELAVADORA', 'FAMI_ESTRATOVIVIENDA',
#        'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET', 'FAMI_EDUCACIONMADRE',
#        'INST_ORIGEN', 'MOD_RAZONA_CUANTITAT_PUNT', 'MOD_COMUNI_ESCRITA_PUNT',
#        'MOD_COMUNI_ESCRITA_DESEM', 'MOD_INGLES_DESEM',
#        'MOD_LECTURA_CRITICA_PUNT', 'MOD_INGLES_PUNT',
#        'MOD_COMPETEN_CIUDADA_PUNT', 'AÑO', 'EDAD_EXAMEN', 'COD_MPIO',
#        'CATEGORIA'],
#       dtype='object')

# %%
# Seleccionar las variables relevantes para el análisis de PCA en cada dataset
# Variables socioeconómicas y puntajes clave en Saber11
variables_saber11 = ['FAMI_CUARTOSHOGAR', 'FAMI_PERSONASHOGAR', 'FAMI_ESTRATOVIVIENDA', 
                     'FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE', 'CATEGORIA', 'EDAD_EXAMEN', 
                     'PUNT_MATEMATICAS', 'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL']

# Variables socioeconómicas y puntajes clave en SaberPro
variables_saberpro = ['FAMI_ESTRATOVIVIENDA', 'FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE', 
                      'CATEGORIA', 'EDAD_EXAMEN', 'MOD_RAZONA_CUANTITAT_PUNT', 
                      'MOD_LECTURA_CRITICA_PUNT', 'MOD_COMUNI_ESCRITA_PUNT', 
                      'MOD_INGLES_PUNT', 'MOD_COMPETEN_CIUDADA_PUNT']

# Crear dataframes con las columnas seleccionadas para cada base de datos
df_pca_saber11 = df_Saber11[variables_saber11]
df_pca_saberpro = df_SaberPro[variables_saberpro]

# Define la ruta donde se guardarán los archivos
ruta_salida = r"C:\Users\jaime\ALUNA Dropbox\JAIME ARTURO RAMIREZ\MIAD-Proyecto"

# Guardar los DataFrames de Saber11 y SaberPro en archivos CSV en la ruta especificada
df_pca_saber11.to_csv(f"{ruta_salida}\\Saber11_PCA_ready.csv", index=False)
df_pca_saberpro.to_csv(f"{ruta_salida}\\SaberPro_PCA_ready.csv", index=False)

print("Archivos CSV generados: 'Saber11_PCA_ready.csv' y 'SaberPro_PCA_ready.csv'")
# Out:
# Archivos CSV generados: 'Saber11_PCA_ready.csv' y 'SaberPro_PCA_ready.csv'

# %%
# Mostrar la cantidad de registros en cada DataFrame
num_filas_saber11 = df_pca_saber11.shape[0]
num_filas_saberpro = df_pca_saberpro.shape[0]

print(f"Cantidad de registros en Saber11: {num_filas_saber11}")
print(f"Cantidad de registros en SaberPro: {num_filas_saberpro}")
# Out:
# Cantidad de registros en Saber11: 4257229
# Cantidad de registros en SaberPro: 1090585

# %%
# Frecuencia de las variables categóricas principales en Saber11
categoricas_saber11 = ['COLE_AREA_UBICACION', 'COLE_BILINGUE', 'COLE_CALENDARIO', 
                       'COLE_GENERO', 'COLE_JORNADA', 'COLE_NATURALEZA', 'ESTU_GENERO', 
                       'FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE', 'FAMI_ESTRATOVIVIENDA']
for col in categoricas_saber11:
    print(f"\nFrecuencia de valores en {col} de Saber11:")
    print(df_Saber11[col].value_counts())

# Paso 3d: Frecuencia de las variables categóricas principales en SaberPro
categoricas_saberpro = ['INST_CARACTER_ACADEMICO', 'ESTU_NIVEL_PRGM_ACADEMICO', 
                        'ESTU_METODO_PRGM', 'ESTU_GENERO', 'INST_ORIGEN', 
                        'FAMI_EDUCACIONPADRE', 'FAMI_EDUCACIONMADRE', 'FAMI_ESTRATOVIVIENDA']
for col in categoricas_saberpro:
    print(f"\nFrecuencia de valores en {col} de SaberPro:")
    print(df_SaberPro[col].value_counts())
